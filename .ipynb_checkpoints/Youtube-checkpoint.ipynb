# %%
import numpy as np
import pandas as pd

df = pd.read_excel("youtube_scrape.xlsx")
df
# Out:
#                                                   title  \
# 0     Trinh Tuan Dung - Interactive Course Materials...
# 1     IS480: Final Year Projects (AY2013 -14 T2): Te...
# 2                                      Team Anthanasios
# 3                                           B1G1 - Kyaw
# 4            Li Yuanming - Distributed Machine Learning
# ...                                                 ...
# 4792  SIT Open House 2011 - The Culinary Institute o...
# 4793                SIT Open House 2011 Admissions Talk
# 4794                     SIT Open House 2011 Highlights
# 4795  Dr Ting Seng Kiong, Deputy President (Academic...
# 4796           Professor Tan Chin Tiong, President, SIT
#
#                                             description  videoLength  \
# 0                                                   NaN        185.0
# 1                http://wiki.smu.edu.sg/is480/Main_Page         90.0
# 2                                                   NaN        307.0
# 3         Kyaw  reflects on his project work with B1G1.         26.0
# 4                                                   NaN        470.0
# ...                                                 ...          ...
# 4792  Singapore Institute of Technology (SIT) had ou...        347.0
# 4793  Singapore Institute of Technology (SIT) had ou...        388.0
# 4794  Have a look at what happened over the 2 days w...        599.0
# 4795  Dr Ting gives his introduction to SIT, who we ...        404.0
# 4796  Professor Tan Chin Tiong, President, SIT gives...        229.0
#
#                                            thumbnailUrl      videoId  \
# 0     https://i.ytimg.com/vi/7JfrWorLUdw/maxresdefau...  7JfrWorLUdw
# 1      https://i.ytimg.com/vi/qnk99rTQZzQ/hqdefault.jpg  qnk99rTQZzQ
# 2      https://i.ytimg.com/vi/UddTUfEwuZk/hqdefault.jpg  UddTUfEwuZk
# 3      https://i.ytimg.com/vi/OUmUlbEV0Mk/hqdefault.jpg  OUmUlbEV0Mk
# 4      https://i.ytimg.com/vi/wEdYJ9NCEPw/hqdefault.jpg  wEdYJ9NCEPw
# ...                                                 ...          ...
# 4792   https://i.ytimg.com/vi/eH6RTLhmz9M/hqdefault.jpg  eH6RTLhmz9M
# 4793   https://i.ytimg.com/vi/EHn2jLejP5k/hqdefault.jpg  EHn2jLejP5k
# 4794   https://i.ytimg.com/vi/ZHUpi_gVibk/hqdefault.jpg  ZHUpi_gVibk
# 4795   https://i.ytimg.com/vi/qwhAnsCk1dI/hqdefault.jpg  qwhAnsCk1dI
# 4796   https://i.ytimg.com/vi/yOkXCFDNtKg/hqdefault.jpg  yOkXCFDNtKg
#
#                                          videoUrl                 channelId  \
# 0     https://www.youtube.com/watch?v=7JfrWorLUdw  UCNSaFyFPonGbx2EAGFBkwgA
# 1     https://www.youtube.com/watch?v=qnk99rTQZzQ  UCP9tOGPsNkPhqfQUQOgtUVQ
# 2     https://www.youtube.com/watch?v=UddTUfEwuZk  UCP9tOGPsNkPhqfQUQOgtUVQ
# 3     https://www.youtube.com/watch?v=OUmUlbEV0Mk  UCP9tOGPsNkPhqfQUQOgtUVQ
# 4     https://www.youtube.com/watch?v=wEdYJ9NCEPw  UCNSaFyFPonGbx2EAGFBkwgA
# ...                                           ...                       ...
# 4792  https://www.youtube.com/watch?v=eH6RTLhmz9M  UCoLSRpZqPJMw1Pqt614H3HA
# 4793  https://www.youtube.com/watch?v=EHn2jLejP5k  UCoLSRpZqPJMw1Pqt614H3HA
# 4794  https://www.youtube.com/watch?v=ZHUpi_gVibk  UCoLSRpZqPJMw1Pqt614H3HA
# 4795  https://www.youtube.com/watch?v=qwhAnsCk1dI  UCoLSRpZqPJMw1Pqt614H3HA
# 4796  https://www.youtube.com/watch?v=yOkXCFDNtKg  UCoLSRpZqPJMw1Pqt614H3HA
#
#                                              channelUrl  \
# 0     https://www.youtube.com/channel/UCNSaFyFPonGbx...
# 1     https://www.youtube.com/channel/UCP9tOGPsNkPhq...
# 2     https://www.youtube.com/channel/UCP9tOGPsNkPhq...
# 3     https://www.youtube.com/channel/UCP9tOGPsNkPhq...
# 4     https://www.youtube.com/channel/UCNSaFyFPonGbx...
# ...                                                 ...
# 4792  https://www.youtube.com/channel/UCoLSRpZqPJMw1...
# 4793  https://www.youtube.com/channel/UCoLSRpZqPJMw1...
# 4794  https://www.youtube.com/channel/UCoLSRpZqPJMw1...
# 4795  https://www.youtube.com/channel/UCoLSRpZqPJMw1...
# 4796  https://www.youtube.com/channel/UCoLSRpZqPJMw1...
#
#                                                keywords  averageRating  ...  \
# 0                                                   NaN            NaN  ...
# 1     SMU, SIS, School of Information Systems, Singa...            NaN  ...
# 2     School of Information Systems, SMU, Is480, Pro...            NaN  ...
# 3     B1g1, Singapore Management University, School ...            NaN  ...
# 4                                                   NaN            NaN  ...
# ...                                                 ...            ...  ...
# 4792  SIT, speech, university, singaporetech, open h...            NaN  ...
# 4793  SIT, speech, university, singaporetech, open h...            NaN  ...
# 4794  Open house, talks, SIT, highlights, university...            NaN  ...
# 4795  SIT, speech, university, singaporetech, open h...            NaN  ...
# 4796  SIT, speech, university, open house, education...            NaN  ...
#
#      likeCount dislikeCount  \
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
# ...        ...          ...
# 4792       6.0          NaN
# 4793       NaN          NaN
# 4794       1.0          NaN
# 4795       8.0          NaN
# 4796       8.0          NaN
#
#                                      authorThumbnailUrl    subscriberCount  \
# 0     https://yt3.ggpht.com/ytc/AKedOLShSNmQxGfxeYWd...    361 subscribers
# 1     https://yt3.ggpht.com/ytc/AKedOLQ-4vhlowEz3eva...    385 subscribers
# 2     https://yt3.ggpht.com/ytc/AKedOLQ-4vhlowEz3eva...    385 subscribers
# 3     https://yt3.ggpht.com/ytc/AKedOLQ-4vhlowEz3eva...    385 subscribers
# 4     https://yt3.ggpht.com/ytc/AKedOLShSNmQxGfxeYWd...    361 subscribers
# ...                                                 ...                ...
# 4792  https://yt3.ggpht.com/ytc/AKedOLQ5orpxTBIr0pMo...  2.51K subscribers
# 4793  https://yt3.ggpht.com/ytc/AKedOLQ5orpxTBIr0pMo...  2.51K subscribers
# 4794  https://yt3.ggpht.com/ytc/AKedOLQ5orpxTBIr0pMo...  2.51K subscribers
# 4795  https://yt3.ggpht.com/ytc/AKedOLQ5orpxTBIr0pMo...  2.51K subscribers
# 4796  https://yt3.ggpht.com/ytc/AKedOLQ5orpxTBIr0pMo...  2.51K subscribers
#
#             category          publishDate isLiveContent isFamilySafe  \
# 0          Education  2021-06-08 00:00:00         False         True
# 1          Education  2016-04-08 00:00:00         False         True
# 2          Education  2013-11-06 00:00:00         False         True
# 3          Education  2013-11-06 00:00:00         False         True
# 4          Education  2021-06-09 00:00:00         False         True
# ...              ...                  ...           ...          ...
# 4792       Education             ########         False         True
# 4793       Education             ########         False         True
# 4794       Education             ########         False         True
# 4795       Education             ########         False         True
# 4796  People & Blogs             ########         False         True
#
#                                             query                 timestamp
# 0     https://www.youtube.com/watch?v=7JfrWorLUdw  2022-03-27T01:15:13.440Z
# 1     https://www.youtube.com/watch?v=qnk99rTQZzQ  2022-03-27T00:03:57.652Z
# 2     https://www.youtube.com/watch?v=UddTUfEwuZk  2022-03-27T00:10:33.973Z
# 3     https://www.youtube.com/watch?v=OUmUlbEV0Mk  2022-03-27T00:11:22.926Z
# 4     https://www.youtube.com/watch?v=wEdYJ9NCEPw  2022-03-27T01:14:22.845Z
# ...                                           ...                       ...
# 4792  https://www.youtube.com/watch?v=eH6RTLhmz9M  2022-03-27T08:29:39.619Z
# 4793  https://www.youtube.com/watch?v=EHn2jLejP5k  2022-03-27T08:29:41.298Z
# 4794  https://www.youtube.com/watch?v=ZHUpi_gVibk  2022-03-27T08:29:42.668Z
# 4795  https://www.youtube.com/watch?v=qwhAnsCk1dI  2022-03-27T08:29:43.754Z
# 4796  https://www.youtube.com/watch?v=yOkXCFDNtKg  2022-03-27T08:29:44.814Z
#
# [4797 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['title', 'description', 'videoLength', 'thumbnailUrl', 'videoId',
#        'videoUrl', 'channelId', 'channelUrl', 'keywords', 'averageRating',
#        'author', 'profileUrl', 'viewCount', 'likeCount', 'dislikeCount',
#        'authorThumbnailUrl', 'subscriberCount', 'category', 'publishDate',
#        'isLiveContent', 'isFamilySafe', 'query', 'timestamp'],
#       dtype='object')

# %%
df["author"].unique()
# Out:
# array(['SCSEMarketing', 'SMU School of Computing and Information Systems',
#        'Singapore Management University', 'NUS', 'NUS Computing', 'NTUsg',
#        'Singapore University of Social Sciences (SUSS)',
#        'SUTD Singapore University of Technology and Design',
#        'Singapore Institute of Technology (SIT)'], dtype=object)

# %%
df2 = df.loc[:,["title","description","videoLength","keywords","author","viewCount","likeCount","subscriberCount","category","publishDate","isLiveContent","isFamilySafe","query"]]
df2
# Out:
#                                                   title  \
# 0     Trinh Tuan Dung - Interactive Course Materials...
# 1     IS480: Final Year Projects (AY2013 -14 T2): Te...
# 2                                      Team Anthanasios
# 3                                           B1G1 - Kyaw
# 4            Li Yuanming - Distributed Machine Learning
# ...                                                 ...
# 4792  SIT Open House 2011 - The Culinary Institute o...
# 4793                SIT Open House 2011 Admissions Talk
# 4794                     SIT Open House 2011 Highlights
# 4795  Dr Ting Seng Kiong, Deputy President (Academic...
# 4796           Professor Tan Chin Tiong, President, SIT
#
#                                             description  videoLength  \
# 0                                                   NaN        185.0
# 1                http://wiki.smu.edu.sg/is480/Main_Page         90.0
# 2                                                   NaN        307.0
# 3         Kyaw  reflects on his project work with B1G1.         26.0
# 4                                                   NaN        470.0
# ...                                                 ...          ...
# 4792  Singapore Institute of Technology (SIT) had ou...        347.0
# 4793  Singapore Institute of Technology (SIT) had ou...        388.0
# 4794  Have a look at what happened over the 2 days w...        599.0
# 4795  Dr Ting gives his introduction to SIT, who we ...        404.0
# 4796  Professor Tan Chin Tiong, President, SIT gives...        229.0
#
#                                                keywords  \
# 0                                                   NaN
# 1     SMU, SIS, School of Information Systems, Singa...
# 2     School of Information Systems, SMU, Is480, Pro...
# 3     B1g1, Singapore Management University, School ...
# 4                                                   NaN
# ...                                                 ...
# 4792  SIT, speech, university, singaporetech, open h...
# 4793  SIT, speech, university, singaporetech, open h...
# 4794  Open house, talks, SIT, highlights, university...
# 4795  SIT, speech, university, singaporetech, open h...
# 4796  SIT, speech, university, open house, education...
#
#                                                author  viewCount  likeCount  \
# 0                                       SCSEMarketing        0.0        NaN
# 1     SMU School of Computing and Information Systems        1.0        NaN
# 2     SMU School of Computing and Information Systems        1.0        NaN
# 3     SMU School of Computing and Information Systems        1.0        NaN
# 4                                       SCSEMarketing        1.0        NaN
# ...                                               ...        ...        ...
# 4792          Singapore Institute of Technology (SIT)     4688.0        6.0
# 4793          Singapore Institute of Technology (SIT)      370.0        NaN
# 4794          Singapore Institute of Technology (SIT)      647.0        1.0
# 4795          Singapore Institute of Technology (SIT)     1474.0        8.0
# 4796          Singapore Institute of Technology (SIT)     1305.0        8.0
#
#         subscriberCount        category          publishDate  isLiveContent  \
# 0       361 subscribers       Education  2021-06-08 00:00:00          False
# 1       385 subscribers       Education  2016-04-08 00:00:00          False
# 2       385 subscribers       Education  2013-11-06 00:00:00          False
# 3       385 subscribers       Education  2013-11-06 00:00:00          False
# 4       361 subscribers       Education  2021-06-09 00:00:00          False
# ...                 ...             ...                  ...            ...
# 4792  2.51K subscribers       Education             ########          False
# 4793  2.51K subscribers       Education             ########          False
# 4794  2.51K subscribers       Education             ########          False
# 4795  2.51K subscribers       Education             ########          False
# 4796  2.51K subscribers  People & Blogs             ########          False
#
#       isFamilySafe                                        query
# 0             True  https://www.youtube.com/watch?v=7JfrWorLUdw
# 1             True  https://www.youtube.com/watch?v=qnk99rTQZzQ
# 2             True  https://www.youtube.com/watch?v=UddTUfEwuZk
# 3             True  https://www.youtube.com/watch?v=OUmUlbEV0Mk
# 4             True  https://www.youtube.com/watch?v=wEdYJ9NCEPw
# ...            ...                                          ...
# 4792          True  https://www.youtube.com/watch?v=eH6RTLhmz9M
# 4793          True  https://www.youtube.com/watch?v=EHn2jLejP5k
# 4794          True  https://www.youtube.com/watch?v=ZHUpi_gVibk
# 4795          True  https://www.youtube.com/watch?v=qwhAnsCk1dI
# 4796          True  https://www.youtube.com/watch?v=yOkXCFDNtKg
#
# [4797 rows x 13 columns]

# %%
ntu_scse = df2[df2['author'] == "SCSEMarketing"]
ntu_scse = ntu_scse.reset_index(drop = True)
ntu_scse
# Out:
#                                                   title  \
# 0     Trinh Tuan Dung - Interactive Course Materials...
# 1            Li Yuanming - Distributed Machine Learning
# 2     25_Mantri Raghav_Feature Selection for Demand ...
# 3     Chen Taoyu - Instruction Level Branch Conditio...
# 4                            26_Mok Wei Min_ ARTVStudio
# ...                                                 ...
# 1112  Tan Chade-Meng Google's Jolly Good Fellow (Whi...
# 1113  Greetings to incoming Undergraduates from SCE ...
# 1114                                     Research Video
# 1115  Android Phone Based RC Helicopter | Final Year...
# 1116               Illness Tracker | Final Year Project
#
#                                             description  videoLength  \
# 0                                                   NaN        185.0
# 1                                                   NaN        470.0
# 2                                                   NaN        393.0
# 3                                                   NaN        416.0
# 4                                                   NaN        227.0
# ...                                                 ...          ...
# 1112  SCE Alumnus; Smart, Passionate, Kind & Compass...        321.0
# 1113  Srikanthan Thambipillai, Chair of the School o...         52.0
# 1114                                                NaN        372.0
# 1115  The Android Phone Based RC Helicopter is a rem...        114.0
# 1116  Kenneth Leong Zheng Sen, 2012 Final Year Compu...        411.0
#
#                                                keywords         author  \
# 0                                                   NaN  SCSEMarketing
# 1                                                   NaN  SCSEMarketing
# 2                                                   NaN  SCSEMarketing
# 3                                                   NaN  SCSEMarketing
# 4                                                   NaN  SCSEMarketing
# ...                                                 ...            ...
# 1112  Tan Chade-Meng, Google, Jolly Good Fellow, SCE...  SCSEMarketing
# 1113  Education, School of Computer Engineering, Com...  SCSEMarketing
# 1114  Computer Engineering, Computer Science, Resear...  SCSEMarketing
# 1115  Andriod, Andriod Phone, RC Helicopter, RC, Rem...  SCSEMarketing
# 1116  Mobile, Undergraduate, Undergraduate Programme...  SCSEMarketing
#
#       viewCount  likeCount  subscriberCount   category          publishDate  \
# 0           0.0        NaN  361 subscribers  Education  2021-06-08 00:00:00
# 1           1.0        NaN  361 subscribers  Education  2021-06-09 00:00:00
# 2           2.0        NaN  361 subscribers  Education  2022-02-16 00:00:00
# 3           2.0        NaN  361 subscribers  Education  2021-06-09 00:00:00
# 4           3.0        NaN  361 subscribers  Education  2022-02-16 00:00:00
# ...         ...        ...              ...        ...                  ...
# 1112      286.0        1.0  361 subscribers  Education  2012-06-06 00:00:00
# 1113      577.0        1.0  361 subscribers  Education  2012-06-06 00:00:00
# 1114       73.0        NaN  361 subscribers  Education  2012-06-06 00:00:00
# 1115     8564.0       15.0  361 subscribers  Education  2012-06-06 00:00:00
# 1116    29417.0       77.0  361 subscribers  Education  2012-06-06 00:00:00
#
#       isLiveContent  isFamilySafe                                        query
# 0             False          True  https://www.youtube.com/watch?v=7JfrWorLUdw
# 1             False          True  https://www.youtube.com/watch?v=wEdYJ9NCEPw
# 2             False          True  https://www.youtube.com/watch?v=7cjKQulY060
# 3             False          True  https://www.youtube.com/watch?v=DTTPZsE98Co
# 4             False          True  https://www.youtube.com/watch?v=8RFqGR3UTN0
# ...             ...           ...                                          ...
# 1112          False          True  https://www.youtube.com/watch?v=jOEerEd2Z8o
# 1113          False          True  https://www.youtube.com/watch?v=mkBYucbNGW0
# 1114          False          True  https://www.youtube.com/watch?v=0lBf2CKUl8E
# 1115          False          True  https://www.youtube.com/watch?v=TxoJstBXsI4
# 1116          False          True  https://www.youtube.com/watch?v=LdNYz5YTLhU
#
# [1117 rows x 13 columns]

# %%
smu_scis = df2[df2['author'] == "SMU School of Computing and Information Systems"]
smu_scis = smu_scis.reset_index(drop = True)
smu_scis
# Out:
#                                                  title  \
# 0    IS480: Final Year Projects (AY2013 -14 T2): Te...
# 1                                     Team Anthanasios
# 2                                          B1G1 - Kyaw
# 3    IS480: Final Year Projects (AY2013 -14 T2): Te...
# 4                                                 iLab
# ..                                                 ...
# 611  1 minute to know what SMU School of Informatio...
# 612      Information Systems in SMU (Produced in 2020)
# 613         Computer Science in SMU (Produced in 2020)
# 614  What makes #SMUMITB special? Hear from Ms Anut...
# 615  IS306 (AY2013-14 Term 1): G1T4 Team 3Plus1G - ...
#
#                                            description  videoLength  \
# 0               http://wiki.smu.edu.sg/is480/Main_Page         90.0
# 1                                                  NaN        307.0
# 2        Kyaw  reflects on his project work with B1G1.         26.0
# 3               http://wiki.smu.edu.sg/is480/Main_Page         71.0
# 4                                                  NaN        329.0
# ..                                                 ...          ...
# 611  SIS Website: http://sis.smu.edu.sg/\n\nFind ou...         77.0
# 612  * School Name has been changed to School of Co...        381.0
# 613  * School Name has been changed to School of Co...        317.0
# 614  Do you know why SMU Master of IT in Business (...         44.0
# 615  This project was done by the team for their (I...         59.0
#
#                                               keywords  \
# 0    SMU, SIS, School of Information Systems, Singa...
# 1    School of Information Systems, SMU, Is480, Pro...
# 2    B1g1, Singapore Management University, School ...
# 3    SMU, SIS, School of Information Systems, Singa...
# 4    SMU, SIS, School of Information Systems, Singa...
# ..                                                 ...
# 611  SMU, SIS, School of Information Systems, Singa...
# 612  SMU, SIS, School of Information Systems, Singa...
# 613  SMU, SIS, School of Information Systems, Singa...
# 614  SMU, SIS, School of Information Systems, Singa...
# 615  Singapore Management University, Project, Scho...
#
#                                               author  viewCount  likeCount  \
# 0    SMU School of Computing and Information Systems        1.0        NaN
# 1    SMU School of Computing and Information Systems        1.0        NaN
# 2    SMU School of Computing and Information Systems        1.0        NaN
# 3    SMU School of Computing and Information Systems        2.0        NaN
# 4    SMU School of Computing and Information Systems        2.0        NaN
# ..                                               ...        ...        ...
# 611  SMU School of Computing and Information Systems     3402.0       10.0
# 612  SMU School of Computing and Information Systems     7301.0       72.0
# 613  SMU School of Computing and Information Systems     9023.0       56.0
# 614  SMU School of Computing and Information Systems   102270.0        2.0
# 615  SMU School of Computing and Information Systems        NaN        NaN
#
#      subscriberCount   category          publishDate  isLiveContent  \
# 0    385 subscribers  Education  2016-04-08 00:00:00          False
# 1    385 subscribers  Education  2013-11-06 00:00:00          False
# 2    385 subscribers  Education  2013-11-06 00:00:00          False
# 3    385 subscribers  Education  2016-04-08 00:00:00          False
# 4    385 subscribers  Education  2013-11-06 00:00:00          False
# ..               ...        ...                  ...            ...
# 611  385 subscribers  Education  2014-03-25 00:00:00          False
# 612  385 subscribers  Education  2020-02-27 00:00:00          False
# 613  385 subscribers  Education  2020-02-25 00:00:00          False
# 614  385 subscribers  Education  2020-08-31 00:00:00          False
# 615              NaN  Education             ########          False
#
#      isFamilySafe                                        query
# 0            True  https://www.youtube.com/watch?v=qnk99rTQZzQ
# 1            True  https://www.youtube.com/watch?v=UddTUfEwuZk
# 2            True  https://www.youtube.com/watch?v=OUmUlbEV0Mk
# 3            True  https://www.youtube.com/watch?v=t8znYuUtV1E
# 4            True  https://www.youtube.com/watch?v=cHJUwQcahuc
# ..            ...                                          ...
# 611          True  https://www.youtube.com/watch?v=Om6rIhDp878
# 612          True  https://www.youtube.com/watch?v=R4HcXQWbqNo
# 613          True  https://www.youtube.com/watch?v=C376Bm6zvYs
# 614          True  https://www.youtube.com/watch?v=yVKXb-jTDmo
# 615          True   https://www.youtube.com/shorts/yEl2x-4lZeo
#
# [616 rows x 13 columns]

# %%
smu = df2[df2['author'] == "Singapore Management University"]
smu = smu.reset_index(drop = True)
smu
# Out:
#                                                   title  \
# 0          AMERICAN WRITERS FESTIVAL 2013: DAY 5 PART 3
# 1         AMERICAN WRITERS FESTIVAL 2013:  DAY 5 PART 1
# 2          AMERICAN WRITERS FESTIVAL 2013: DAY 3 PART 2
# 3          AMERICAN WRITERS FESTIVAL 2013: DAY 2 PART 2
# 4          AMERICAN WRITERS FESTIVAL 2014: DAY 2 Part 2
# ...                                                 ...
# 1171       SMU MSc in Innovation: Someone Who Innovates
# 1172    Why pursue SMU Master of Business in IT (MITB)?
# 1173                              SMU City Perspectives
# 1174  SMU Ho Rih Hwa Lecture: Datuk Seri Anwar Ibrah...
# 1175  #TalentsOfSMU: Karl Mak & Adrian Ang, the Duo ...
#
#                                             description  videoLength  \
# 0     Every event is different and yet every event d...       1969.0
# 1     Every event is different and yet every event d...       1745.0
# 2     Every event is different and yet every event d...       1117.0
# 3     Every event is different and yet every event d...       1443.0
# 4     Additional info :This year is indeed a very sp...       1570.0
# ...                                                 ...          ...
# 1171  Want to become Asia's next Innovation Leader? ...         24.0
# 1172  Gain insights into the MITB programme highligh...         87.0
# 1173  Cities grow when ideas chart larger conversati...         76.0
# 1174  Singapore Management University (SMU) was priv...       4277.0
# 1175  You might have heard of SGAG (@Nubbad TV), @Of...         96.0
#
#                                                keywords  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1171  Singapore Management University, SMU, MSc in I...
# 1172  singapore management university, smu, singapor...
# 1173  singapore management university, smu, singapor...
# 1174  Ho Rih Hwa Leadership Lecture Series, HRH Lect...
# 1175  Singapore Management University, SMU, Alumni, ...
#
#                                author  viewCount  likeCount  \
# 0     Singapore Management University        6.0        NaN
# 1     Singapore Management University        8.0        NaN
# 2     Singapore Management University        8.0        NaN
# 3     Singapore Management University        9.0        1.0
# 4     Singapore Management University       10.0        NaN
# ...                               ...        ...        ...
# 1171  Singapore Management University   277068.0        4.0
# 1172  Singapore Management University   317239.0        6.0
# 1173  Singapore Management University   506827.0       12.0
# 1174  Singapore Management University   734521.0     3284.0
# 1175  Singapore Management University    27094.0       91.0
#
#         subscriberCount   category          publishDate  isLiveContent  \
# 0     12.4K subscribers  Education  2015-07-21 00:00:00          False
# 1     12.4K subscribers  Education  2015-07-21 00:00:00          False
# 2     12.4K subscribers  Education  2015-07-21 00:00:00          False
# 3     12.4K subscribers  Education  2015-07-21 00:00:00          False
# 4     12.4K subscribers  Education  2015-07-21 00:00:00          False
# ...                 ...        ...                  ...            ...
# 1171  12.4K subscribers  Education  2017-03-21 00:00:00          False
# 1172  12.4K subscribers  Education  2020-09-30 00:00:00          False
# 1173  12.4K subscribers  Education  2021-01-07 00:00:00          False
# 1174  12.4K subscribers  Education  2018-09-21 00:00:00          False
# 1175  12.4K subscribers  Education             ########          False
#
#       isFamilySafe                                        query
# 0             True  https://www.youtube.com/watch?v=U2eKuWCqXmU
# 1             True  https://www.youtube.com/watch?v=ft95KACyz6I
# 2             True  https://www.youtube.com/watch?v=UA-zpRZJY9M
# 3             True  https://www.youtube.com/watch?v=zgq3c3-0AHU
# 4             True  https://www.youtube.com/watch?v=ZYTrRWKTUxo
# ...            ...                                          ...
# 1171          True  https://www.youtube.com/watch?v=EaXDQM4C7VM
# 1172          True  https://www.youtube.com/watch?v=7WOz81HEVx8
# 1173          True  https://www.youtube.com/watch?v=vS4_kV8p9F0
# 1174          True  https://www.youtube.com/watch?v=l9l82dwpNUc
# 1175          True  https://www.youtube.com/watch?v=zyymuvxU7jw
#
# [1176 rows x 13 columns]

# %%
nus = df2[df2['author'] == "NUS"]
nus = nus.reset_index(drop = True)
nus
# Out:
#                                                 title  \
# 0   CAREER COMPASS: NUS CDE: An interdisciplinary ...
# 1   CAREER COMPASS: All you need to know about the...
# 2   CAREER COMPASS: Helping NUS students build a s...
# 3   CAREER COMPASS: An enhanced undergraduate expe...
# 4                                 The SCOT Experience
# ..                                                ...
# 82                                   NUS Student Life
# 83                             Best of NUSSU Rag 2015
# 84                  NUS Institutional Video - Chinese
# 85                                The SCOT Experience
# 86        Multi-Drone Light Show - Behind the Scenes!
#
#                                           description  videoLength  \
# 0   CNA938 Career Compass | Monday, 14 February 20...        804.0
# 1   CNA938 Career Compass | Monday, 21 February 20...        898.0
# 2   CNA938 Career Compass | Monday, 7 February 202...        823.0
# 3   CNA938 Career Compass | Monday, 28 February 20...        969.0
# 4   Hop on and experience a driverless ride with S...        135.0
# ..                                                ...          ...
# 82  Check out this video to get a glimpse of the e...        186.0
# 83  Held on August 7 2015, NUS Students Union Rag ...        215.0
# 84  The NUS institutional video captures the disti...        220.0
# 85  Hop on and experience a driverless ride with S...        135.0
# 86  Temasek Laboratories @ NUS led a team of resea...        111.0
#
#                                              keywords author  viewCount  \
# 0   National University of Singapore, Singapore, N...    NUS       24.0
# 1   National University of Singapore, Singapore, N...    NUS       25.0
# 2   National University of Singapore, Singapore, N...    NUS       39.0
# 3   National University of Singapore, Singapore, N...    NUS       49.0
# 4    National University of Singapore, Singapore, NUS    NUS       49.0
# ..                                                ...    ...        ...
# 82   National University of Singapore, Singapore, NUS    NUS      419.0
# 83   National University of Singapore, Singapore, NUS    NUS      324.0
# 84                                                NaN    NUS      195.0
# 85   National University of Singapore, Singapore, NUS    NUS       49.0
# 86   National University of Singapore, Singapore, NUS    NUS     1414.0
#
#     likeCount  subscriberCount        category          publishDate  \
# 0         NaN  623 subscribers       Education  2022-03-03 00:00:00
# 1         NaN  623 subscribers       Education  2022-03-03 00:00:00
# 2         NaN  623 subscribers       Education  2022-03-03 00:00:00
# 3         NaN  623 subscribers       Education  2022-03-03 00:00:00
# 4         NaN  623 subscribers  People & Blogs  2016-01-12 00:00:00
# ..        ...              ...             ...                  ...
# 82        1.0  623 subscribers  People & Blogs             ########
# 83        NaN  623 subscribers  People & Blogs             ########
# 84        NaN  623 subscribers  People & Blogs             ########
# 85        NaN  623 subscribers  People & Blogs             ########
# 86        4.0  623 subscribers  People & Blogs             ########
#
#     isLiveContent  isFamilySafe                                        query
# 0           False          True  https://www.youtube.com/watch?v=EGmIoLuIZXs
# 1           False          True  https://www.youtube.com/watch?v=PnZbxexqP64
# 2           False          True  https://www.youtube.com/watch?v=2gW2gXK0a3U
# 3           False          True  https://www.youtube.com/watch?v=19dEvetG4ZA
# 4           False          True  https://www.youtube.com/watch?v=1K73SLNJv-A
# ..            ...           ...                                          ...
# 82          False          True  https://www.youtube.com/watch?v=8Ihcdnk_3SM
# 83          False          True  https://www.youtube.com/watch?v=es_UYLKirRk
# 84          False          True  https://www.youtube.com/watch?v=dO8L4BLgJts
# 85          False          True  https://www.youtube.com/watch?v=1K73SLNJv-A
# 86          False          True  https://www.youtube.com/watch?v=_mXUdqT_oq0
#
# [87 rows x 13 columns]

# %%
nus_computing = df2[df2['author'] == "NUS Computing"]
nus_computing = nus_computing.reset_index(drop = True)
nus_computing
# Out:
#                                                  title  \
# 0        2015 Commencement Pre-Ceremony Video Outtakes
# 1    Outtakes: Insider Tips for Freshmen - Ash & As...
# 2                     2015 Commencement Clip Colin Tan
# 3                11th STePS: SoC Term Project Showcase
# 4                 2015 Commencement Clip Ooi Wei Tsang
# ..                                                 ...
# 161                 2015 Commencement Clip Tuan Q Phan
# 162                         Computing Through The Ages
# 163                            NUS School of Computing
# 164                Computing Through The Ages - Teaser
# 165                                 The SoC Experience
#
#                                            description  videoLength  \
# 0    Our profs are experts in their fields, but not...        206.0
# 1    Check out all the bits of this funny duo that ...         90.0
# 2    Dr Colin Tan congratulates the Class of 2015 a...         76.0
# 3    Students showcase their innovative and excitin...         70.0
# 4    Associate Professor Ooi Wei Tsang encourages t...         22.0
# ..                                                 ...          ...
# 161  It's a special year for Dr. Tuan Phan as the f...         64.0
# 162  NUS School of Computing celebrates its 16th an...        211.0
# 163  Thinking about what to study at university? Ge...        263.0
# 164  Calling all DCS, DISCS, and SoC Alumni!\n \n W...         74.0
# 165  -by Lighthouse Productions\n A student made vi...         90.0
#
#                                               keywords         author  \
# 0    Graduation (Field Of Study), National Universi...  NUS Computing
# 1    National University Of Singapore (College/Univ...  NUS Computing
# 2    Graduation (Field Of Study), Computer Engineer...  NUS Computing
# 3    school, university, class, term, project, show...  NUS Computing
# 4    Graduation (Field Of Study), Computer Science ...  NUS Computing
# ..                                                 ...            ...
# 161  Graduation (Field Of Study), Information Syste...  NUS Computing
# 162  Computer Science (Field Of Study), Computing (...  NUS Computing
# 163  National University Of Singapore (College/Univ...  NUS Computing
# 164  Computing (Website Category), Computer Science...  NUS Computing
# 165  NUS, Computing, Singapore, Computer Science (I...  NUS Computing
#
#      viewCount  likeCount    subscriberCount         category  \
# 0        113.0        NaN  1.33K subscribers        Education
# 1        181.0        NaN  1.33K subscribers        Education
# 2        181.0        NaN  1.33K subscribers        Education
# 3        201.0        1.0  1.33K subscribers        Education
# 4        263.0        1.0  1.33K subscribers        Education
# ..         ...        ...                ...              ...
# 161      560.0        2.0  1.33K subscribers        Education
# 162      388.0        2.0  1.33K subscribers        Education
# 163    17059.0       96.0  1.33K subscribers        Education
# 164      466.0        3.0  1.33K subscribers  Travel & Events
# 165     4132.0       24.0  1.33K subscribers   People & Blogs
#
#              publishDate  isLiveContent  isFamilySafe  \
# 0    2015-07-15 00:00:00          False          True
# 1    2015-10-27 00:00:00          False          True
# 2    2015-07-15 00:00:00          False          True
# 3    2017-11-16 00:00:00          False          True
# 4    2015-07-15 00:00:00          False          True
# ..                   ...            ...           ...
# 161             ########          False          True
# 162             ########          False          True
# 163             ########          False          True
# 164             ########          False          True
# 165  2014-04-02 00:00:00          False          True
#
#                                            query
# 0    https://www.youtube.com/watch?v=ho_lOd2fnZo
# 1    https://www.youtube.com/watch?v=-pfkzLcgmzk
# 2    https://www.youtube.com/watch?v=Drr5wXJe-AY
# 3    https://www.youtube.com/watch?v=-k2oE_zxLuE
# 4    https://www.youtube.com/watch?v=iaKMHv4mCL4
# ..                                           ...
# 161  https://www.youtube.com/watch?v=W-fArXCvgjU
# 162  https://www.youtube.com/watch?v=FZW2z1CEH8s
# 163  https://www.youtube.com/watch?v=9ZhNn4oKq58
# 164  https://www.youtube.com/watch?v=E4ZdChAKHWE
# 165  https://www.youtube.com/watch?v=CgnEGoRyAs0
#
# [166 rows x 13 columns]

# %%
ntu = df2[df2['author'] == "NTUsg"]
ntu = ntu.reset_index(drop = True)
ntu
# Out:
#                                                  title  \
# 0    Healthier, more sustainable alternative to pal...
# 1                    Your guide to the NTU HEY! AR app
# 2    PRWeek Awards Asia 2014 Best Corporate Publica...
# 3    An submarine Q&A with a national underwater ru...
# 4                     Art and technology on the runway
# ..                                                 ...
# 458                      NTU studentsâ€™ favourite BBT
# 459  Celebrate with these Instagram filters for #NT...
# 460                            Latte art by Connect 71
# 461    Drawings of The Hive by primary school students
# 462            Hunting wild boars in the winter in NTU
#
#                                            description  videoLength  \
# 0    A healthier oil made from microalgae may be th...        100.0
# 1    Interact with your copy of HEY! and watch page...         66.0
# 2    NTU’s HEY! magazine was named Best Corporate P...         15.0
# 3    National underwater rugby player and NTU alumn...         35.0
# 4    Weaving art with technology, undergraduates fr...        136.0
# ..                                                 ...          ...
# 458  NTU students spill on their favourite bubble t...         43.0
# 459  #NTUsgClassof2020, ARe you ready to celebrate ...         47.0
# 460  Baristas at Connect71 in NTU create works of a...         50.0
# 461  The Hive, NTUâ€™s learning hub, has inspired c...         19.0
# 462  In an alternate universe, NTU students go hunt...         16.0
#
#                                               keywords author  viewCount  \
# 0    Nanyang Technological University, NTU Singapor...  NTUsg      134.0
# 1    HEY!, HEY! AR, HEY! magazine, NTU Magazine, AR...  NTUsg      176.0
# 2                                                  NaN  NTUsg      179.0
# 3                                                  NaN  NTUsg      182.0
# 4    Nanyang Technological University (Organization...  NTUsg      184.0
# ..                                                 ...    ...        ...
# 458  HEY!, HEY! AR, HEY! magazine, NTU Magazine, AR...  NTUsg        NaN
# 459  Nanyang Technological University, NTU Singapor...  NTUsg        NaN
# 460                                                NaN  NTUsg        NaN
# 461                                                NaN  NTUsg        NaN
# 462                                                NaN  NTUsg        NaN
#
#      likeCount    subscriberCount              category          publishDate  \
# 0          NaN  18.1K subscribers             Education  2022-03-21 00:00:00
# 1          4.0  18.1K subscribers             Education  2020-10-18 00:00:00
# 2          2.0  18.1K subscribers             Education  2014-08-21 00:00:00
# 3          1.0  18.1K subscribers  Science & Technology  2021-09-08 00:00:00
# 4          1.0  18.1K subscribers             Education  2013-07-23 00:00:00
# ..         ...                ...                   ...                  ...
# 458        NaN                NaN             Education             ########
# 459        NaN                NaN             Education             ########
# 460        NaN                NaN             Education             ########
# 461        NaN                NaN             Education             ########
# 462        NaN                NaN             Education             ########
#
#      isLiveContent  isFamilySafe                                        query
# 0            False          True  https://www.youtube.com/watch?v=KL4BMs63oys
# 1            False          True  https://www.youtube.com/watch?v=O_kKQ9LMJ2M
# 2            False          True  https://www.youtube.com/watch?v=LkyDuIQkOn0
# 3            False          True  https://www.youtube.com/watch?v=TFGtGB6jFC4
# 4            False          True  https://www.youtube.com/watch?v=BEkZGuyiXD4
# ..             ...           ...                                          ...
# 458          False          True   https://www.youtube.com/shorts/uSFzwTv6aRc
# 459          False          True   https://www.youtube.com/shorts/R1j7a6GrDWE
# 460          False          True   https://www.youtube.com/shorts/cX-RVg5pZV0
# 461          False          True   https://www.youtube.com/shorts/qK1s9OTe0k8
# 462          False          True   https://www.youtube.com/shorts/AdMRfzuxNVM
#
# [463 rows x 13 columns]

# %%
suss = df2[df2['author'] == "Singapore University of Social Sciences (SUSS)"]
suss = suss.reset_index(drop = True)
suss
# Out:
#                                                  title  \
# 0    Make Your Mark For The Greater Good - Radiah (...
# 1    Make Your Mark For The Greater Good - Samantha...
# 2    Make Your Mark For The Greater Good - Firdaus ...
# 3    Make Your Mark For The Greater Good - Edwin Ho...
# 4                         SUSS Human Factors Programme
# ..                                                 ...
# 322                    Unleash Your Potential To Excel
# 323                      Join The U That Believes In U
# 324                      Join The U That Believes In U
# 325  Life as a UniSIM SBIZ student (Part 1 of 4) â€...
# 326                             UniSIM University Song
#
#                                            description  videoLength  \
# 0    Radiah shares how learning from industry pract...         30.0
# 1    Samantha shares how SUSS made a difference in ...         30.0
# 2    Firdaus discusses how the learning culture at ...         29.0
# 3    Edwin discuss how entrepreneurship programmes ...         30.0
# 4    20 QUESTIONS WITH SUSS: A/P Chui Yoon Ping, fr...        191.0
# ..                                                 ...          ...
# 322  If you dream of building a better future for y...         15.0
# 323  At SIM University, youâ€™ll discover that noth...         60.0
# 324  At SIM University, youâ€™ll discover that noth...         90.0
# 325  Ever wondered what life is like as a student i...         68.0
# 326  UniSIM's University song sang during Convocati...        247.0
#
#                                               keywords  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 322      UniSIM, SIM University, Degree, Undergraduate
# 323  UniSIM, SIM University, SIM, Further Education...
# 324                 UniSIM, Open House, SIM University
# 325                             UniSIM, SIM University
# 326                                                NaN
#
#                                              author  viewCount  likeCount  \
# 0    Singapore University of Social Sciences (SUSS)       20.0        NaN
# 1    Singapore University of Social Sciences (SUSS)       24.0        NaN
# 2    Singapore University of Social Sciences (SUSS)       13.0        NaN
# 3    Singapore University of Social Sciences (SUSS)       18.0        NaN
# 4    Singapore University of Social Sciences (SUSS)       72.0        1.0
# ..                                              ...        ...        ...
# 322  Singapore University of Social Sciences (SUSS)    88032.0        1.0
# 323  Singapore University of Social Sciences (SUSS)   148879.0        5.0
# 324  Singapore University of Social Sciences (SUSS)   152168.0        8.0
# 325  Singapore University of Social Sciences (SUSS)     1152.0        3.0
# 326  Singapore University of Social Sciences (SUSS)     1780.0        3.0
#
#     subscriberCount   category          publishDate  isLiveContent  \
# 0               NaN  Education             ########          False
# 1               NaN  Education             ########          False
# 2               NaN  Education             ########          False
# 3               NaN  Education             ########          False
# 4               NaN  Education             ########          False
# ..              ...        ...                  ...            ...
# 322             NaN  Education  2017-01-06 00:00:00          False
# 323             NaN  Education  2016-09-04 00:00:00          False
# 324             NaN  Education  2016-08-01 00:00:00          False
# 325             NaN  Education             ########          False
# 326             NaN  Education             ########          False
#
#      isFamilySafe                                        query
# 0            True  https://www.youtube.com/watch?v=WNIrQ8NxQLI
# 1            True  https://www.youtube.com/watch?v=Rp0A7-NGx3w
# 2            True  https://www.youtube.com/watch?v=caEZn087g1Q
# 3            True  https://www.youtube.com/watch?v=_Llb2EekfLc
# 4            True  https://www.youtube.com/watch?v=e9VJdnp88Ck
# ..            ...                                          ...
# 322          True  https://www.youtube.com/watch?v=8tzCM0A56wI
# 323          True  https://www.youtube.com/watch?v=sNnvCoVn-MA
# 324          True  https://www.youtube.com/watch?v=b8XzStiJimI
# 325          True  https://www.youtube.com/watch?v=Kx6oLSU8XNs
# 326          True  https://www.youtube.com/watch?v=6YHBtRxPjIA
#
# [327 rows x 13 columns]

# %%
sutd = df2[df2['author'] == "SUTD Singapore University of Technology and Design"]
sutd = sutd.reset_index(drop = True)
sutd
# Out:
#                                                  title  \
# 0                    SUTD Design Innovation Forum 2022
# 1    Project SO COOL! - an SUTD innovation designed...
# 2    Project Sproot - an SUTD innovation designed f...
# 3    Ask CSD (Computer Science and Design) - SUTD O...
# 4    Admissions and Scholarships 101 - SUTD Open Ho...
# ..                                                 ...
# 425  Interviews with our President and Board of Tru...
# 426                                  The Ideas Economy
# 427  Interview with Participating MIT Faculty Membe...
# 428                              Prof. Thomas Magnanti
# 429  Prime Minister of Singapore - Mr. Lee Hsien Loong
#
#                                            description  videoLength  \
# 0    SUTDâ€™s mission of "A Better World by Design"...       7125.0
# 1    Design helps keep us cool in the park. Harness...         15.0
# 2    Design transforms the way we eat and grow food...         15.0
# 3    Learn more about our Computer Science and Desi...       3136.0
# 4    Find out everything you need to know about app...       2979.0
# ..                                                 ...          ...
# 425  The Singapore University of Technology and Des...        546.0
# 426  The Singapore University of Technology and Des...        125.0
# 427  Interview of John E. Fernandez - Associate Pro...        244.0
# 428  President of Singapore University of Technolog...        282.0
# 429  Prime Minister of Singapore, Mr. Lee Hsien Loo...        162.0
#
#                                               keywords  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 425  SUTD, sutd, university, technology, design, Si...
# 426  SUTD, sutd, Singapore, university, technology,...
# 427                               richard de neufville
# 428  SUTD, sutd, Singapore, university, technology,...
# 429  SUTD, sutd, Singapore, university, technology,...
#
#                                                 author  viewCount  likeCount  \
# 0    SUTD Singapore University of Technology and De...      683.0       17.0
# 1    SUTD Singapore University of Technology and De...     7687.0       15.0
# 2    SUTD Singapore University of Technology and De...     7841.0       14.0
# 3    SUTD Singapore University of Technology and De...      713.0        9.0
# 4    SUTD Singapore University of Technology and De...      434.0        8.0
# ..                                                 ...        ...        ...
# 425  SUTD Singapore University of Technology and De...     3153.0       10.0
# 426  SUTD Singapore University of Technology and De...     1078.0        5.0
# 427  SUTD Singapore University of Technology and De...     2626.0        5.0
# 428  SUTD Singapore University of Technology and De...     1846.0        6.0
# 429  SUTD Singapore University of Technology and De...    20262.0       50.0
#
#       subscriberCount   category publishDate  isLiveContent  isFamilySafe  \
# 0    3.5K subscribers  Education    ########           True          True
# 1    3.5K subscribers  Education    ########          False          True
# 2    3.5K subscribers  Education    ########          False          True
# 3    3.5K subscribers  Education    ########           True          True
# 4    3.5K subscribers  Education    ########           True          True
# ..                ...        ...         ...            ...           ...
# 425  3.5K subscribers  Education    ########          False          True
# 426  3.5K subscribers  Education    ########          False          True
# 427  3.5K subscribers  Education    ########          False          True
# 428  3.5K subscribers  Education    ########          False          True
# 429  3.5K subscribers  Education    ########          False          True
#
#                                            query
# 0    https://www.youtube.com/watch?v=045rYhhJBmA
# 1    https://www.youtube.com/watch?v=KUaEQ_CudTg
# 2    https://www.youtube.com/watch?v=S5dtBXz5hmw
# 3    https://www.youtube.com/watch?v=jklUcIWPxPc
# 4    https://www.youtube.com/watch?v=Br6PJI99sJE
# ..                                           ...
# 425  https://www.youtube.com/watch?v=MQvZZ0BE1ew
# 426  https://www.youtube.com/watch?v=YgYx5kNQuTo
# 427  https://www.youtube.com/watch?v=7x4WgYO3sTg
# 428  https://www.youtube.com/watch?v=3ExJA60S-6w
# 429  https://www.youtube.com/watch?v=8tEfk8_E9Dk
#
# [430 rows x 13 columns]

# %%
sit = df2[df2['author'] == "Singapore Institute of Technology (SIT)"]
sit = sit.reset_index(drop = True)
sit
# Out:
#                                                  title  \
# 0               Building Partnerships: Siemens Pte Ltd
# 1    Building Partnerships: Singapore Logistics Ass...
# 2             Protein Supplements for the Asian Palate
# 3    Building Partnerships: YCH Group and Y3 Techno...
# 4                            Our #SITizens: Agnes Chew
# ..                                                 ...
# 410  SIT Open House 2011 - The Culinary Institute o...
# 411                SIT Open House 2011 Admissions Talk
# 412                     SIT Open House 2011 Highlights
# 413  Dr Ting Seng Kiong, Deputy President (Academic...
# 414           Professor Tan Chin Tiong, President, SIT
#
#                                            description  videoLength  \
# 0    SIT has partnered Siemens Pte Ltd to develop a...         86.0
# 1    A partnership with the Singapore Logistics Ass...         90.0
# 2    When you think about protein supplements, flav...        215.0
# 3    Digitalisation is essential to an ever-changin...         89.0
# 4    Meet #SITizen Agnes Chew! Her love for science...        145.0
# ..                                                 ...          ...
# 410  Singapore Institute of Technology (SIT) had ou...        347.0
# 411  Singapore Institute of Technology (SIT) had ou...        388.0
# 412  Have a look at what happened over the 2 days w...        599.0
# 413  Dr Ting gives his introduction to SIT, who we ...        404.0
# 414  Professor Tan Chin Tiong, President, SIT gives...        229.0
#
#                                               keywords  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    education, university, degree programme, stude...
# ..                                                 ...
# 410  SIT, speech, university, singaporetech, open h...
# 411  SIT, speech, university, singaporetech, open h...
# 412  Open house, talks, SIT, highlights, university...
# 413  SIT, speech, university, singaporetech, open h...
# 414  SIT, speech, university, open house, education...
#
#                                       author  viewCount  likeCount  \
# 0    Singapore Institute of Technology (SIT)       28.0        NaN
# 1    Singapore Institute of Technology (SIT)       44.0        NaN
# 2    Singapore Institute of Technology (SIT)      121.0        5.0
# 3    Singapore Institute of Technology (SIT)       69.0        2.0
# 4    Singapore Institute of Technology (SIT)      264.0        6.0
# ..                                       ...        ...        ...
# 410  Singapore Institute of Technology (SIT)     4688.0        6.0
# 411  Singapore Institute of Technology (SIT)      370.0        NaN
# 412  Singapore Institute of Technology (SIT)      647.0        1.0
# 413  Singapore Institute of Technology (SIT)     1474.0        8.0
# 414  Singapore Institute of Technology (SIT)     1305.0        8.0
#
#        subscriberCount        category          publishDate  isLiveContent  \
# 0    2.51K subscribers   Entertainment             ########          False
# 1    2.51K subscribers   Entertainment             ########          False
# 2    2.51K subscribers   Entertainment             ########          False
# 3    2.51K subscribers   Entertainment             ########          False
# 4    2.51K subscribers       Education  2022-03-01 00:00:00          False
# ..                 ...             ...                  ...            ...
# 410  2.51K subscribers       Education             ########          False
# 411  2.51K subscribers       Education             ########          False
# 412  2.51K subscribers       Education             ########          False
# 413  2.51K subscribers       Education             ########          False
# 414  2.51K subscribers  People & Blogs             ########          False
#
#      isFamilySafe                                        query
# 0            True  https://www.youtube.com/watch?v=GSNWoMfeCgM
# 1            True  https://www.youtube.com/watch?v=sreyGP7gB3k
# 2            True  https://www.youtube.com/watch?v=wKc_M1TCdo0
# 3            True  https://www.youtube.com/watch?v=svmoCRNaZL8
# 4            True  https://www.youtube.com/watch?v=q5TIpezrsIo
# ..            ...                                          ...
# 410          True  https://www.youtube.com/watch?v=eH6RTLhmz9M
# 411          True  https://www.youtube.com/watch?v=EHn2jLejP5k
# 412          True  https://www.youtube.com/watch?v=ZHUpi_gVibk
# 413          True  https://www.youtube.com/watch?v=qwhAnsCk1dI
# 414          True  https://www.youtube.com/watch?v=yOkXCFDNtKg
#
# [415 rows x 13 columns]

# %%
df2.isna().sum()
# Out:
# title                 0
# description        1327
# videoLength           0
# keywords           2041
# author                0
# viewCount            33
# likeCount          1962
# subscriberCount     348
# category              0
# publishDate           0
# isLiveContent         0
# isFamilySafe          0
# query                 0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4797 entries, 0 to 4796
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            4797 non-null   object
#  1   description      3470 non-null   object
#  2   videoLength      4797 non-null   float64
#  3   keywords         2756 non-null   object
#  4   author           4797 non-null   object
#  5   viewCount        4764 non-null   float64
#  6   likeCount        2835 non-null   float64
#  7   subscriberCount  4449 non-null   object
#  8   category         4797 non-null   object
#  9   publishDate      4797 non-null   object
#  10  isLiveContent    4797 non-null   bool
#  11  isFamilySafe     4797 non-null   bool
#  12  query            4797 non-null   object
# dtypes: bool(2), float64(3), object(8)
# memory usage: 421.7+ KB

# %%
df2.describe()
# Out:
#         videoLength     viewCount    likeCount
# count   4797.000000  4.764000e+03  2835.000000
# mean     720.786950  7.591471e+03    19.262434
# std     1536.202159  5.285492e+04   127.770169
# min        6.000000  0.000000e+00     1.000000
# 25%       83.000000  5.300000e+01     2.000000
# 50%      179.000000  2.750000e+02     5.000000
# 75%      379.000000  1.053500e+03    11.000000
# max    30145.000000  1.577069e+06  4503.000000

# %%
df2.hist()
# Out:
# array([[<AxesSubplot:title={'center':'videoLength'}>,
#         <AxesSubplot:title={'center':'viewCount'}>],
#        [<AxesSubplot:title={'center':'likeCount'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
sit.hist()
# sutd
# suss
# ntu
# nus_computing
# nus
# smu
# smu_scis
# ntu_scse
# Out:
# array([[<AxesSubplot:title={'center':'videoLength'}>,
#         <AxesSubplot:title={'center':'viewCount'}>],
#        [<AxesSubplot:title={'center':'likeCount'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
import nltk
from pprint import pprint
import yaml
import sys
import os
import re

dict_tagged_sentences = ''
# Below indicates the relative path to
# positive/negative/inverter/incrementer/decrementer files
DICTIONARY_DIR_PREFIX = 'dicts2/'

# %%
class Splitter(object):
    def __init__(self):
        self.nltk_splitter = nltk.data.load('tokenizers/punkt/english.pickle')
        self.nltk_tokenizer = nltk.tokenize.TreebankWordTokenizer()

    def split(self, text):
        """
        input format: a paragraph of text
        output format: a list of lists of words.
            e.g.: [['this', 'is', 'a', 'sentence'], ['this', 'is', 'another', 'one']]
        """
        sentences = self.nltk_splitter.tokenize(text)
        tokenized_sentences = [self.nltk_tokenizer.tokenize(sent) for sent in sentences]
        return tokenized_sentences


class POSTagger(object):
    def __init__(self):
        pass

    def pos_tag(self, sentences):
        """
        input format: list of lists of words
            e.g.: [['this', 'is', 'a', 'sentence'], ['this', 'is', 'another', 'one']]
        output format: list of lists of tagged tokens. Each tagged tokens has a
        form, a lemma, and a list of tags
            e.g: [[('this', 'this', ['DT']), ('is', 'be', ['VB']), ('a', 'a', ['DT']), ('sentence', 'sentence', ['NN'])],
                    [('this', 'this', ['DT']), ('is', 'be', ['VB']), ('another', 'another', ['DT']), ('one', 'one', ['CARD'])]]
        """

        pos = [nltk.pos_tag(sentence) for sentence in sentences]
        #adapt format
        pos = [[(word, word, [postag]) for (word, postag) in sentence] for sentence in pos]
        return pos

class DictionaryTagger(object):
    def __init__(self, dictionary_paths):
        """

        :rtype : object
        """
        files = [open(path, 'r') for path in dictionary_paths]
        dictionaries = [yaml.load(dict_file) for dict_file in files]
        map(lambda x: x.close(), files)
        self.dictionary = {}
        self.max_key_size = 0
        for curr_dict in dictionaries:
            for key in curr_dict:
                if key in self.dictionary:
                    self.dictionary[key].extend(curr_dict[key])
                else:
                    self.dictionary[key] = curr_dict[key]
                    self.max_key_size = max(self.max_key_size, len(key))

    def tag(self, postagged_sentences):
        return [self.tag_sentence(sentence) for sentence in postagged_sentences]

    def tag_sentence(self, sentence, tag_with_lemmas=False):
        """
        the result is only one tagging of all the possible ones.
        The resulting tagging is determined by these two priority rules:
            - longest matches have higher priority
            - search is made from left to right
        """
        tag_sentence = []
        N = len(sentence)
        if self.max_key_size == 0:
            self.max_key_size = N
        i = 0
        while (i < N):
            j = min(i + self.max_key_size, N) #avoid overflow
            tagged = False
            while (j > i):
                expression_form = ' '.join([word[0] for word in sentence[i:j]]).lower()
                expression_lemma = ' '.join([word[1] for word in sentence[i:j]]).lower()
                if tag_with_lemmas:
                    literal = expression_lemma
                else:
                    literal = expression_form
                if literal in self.dictionary:
                    #self.logger.debug("found: %s" % literal)
                    is_single_token = j - i == 1
                    original_position = i
                    i = j
                    taggings = [tag for tag in self.dictionary[literal]]
                    tagged_expression = (expression_form, expression_lemma, taggings)
                    if is_single_token: #if the tagged literal is a single token, conserve its previous taggings:
                        original_token_tagging = sentence[original_position][2]
                        tagged_expression[2].extend(original_token_tagging)
                    tag_sentence.append(tagged_expression)
                    tagged = True
                else:
                    j = j - 1
            if not tagged:
                tag_sentence.append(sentence[i])
                i += 1
        return tag_sentence

def value_of(sentiment):
    if sentiment == 'positive': return 1
    if sentiment == 'negative': return -1
    return 0

def sentiment_score(review):
    return sum ([value_of(tag) for sentence in dict_tagged_sentences for token in sentence for tag in token[2]])

def sentence_score(sentence_tokens, previous_token, acum_score):
    if not sentence_tokens:
        return acum_score
    else:
        current_token = sentence_tokens[0]
        tags = current_token[2]
        token_score = sum([value_of(tag) for tag in tags])
        if previous_token is not None:
            previous_tags = previous_token[2]
            if 'inc' in previous_tags:
                token_score *= 2.0
            elif 'dec' in previous_tags:
                token_score /= 2.0
            elif 'inv' in previous_tags:
                token_score *= -1.0
        return sentence_score(sentence_tokens[1:], current_token, acum_score + token_score)

def sentiment_score(sentences):
    return sum([sentence_score(sentence, None, 0.0) for sentence in sentences])


def run_analysis(text):
    splitter = Splitter() # This boy will split a long single string into sentences.
    postagger = POSTagger() # This boy is the Part-Of-Speech tagger.

    # If text contains multiple sentences, this line splits it into individual sentences.
    splitted_sentences = splitter.split(text)
    print (splitted_sentences)
    #exit(1)

    print ("########## This performs Part-Of-Speech tagging. ##########")
    # This performs Part-Of-Speech tagging.
    pos_tagged_sentences = postagger.pos_tag(splitted_sentences)
    pprint (pos_tagged_sentences)
    exit(1)

    print ("########## This line loads Positive word and Negative word corpus. ##########")
    # This line loads Positive word and Negative word dictionaries.
    dicttagger = DictionaryTagger([ DICTIONARY_DIR_PREFIX + 'positive.yml', DICTIONARY_DIR_PREFIX + 'negative.yml'])
    dict_tagged_sentences = dicttagger.tag(pos_tagged_sentences)
    #pprint(dict_tagged_sentences)
    #exit(1)

    print ("########## [Baseline Analysis] Using only Positive/Negative corpus. ##########")
    score = sentiment_score(dict_tagged_sentences)
    print ("Score: %d" % score)
    #exit(1)

    print ("########## This line loads Positve/Negative corpus + incrementer/decrementer corpus. ##########")
    dicttagger = DictionaryTagger([ DICTIONARY_DIR_PREFIX + 'positive.yml', DICTIONARY_DIR_PREFIX + 'negative.yml', DICTIONARY_DIR_PREFIX + 'inc.yml', DICTIONARY_DIR_PREFIX + 'dec.yml'])
    dict_tagged_sentences = dicttagger.tag(pos_tagged_sentences)
    #pprint(dict_tagged_sentences)
    score = sentiment_score(dict_tagged_sentences)
    print ("Score: %d" % score)
    #exit(1)

    print ("########## This line loads Positve/Negative corpus + incrementer/decrementer/inverter corpus. ##########")
    dicttagger = DictionaryTagger([ DICTIONARY_DIR_PREFIX + 'positive.yml', DICTIONARY_DIR_PREFIX + 'negative.yml', DICTIONARY_DIR_PREFIX + 'inc.yml', DICTIONARY_DIR_PREFIX + 'dec.yml', DICTIONARY_DIR_PREFIX + 'inv.yml'])
    dict_tagged_sentences = dicttagger.tag(pos_tagged_sentences)
    #pprint(dict_tagged_sentences)
    score = sentiment_score(dict_tagged_sentences)
    print ("Score: %d" % score)
    #exit(1)

# %%
################### This is the MAIN section ###################
if __name__ == "__main__":

    print ("###############################")

    review_comment_text = "This restaurant really sucks. The service was terrible. Food was horrible."
    # Run sentiment scoring
    run_analysis(review_comment_text)
    
    ###################### Challenge ######################
    # Modify this script to read from 'Yelp_Food_Input.txt'
    #   Each row is a unique "review" (textual)
    # Open the TXT file and see how to extract the review content (which column contains the content?)
    # Attempt to score each review
    # Summarize the sentiment scores across ALL reviews using apprpriate charts, e.g. bar chart, box plot, etc.
# Out:
# ###############################
# [['This', 'restaurant', 'really', 'sucks', '.'], ['The', 'service', 'was', 'terrible', '.'], ['Food', 'was', 'horrible', '.']]
# ########## This performs Part-Of-Speech tagging. ##########
# [[('This', 'This', ['DT']),
#   ('restaurant', 'restaurant', ['NN']),
#   ('really', 'really', ['RB']),
#   ('sucks', 'sucks', ['VBZ']),
#   ('.', '.', ['.'])],
#  [('The', 'The', ['DT']),
#   ('service', 'service', ['NN']),
#   ('was', 'was', ['VBD']),
#   ('terrible', 'terrible', ['JJ']),
#   ('.', '.', ['.'])],
#  [('Food', 'Food', ['NN']),
#   ('was', 'was', ['VBD']),
#   ('horrible', 'horrible', ['JJ']),
#   ('.', '.', ['.'])]]
# ########## This line loads Positive word and Negative word corpus. ##########
# ########## [Baseline Analysis] Using only Positive/Negative corpus. ##########
# Score: 0
# ########## This line loads Positve/Negative corpus + incrementer/decrementer corpus. ##########
# Score: 0
# ########## This line loads Positve/Negative corpus + incrementer/decrementer/inverter corpus. ##########
# Score: 0
# <ipython-input-28-1017e9542d06>:43: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   dictionaries = [yaml.load(dict_file) for dict_file in files]
