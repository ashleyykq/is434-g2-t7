# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_colwidth', None) #prevent truncated view of dataframe
pd.set_option('display.max_rows', None) #show all rows

# %%
df = pd.read_csv("job_with_skills.csv")

# %%
df = df.drop(df.columns[0:1], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2555 entries, 0 to 2554
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   keyword           2555 non-null   object
#  1   clean_job_title   2554 non-null   object
#  2   clean_job_desc    2555 non-null   object
#  3   technical_skills  2555 non-null   object
#  4   soft_skills       2555 non-null   object
#  5   raw_skills        2555 non-null   object
# dtypes: object(6)
# memory usage: 119.9+ KB

# %%
df['technical_skills'] = df['technical_skills'].apply(eval)
df['soft_skills'] = df['soft_skills'].apply(eval)
df['raw_skills'] = df['raw_skills'].apply(eval)

# %%
with open("testing.csv", "w") as f:
    for index, row in df.iterrows():
        print("*******",row['clean_job_title'],"******")
        for i in row['technical_skills']:
            print(i, end=", ")
            f.write(row['keyword']+","+i+"\n")
        print()
        print("#"*25)
# Out:
# ******* Cloud Engineer ******
# linux, python,
# #########################
# ******* Cloud Engineer ******
# sql,
# #########################
# ******* Cloud Engineer Bedok Months Contract ******
# linux,
# #########################
# ******* Lead Cloud Engineer ******
#
# #########################
# ******* Cloud System Engineer ******
#
# #########################
# ******* System Engineer ******
#
# #########################
# ******* Devops Engineer ******
#
# #########################
# ******* Systems Engineer ******
# linux,
# #########################
# ******* Cloud Engineer Year Renewable Contract Bedok Up To ******
# linux,
# #########################
# ******* Cloud Devops Engineer ******
#
# #########################
# ******* Lead Cloud Engineer ******
#
# #########################
# ******* Cloud Data Engineer Analyst ******
# tableau, python, hadoop, spark, sql,
# #########################
# ******* Cloud Engineer ******
# scala, numpy, python, java,
# ...

# %%
with open("soft_skills_map.csv", "w") as f:
    for index, row in df.iterrows():
#         print("*******",row['clean_job_title'],"******")
        for i in row['soft_skills']:
#             print(i, end=", ")
            try:
                f.write(row['keyword']+","+i+"\n")
            except:
                print(i)
#         print()
#         print("#"*25)
# Out:
# 高性能和高可用性的系统
# cd流程
# 同时维护和改进我们的ci
# 有docker
# 如python
# 网络和故障排除技术有深刻理解
# ansible和jenkins的经验
# shell脚本
# 以确保对客户的服务交付承诺得以实现
# 对微服务架构和调试
# 实施自动化工具和框架
# 帮助定义和维护正确的网络运营实践
# 精通脚本语言
# 帮助将其整合到腾讯的平台上
# 对主要云平台aws
# 熟悉数据库
# 熟悉android
# ui框架及相关开发工具
# ip和http有较深刻的理解和经验
