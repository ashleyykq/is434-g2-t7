# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_colwidth', None) #prevent truncated view of dataframe
pd.set_option('display.max_rows', None) #show all rows

# %%
df = pd.read_csv("job_with_skills.csv")

# %%
df = df.drop(df.columns[0:1], axis=1)

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2554 entries, 0 to 2554
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   keyword           2554 non-null   object
#  1   clean_job_title   2554 non-null   object
#  2   clean_job_desc    2554 non-null   object
#  3   technical_skills  2554 non-null   object
#  4   soft_skills       2554 non-null   object
# dtypes: object(5)
# memory usage: 119.7+ KB

# %%
df.head()
# Out:
#           keyword                       clean_job_title  \
# 0  cloud engineer                        Cloud Engineer
# 1  cloud engineer                        Cloud Engineer
# 2  cloud engineer  Cloud Engineer Bedok Months Contract
# 3  cloud engineer                   Lead Cloud Engineer
# 4  cloud engineer                 Cloud System Engineer
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             clean_job_desc  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               description position suitable individual constant learner problem solver multi taskers candidate thrive fast paced environment step face challenge able deliver result welcome apply looking candidate interested implementation operation cloud infrastructure responsible implementing maintaining cloud infrastructure aws azure google cloud xtremax customer provide support customer issue cloud infrastructure closely security monitor privacy develop incident response procedure least year hand managing network infrastructure managed service aws azure gcp least one cloud certification level higher e g aws certified sysops administrator associate microsoft certified azure administrator associate google cloud certified professional data engineer least one operating system linux window understanding networking preferable tcp ip ip address http dns basic security concept user management o hardening communication scripting skill powershell bash python nodejs etc extra value submitting resume cv consent agree allow information provided used processed behalf xtremax pte ltd purpose registration interest current future employment u processing application employment personal data held u relating application kept strictly confidential accordance pdpa may also refer privacy policy detail http www xtremax com privacy policy inform consent providing necessary data required u process application potentially able offer
# 1  looking individual passionate designing implementing maintaining cloud infrastructure ecosystem participate project play important major role shaping customer interact u project include customer facing website portal acquire retain potential existing customer understand business design implement maintain cloud infrastructure architecture support ongoing application development integration cloud service need comfortable cloud technology architecture report directly technology manager day life collaborating engineering development team evaluate identify optimal cloud solution modifying improving existing system educating team implementation cloud technology initiative designing developing deploying modular cloud based system developing maintaining cloud solution accordance best practice ensuring efficient functioning data storage processing function accordance security policy best practice cloud security identifying analyzing resolving infrastructure vulnerability application deployment issue regularly reviewing existing system making recommendation improvement need diploma bachelor degree computer science information system computer engineering equivalent qualification azure cloud certification preferred role least year hand deploying maintaining troubleshooting cloud infrastructure familiar azure virtual desktop window virtual desktop environment preferred working azure cloud infrastructure sql server web server bonus team player able collaboratively member team troubleshooting analytical able multi task handle multiple assignment tight timeline please provide portfolio addition resume attached softcopy url offer centrally located office anson road connected tanjong pagar mrt empowering people draw career map promote agile working environment hybrid option passion building motivating dynamic competent team collaborative culture cherishes idea respectful environment competitive employee benefit flexible benefit medical wellness program creating inclusive space employee valued experience unique perspective
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     industry technology location bedok month renewable support instance wintel linux aws azure cloud environment deliver stable efficient reliable cloud infrastructure operation meet exceed stipulated sla support design implementation testing installation network underlay overlay software defined networking cloud infrastructure prem cloud perform daily performance monitoring analysis maintenance ensure network underlay prem sdn cloud infrastructure performed according sla apply interested party please send resume evonne_png persolkelly com click apply applicant would evonne png wen xuan reg r persolkelly singapore pte ltd ea license r sending u personal data curriculum vitae cv deemed consent persolkelly singapore pte ltd local overseas subsidiary affiliate collecting using disclosing personal data prospective employer company based country purpose evaluating suitability employment conducting reference check administering employment service complying government covid health advisory purpose stated privacy policy full privacy policy available www persolkelly com sg wish withdraw consent please drop u email let u know please feel free contact u query thank day
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  design implement cloud infrastructure solution secure scalable highly available aws collaborate various team define infrastructure deployment support digital transformation project provision configure maintain aws cloud infrastructure defined code ensure configuration compliance source control service eg codecommit act level support operation team automation issue encountered troubleshoot problem across wide array service functional area build operational tool deployment monitoring analysis aws infrastructure system handover operation team e g aws system manager involve participate infrastructure cost analysis optimization effort provide documentation conduct training session solution required evaluate cloud provider prepare multi cloud strategy drive transformational modernisation project degree accredited university minimum year relevant particularly cloud area focus aws cloud demonstrated hand aws code pipeline rd party integration tech savvy hand automation tool eg ansible familiar container service serverless computing preferably aws cloud certification eg aws devops solution architect ability manage time effectively set priority meet deadline posse analytical critical thinking problem solving excellent written verbal communication communication influencing presentation friendly professional demeanour ability excel team oriented environment
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     order number focused delivery wide range technology solution including innovative technology vmware microsoft virtualization microsoft core solution azure system infrastructure server storage backup many solution customer consultative basis provide troubleshooting workaround solution software issue ongoing basis customer provide installation configuration support technology solution based client work project manager deliver project accordance project management sop provide customer support direct quality assurance project assigned technical service manager provide x standby duty based duty roaster existing system maintenance customer enhance customer satisfaction overall customer relationship help leverage customer relationship within business development effort coordinate customer project schedule manage stakeholder expectation requirement till closure project deliver statement proposed consultant team ensure design accordance proposal diploma degree computer science study ability independently efficiently productively without guidance ability multi task meet deadline willingness capability learning technology required accomplishing project goal willingness x standby based duty roaster project implementation deployment troubleshooting microsoft cloud hybrid cloud solution preferred depth understanding software concept apply please kindly email updated resume cv_jasonwong goodjobcreations com sg candidate however rest assured application updated resume bank future opportunity ea personnel name jason wong seng siang ea personnel reg r ea license c
#
#                                                              technical_skills  \
# 0                 ['bash', 'gcp', 'data', 'linux', 'nodejs', 'aws', 'python']
# 1                                                    ['agile', 'sql', 'data']
# 2                                        ['linux', 'analysis', 'data', 'aws']
# 3  ['aws', 'analysis', 'optimization', 'devops', 'thinking', 'documentation']
# 4                                                                    ['rest']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          soft_skills
# 0                                                                                   ['cv', 'process', 'future', 'interested', 'aws', 'agree', 'gcp', 'deliver', 'necessary', 'suitable', 'ltd', 'responsible', 'provided', 'basic', 'xtremax', 'implementation', 'constant', 'http', 'pdpa', 'level', 'concept', 'nodejs', 'allow', 'detail', 'www', 'used', 'description', 'required', 'purpose', 'user', 'linux', 'implementing', 'consent', 'engineer', 'associate', 'ip', 'certified', 'current', 'azure', 'fast', 'monitor', 'solver', 'candidate', 'least', 'preferable', 'personal', 'providing', 'address', 'networking', 'learner', 'procedure', 'extra', 'powershell', 'provide', 'support', 'able', 'individual', 'dns', 'incident', 'resume', 'etc', 'professional', 'apply', 'google', 'accordance', 'python', 'privacy', 'thrive', 'inform', 'tcp', 'skill', 'pte', 'paced', 'communication', 'higher', 'bash', 'cloud', 'infrastructure', 'application', 'multi', 'behalf', 'understanding', 'confidential', 'microsoft', 'window', 'sysops', 'develop', 'service', 'com', 'welcome']
# 1  ['understand', 'map', 'portal', 'medical', 'best', 'web', 'server', 'modular', 'implement', 'desktop', 'developing', 'virtual', 'qualification', 'assignment', 'implementation', 'degree', 'vulnerability', 'bachelor', 'analytical', 'timeline', 'agile', 'recommendation', 'sql', 'identify', 'implementing', 'hybrid', 'passionate', 'deployment', 'dynamic', 'azure', 'inclusive', 'least', 'task', 'mrt', 'initiative', 'project', 'optimal', 'potential', 'existing', 'interact', 'diploma', 'solution', 'ecosystem', 'perspective', 'provide', 'support', 'participate', 'able', 'individual', 'flexible', 'please', 'improving', 'resume', 'team', 'collaborative', 'major', 'accordance', 'tight', 'handle', 'working', 'website', 'efficient', 'benefit', 'design', 'evaluate', 'equivalent', 'multiple', 'url', 'facing', 'wellness', 'cloud', 'infrastructure', 'storage', 'application', 'multi', 'important', 'competitive', 'architecture', 'troubleshooting', 'science', 'comfortable', 'need', 'window', 'preferred', 'maintain', 'familiar', 'promote', 'service', 'deploying']
# 2                                                                                                                                                                                                                                                                                                            ['cv', 'drop', 'purpose', 'reliable', 'sla', 'com', 'click', 'design', 'free', 'license', 'linux', 'support', 'stable', 'aws', 'interested', 'singapore', 'overseas', 'consent', 'applicant', 'overlay', 'thank', 'location', 'renewable', 'please', 'local', 'vitae', 'stipulated', 'deliver', 'full', 'cloud', 'infrastructure', 'wish', 'ltd', 'resume', 'suitability', 'exceed', 'prospective', 'perform', 'contact', 'send', 'know', 'apply', 'bedok', 'azure', 'underlay', 'analysis', 'reg', 'wen', 'png', 'employer', 'advisory', 'sg', 'daily', 'implementation', 'ea', 'privacy', 'available', 'personal', 'xuan', 'maintenance', 'meet', 'monitoring', 'covid', 'sdn', 'service', 'withdraw', 'networking', 'email', 'deemed', 'pte', 'prem', 'www', 'efficient', 'defined']
# 3                                                                                                                                                                                   ['demonstrated', 'solution', 'required', 'control', 'university', 'digital', 'container', 'scalable', 'devops', 'design', 'code', 'architect', 'provide', 'support', 'transformational', 'evaluate', 'participate', 'aws', 'deadline', 'communication', 'tool', 'wide', 'operational', 'various', 'manage', 'implement', 'rd', 'prepare', 'deployment', 'troubleshoot', 'infrastructure', 'cloud', 'multi', 'documentation', 'professional', 'verbal', 'excellent', 'critical', 'presentation', 'serverless', 'analysis', 'involve', 'oriented', 'collaborate', 'team', 'minimum', 'posse', 'friendly', 'act', 'configure', 'secure', 'degree', 'build', 'level', 'available', 'functional', 'maintain', 'ansible', 'analytical', 'automation', 'familiar', 'optimization', 'eg', 'meet', 'focus', 'monitoring', 'project', 'service', 'relevant', 'tech', 'savvy', 'influencing', 'drive', 'define', 'defined']
# 4                                                                                                                                                                            ['future', 'server', 'manage', 'deliver', 'assigned', 'willingness', 'satisfaction', 'implementation', 'innovative', 'degree', 'roaster', 'rest', 'help', 'kindly', 'concept', 'range', 'required', 'license', 'hybrid', 'deployment', 'azure', 'depth', 'reg', 'duty', 'leverage', 'candidate', 'sg', 'task', 'meet', 'backup', 'project', 'existing', 'diploma', 'solution', 'jason', 'provide', 'support', 'deadline', 'wide', 'many', 'please', 'consultative', 'resume', 'requirement', 'core', 'apply', 'team', 'accordance', 'vmware', 'standby', 'technical', 'direct', 'stakeholder', 'enhance', 'sop', 'guidance', 'overall', 'focused', 'design', 'cv_jasonwong', 'updated', 'infrastructure', 'cloud', 'coordinate', 'storage', 'application', 'multi', 'wong', 'quality', 'understanding', 'troubleshooting', 'science', 'microsoft', 'ea', 'preferred', 'maintenance', 'email', 'service', 'seng', 'com']

# %%
df['technical_skills'] = df['technical_skills'].apply(eval)
df['soft_skills'] = df['soft_skills'].apply(eval)

# %%
with open("testing.csv", "w") as f:
    for index, row in df.iterrows():
        print("*******",row['clean_job_title'],"******")
        for i in row['technical_skills']:
            print(i, end=", ")
            f.write(row['keyword']+","+i+"\n")
        print()
        print("#"*25)
# Out:
# ******* Cloud Engineer ******
# bash, gcp, data, linux, nodejs, aws, python,
# #########################
# ******* Cloud Engineer ******
# agile, sql, data,
# #########################
# ******* Cloud Engineer Bedok Months Contract ******
# linux, analysis, data, aws,
# #########################
# ******* Lead Cloud Engineer ******
# aws, analysis, optimization, devops, thinking, documentation,
# #########################
# ******* Cloud System Engineer ******
# rest,
# #########################
# ******* System Engineer ******
# documentation, analysis, data, aws,
# #########################
# ******* Devops Engineer ******
# jenkins, aws,
# #########################
# ******* Systems Engineer ******
# bash, optimization, linux,
# #########################
# ******* Cloud Engineer Year Renewable Contract Bedok Up To ******
# linux, analysis, data, aws,
# #########################
# ******* Cloud Devops Engineer ******
# github, devops, gcp, aws,
# #########################
# ******* Lead Cloud Engineer ******
# aws,
# #########################
# ******* Cloud Data Engineer Analyst ******
# spark, python, tableau, devops, modeling, docker, data, api, hadoop, bi, sql, microservices,
# #########################
# ******* Cloud Engineer ******
# rest, lambda, jenkins, java, github, optimization, json, devops, docker, api, numpy, aws, postgresql, python, scala,
# #########################
# ******* Cloud Network Engineer Physical Network Infrastructure ******
# optimization, linux, data,
# #########################
# ******* Cloud Engineer ******
# git, jenkins, analysis, script, gcp, aws, documentation, microservices,
# #########################
# ******* Cloud Network Engineer Physical Network Infrastructure ******
# optimization, linux, data,
# #########################
# ******* Cloud Infrastructure System Engineer ******
# documentation, linux, thinking,
# #########################
# ******* Cloud Security Engineer ******
# rest, analysis, database, modeling, data, linux, aws,
# #########################
# ******* Cloud Engineer ******
# gcp, aws,
# #########################
# ******* Microsoft Azure Cloud Security Engineer ******
# analysis, data, hadoop, consulting, sql, aws, python, mobile,
# #########################
# ******* Cloud Security Engineer ******
# data, aws,
# #########################
# ******* Cloud Specialist Engineer ******
# consulting, devops, data,
# #########################
# ******* Senior Cybersecurity Engineer ******
#
# #########################
# ******* Senior Cloud Engineer Group Consumer Banking And Big Data ******
# script, data, linux, javascript, python,
# #########################
# ******* Desktop Wintel Linux Cloud Cyber Security Engineer ******
# database, script, data, linux, aws, apache,
# #########################
# ******* Public Cloud Solution Engineer Technology And Operations ******
# node, analysis, java, optimization, agile, gcp, linux, aws, python, customer service,
# #########################
# ******* Avp Senior Associate Pcf Cloud Operations Engineer ******
# jenkins, java, splunk, spring, agile, devops, gcp, data, linux, aws, python, customer service,
# #########################
# ******* Cloud Platform Devops Engineer ******
# optimization, gcp, linux, aws, python,
# #########################
# ******* Senior Software Engineer ******
# rest, ruby, html, django, java, python, database, json, mysql, data, api, hadoop, sql, aws, ai, mongodb, php, apache, web development,
# #########################
# ******* Vp Public Cloud Solution Engineer Technology And Operations ******
# node, analysis, java, optimization, agile, gcp, linux, python, customer service,
# #########################
# ******* Senior Cloud Engineer Group Consumer Banking And Big Data ******
# script, data, linux, javascript, python,
# #########################
# ******* Cloud Engineer ******
# net, mysql, data, linux, aws, customer service,
# #########################
# ******* Vp Public Cloud Solution Engineer Technology And Operations ******
# node, analysis, java, optimization, agile, gcp, linux, python, customer service,
# #########################
# ******* Cloud Specialist Up To Yearly Contract ******
# analysis, data, aws,
# #########################
# ******* Cloud Security Engineer ******
# rest, analysis, database, modeling, data, linux, aws,
# #########################
# ******* Avp Senior Associate Devops Engineer Virtual Private Cloud ******
# linux, microservices, docker, python,
# #########################
# ******* Svp Public Cloud Software Engineer Technical Lead ******
# react, vue, aws, node, java, javascript, lambda, json, docker, api, python, git, rest, spring, agile, angular, mvc, sql, mongodb, microservices, web development,
# #########################
# ******* Svp Public Cloud Software Engineer Technical Lead Technology ******
# react, vue, aws, node, java, javascript, lambda, json, docker, api, python, git, rest, spring, agile, angular, mvc, sql, mongodb, microservices, web development,
# #########################
# ******* Aws Cloud Engineer ******
# script, analysis, docker, aws,
# #########################
# ******* Cloud Operations Lead ******
# ai, linux, jira, aws,
# #########################
# ******* Senior Systems Engineer ******
# git, ruby, java, python, jira, bash, devops, docker, linux, aws, documentation, php, apache,
# #########################
# ******* Avp Senior Associate Network Security Engineer Cloud Engineering ******
# documentation, analysis,
# #########################
# ******* Vp Public Cloud Solution Engineer Group Technology Operations ******
# devops, react, vue, aws, node, java, javascript, lambda, jenkins, json, docker, api, python, git, rest, spring, agile, angular, mvc, sql, mongodb, microservices, web development,
# #########################
# ******* It Consultant ******
# aws,
# #########################
# ******* Devops Engineer ******
# jenkins, github, devops, docker, api, linux, aws,
# #########################
# ******* Svp Public Cloud Software Engineer Technical Lead Technology ******
# react, vue, aws, node, java, javascript, lambda, json, docker, api, python, git, rest, spring, agile, angular, mvc, sql, mongodb, microservices, web development,
# #########################
# ******* Svp Public Cloud Software Engineer Technical Lead ******
# react, vue, aws, node, java, javascript, lambda, json, docker, api, python, git, rest, spring, agile, angular, mvc, sql, mongodb, microservices, web development,
# #########################
# ******* Cloud Infrastructure Engineer ******
# documentation, linux, thinking,
# #########################
# ******* Cloud Infrastructure Specialist Ikano Retail ******
# analysis,
# #########################
# ******* Cloud Technical Consultant ******
# java, docker, sql, aws, python,
# #########################
# ******* Cloud Engineer ******
# jira, bash, script, agile, docker, linux, sql, aws, mobile,
# #########################
# ******* Cloud Data Engineer ******
# rest, lambda, spark, django, python, database, tableau, devops, agile, docker, data, api, linux, aws, apache,
# #########################
# ******* System Engineer Cloud Server Linux Configurations Deployment ******
# documentation, linux, data, aws,
# #########################
# ******* Cloud Team Lead ******
# consulting, devops, data, aws,
# #########################
# ******* Senior System Infrastructure Engineer ******
# documentation, database, thinking, data,
# #########################
# ******* Cloud Analyst ******
# aws,
# #########################
# ******* Cloud Specialist Amazon Azure ******
# consulting, analysis, data, aws,
# #########################
# ******* Cloud Security Dev ******
# jenkins, devops, data, aws, python,
# #########################
# ******* Devops Engineer ******
# ubuntu, net, node, jenkins, database, nosql, docker, data, linux, nodejs, mongodb, microservices,
# #########################
# ******* Devops Engineer ******
# git, jenkins, jira, devops, docker, linux,
# #########################
# ******* Senior It Cloud Infra Engineer ******
# microservices, devops, aws,
# #########################
# ******* Cloud Engineer ******
# gcp, aws,
# #########################
# ******* Cloud Engineer 云端工程师 ******
# devops, gcp, docker, api, linux, aws, python,
# #########################
# ******* Cloud Devsecops Architect ******
# lambda, net, java, optimization, spring, devops, restful, data, api, aws, php,
# #########################
# ******* Cloud Infrastructure Engineer ******
# documentation, linux, thinking,
# #########################
# ******* Cloud Infrastructure Engineer ******
# documentation, linux, thinking,
# #########################
# ******* It Lead Worknow ******
# ubuntu, script, gcp, data, linux, bi, aws, power bi,
# #########################
# ******* Cloud Infra Engineer ******
# documentation, linux, data,
# #########################
# ******* Devops Engineer ******
# ubuntu, net, node, jenkins, database, nosql, docker, data, linux, nodejs, mongodb, microservices,
# #########################
# ******* Devops Team Lead ******
# jenkins, aws, bash, script, devops, docker, linux, thinking, python,
# #########################
# ******* Managed Services And Devops Solution Architect ******
# git, jenkins, database, devops, restful, docker, data, api, sql, aws, documentation, customer service,
# #########################
# ******* Cloud Operation Engineer ******
# analysis, script, gcp, aws, documentation, microservices,
# #########################
# ******* Cloud System Engineer ******
# aws, analysis, database, script, devops, linux, thinking, python,
# #########################
# ******* Devops Engineer ******
# jenkins, aws, jira, script, agile, docker, thinking, python,
# #########################
# ******* Cloud Specialist Months Contract ******
# analysis, data, aws,
# #########################
# ******* Senior Devops Engineer ******
# git, jenkins, net, java, bash, devops, aws, python,
# #########################
# ******* Aws Technical Trainer ******
# ruby, net, analysis, bash, devops, gcp, javascript, data, linux, aws, php, python,
# #########################
# ******* Junior Cloud Infrastructure Architect ******
# documentation, linux, thinking,
# #########################
# ******* Quality Engineer ******
# documentation,
# #########################
# ******* Devops Lead Engineer ******
# database, optimization, script, devops, sql, aws, documentation,
# #########################
# ******* Cloud Devops Engineer ******
# jenkins, analysis, script, devops, consulting, aws, documentation, python,
# #########################
# ******* Devops Engineer ******
# jenkins, devops, docker, aws, mongodb,
# #########################
# ******* Regional Cloud Steward ******
# optimization, analysis, aws,
# #########################
# ******* System Engineer ******
# python, bash, data, linux, nodejs, sql, aws, apache,
# #########################
# ******* Software Test Engineer ******
# optimization, analysis, sql, thinking,
# #########################
# ******* Devops Engineer ******
# kong, git, jenkins, analysis, java, jira, database, spring, devops, gcp, docker, api, linux, io, aws, android, python, mobile, spring boot,
# #########################
# ******* Junior Cloud Engineer ******
# python, bash, data, linux, nodejs, sql, aws, apache,
# #########################
# ******* Devops Engineer ******
# rest, jenkins, devops, aws, python,
# #########################
# ******* Lead Senior Cloud Devsecops Engineer ******
# devops, analysis, docker, aws,
# #########################
# ******* Kyndryl Apprenticeship ******
# analysis, java, script, devops, react, data, python,
# #########################
# ******* Avp Public Cloud Developer Technology Operations ******
# script, data, linux, javascript, python,
# #########################
# ******* Apac Data Analyst Engineer ******
# analysis, tableau, data, bi, sql, python,
# #########################
# ******* Vp Public Cloud Developer Technology Operations ******
# script, agile, data, linux, javascript, python,
# #########################
# ******* Senior Cloud Enablement Group Consumer Banking And Big Data ******
# lambda, jenkins, java, splunk, agile, devops, data, nodejs, aws, documentation, python,
# #########################
# ******* Senior Cloud Enablement Group Consumer Banking And Big Data ******
# lambda, jenkins, java, splunk, agile, devops, data, nodejs, aws, documentation, python,
# #########################
# ******* Cloud Ops Engineer ******
# jenkins, analysis, java, database, script, devops, linux, sql, aws, documentation, postgresql,
# #########################
# ******* Devops Engineer ******
# rest, jenkins, python, optimization, agile, devops, docker, api, linux, aws, microservices,
# #########################
# ******* Cloud Infrastructure System Engineer ******
# documentation, linux, thinking,
# #########################
# ******* Solution Engineer ******
# linux, analysis, data, aws,
# #########################
# ******* Senior System Engineer ******
# documentation, optimization,
# #########################
# ******* Junior Dev Ops Engineer Immediate ******
# linux, script, devops, database,
# #########################
# ******* Devops Engineer ******
# jenkins, aws, bash, devops, linux, thinking, documentation,
# #########################
# ******* Devops Engineer ******
# analysis, python, optimization, devops, docker, data, linux, apache,
# #########################
# ******* Linux Administrator ******
# analysis, script, linux, aws, python,
# #########################
# ******* Senior Cloud Enablement Group Consumer Banking And Big Data ******
# lambda, jenkins, java, splunk, agile, devops, data, nodejs, aws, documentation, python,
# #########################
# ******* Senior Research Engineer ******
# documentation, modeling, analysis, data,
# #########################
# ******* Devops Engineer ******
# node, database, nosql, script, devops, mysql, docker, linux, aws, documentation, mongodb, postgresql, python,
# #########################
# ******* Senior Associate Devops Engineer ******
# python, docker, linux, ai, microservices,
# #########################
# ******* Lead Senior Cloud Software Engineer ******
# devops,
# #########################
# ******* Cloud Architect ******
# docker, data, consulting, sql, ai,
# #########################
# ******* It Engineer ******
# analysis, docker, aws,
# #########################
# ******* Devops Engineer ******
# jenkins, jira, database, devops, docker, data, sql, io, android, python, mobile,
# #########################
# ******* Cloud Technical Architect ******
# jira, bash, agile, mysql, docker, data, api, aws, documentation, python,
# #########################
# ******* Infrastructure Engineer Infrastructure And Application Monitoring ******
# ruby, analysis, restful, data, api, thinking, python,
# #########################
# ******* It Engineer Cloud Server Linux Configurations Deployment ******
# documentation, linux, data, aws,
# #########################
# ******* Cloud Engineer ******
# sql, data,
# #########################
# ******* Cloud Site Reliability Engineer Salesforce ******
# jenkins, analysis, java, bootstrap, gcp, docker, linux, swift, aws, salesforce, python,
# #########################
# ******* Technical Support Engineer Video Cloud ******
# optimization, thinking, data,
# #########################
# ******* It Technical Architect Cloud Infrastructure Lead ******
# ubuntu, script, gcp, data, linux, bi, aws, power bi,
# #########################
# ******* Security Engineer ******
# git, jenkins, aws, java, devops, docker, linux, javascript, python,
# #########################
# ******* Service Cloud Solution Engineer Salesforce ******
# html, java, database, sql, salesforce, erp,
# #########################
# ******* Service Cloud Solution Engineer Salesforce ******
# html, java, database, sql, salesforce, erp,
# #########################
# ******* Service Cloud Solution Engineer Worknow ******
# html, java, database, sql, salesforce, erp,
# #########################
# ******* Senior Research Engineer ******
# documentation, modeling, analysis, data,
# #########################
# ******* Service Cloud Solution Engineer Urgent ******
# html, java, database, sql, salesforce, erp,
# #########################
# ******* Senior Devops Engineer ******
# rest, node, nosql, gcp, javascript, docker, data, react, sql, aws, python, mobile,
# #########################
# ******* Service Cloud Solution Engineer Salesforce Urgent ******
# html, java, database, sql, salesforce, erp,
# #########################
# ******* Big Data Technical Architecture Delivery Team Lead ******
# api, agile, database,
# #########################
# ******* Cloud Software Engineer Contract ******
# devops,
# #########################
# ******* Cloud Site Reliability Engineer Worknow ******
# jenkins, analysis, java, bootstrap, gcp, docker, linux, swift, aws, salesforce, python,
# #########################
# ******* Senior System Engineer ******
# documentation, analysis, data, aws,
# #########################
# ******* Cloud Devops Engineer Data Quality Vice President ******
# spark, java, python, optimization, docker, data, sql, aws, apache,
# #########################
# ******* Service Cloud Solution Engineer Worknow ******
# html, java, database, sql, salesforce, erp,
# #########################
# ******* Devops Engineer ******
# jenkins, java, jira, github, devops, data, nodejs, python,
# #########################
# ******* Cloud Infrastructure Architect ******
# documentation, linux, thinking,
# #########################
# ******* Service Cloud Solution Engineer Urgent ******
# html, java, database, sql, salesforce, erp,
# #########################
# ******* Site Reliability Engineer Associate Lead Public Cloud Ai Machine Learning Big Data Servicenow Blockchain ******
# git, rest, ubuntu, jenkins, analysis, java, splunk, json, devops, gcp, agile, data, documentation, aws, ai, python,
# #########################
# ******* Platform Linux Engineer ******
# rest, ruby, optimization, bash, linux, python,
# #########################
# ******* Site Reliability Engineer Cloud Vice President Worknow ******
# git, rest, ubuntu, aws, jenkins, java, splunk, optimization, json, gcp, agile, data, thinking, python,
# #########################
# ******* Devops Engineer Sre ******
# java, devops, javascript, data, linux, typescript, thinking, ai, mongodb, python, kotlin,
# #########################
# ******* Cloud System Engineer ******
# rest, analysis, devops, data, linux,
# #########################
# ******* System Infra Engineer ******
# bash, linux, consulting, aws,
# #########################
# ******* Manager Infocomm Infrastructure ******
# analysis, docker, aws,
# #########################
# ******* Support And Reliability Engineer ******
# linux, devops,
# #########################
# ******* Devops Engineer ******
# net, aws, analysis, bash, agile, devops, docker, react, linux, thinking, documentation, python,
# #########################
# ******* Lead Devops Engineer ******
# git, rest, ruby, ubuntu, net, jenkins, jira, splunk, optimization, bash, devops, linux, aws, documentation, python,
# #########################
# ******* Lead Devops Engineer ******
# jenkins, github, bash, devops, gcp, docker, data, aws, microservices,
# #########################
# ******* Manager Infocomm Infrastructure ******
# analysis, docker, aws,
# #########################
# ******* Infrastructure Engineer ******
# analysis, data, linux, aws, documentation,
# #########################
# ******* Devops Engineer ******
# rest, lambda, java, agile, devops, docker, restful, api, linux,
# #########################
# ******* Vmware Engineer ******
# jenkins, aws, splunk, github, devops, gcp, javascript, docker, linux, sql, thinking, python,
# #########################
# ******* Senior Devops Engineer ******
# git, rest, ubuntu, jenkins, jira, splunk, optimization, devops, docker, linux, documentation,
# #########################
# ******* System Engineer ******
# optimization, docker, data, linux, aws, documentation,
# #########################
# ******* Lead Devops Engineer ******
# git, ruby, ubuntu, net, jira, splunk, optimization, bash, devops, docker, linux, aws, documentation, python,
# #########################
# ******* Senior Devops Engineer ******
# git, rest, ubuntu, jenkins, jira, splunk, optimization, devops, docker, linux, aws, documentation,
# #########################
# ******* Cloud Software Engineer Principal Engineer ******
# database,
# #########################
# ******* Senior Engineer Core Operations ******
# documentation, linux, script,
# #########################
# ******* Cloud Architect ******
# aws,
# #########################
# ******* Cloud ******
# data, linux, aws, documentation, microservices,
# #########################
# ******* Senior Software Engineer ******
# git, lambda, node, jenkins, java, database, devops, agile, autodesk, data, docker, api, linux, aws, python,
# #########################
# ******* Database Hybrid Cloud Engineer ******
# analysis, database, data, linux, sql, aws, customer service,
# #########################
# ******* Infrastructure Architect ******
# splunk, java, bash, docker, data, consulting, python,
# #########################
# ******* Systems Hybrid Cloud Engineer ******
# linux, analysis, aws, customer service,
# #########################
# ******* System Engineer ******
# documentation, optimization,
# #########################
# ******* Devops Engineer Urgent ******
# devops, data, aws,
# #########################
# ******* Devops Engineer ******
# ruby, ubuntu, jenkins, jira, bash, script, devops, docker, aws, documentation, python,
# #########################
# ******* Systems Engineer Engineering ******
# linux, analysis, database, customer service,
# #########################
# ******* Senior Manager Hosting Platform ******
# optimization, docker, data,
# #########################
# ******* It Infrastructure Engineer ******
# database, sql, aws,
# #########################
# ******* Senior Software Engineer ******
# git, lambda, node, jenkins, java, database, devops, agile, autodesk, data, docker, api, linux, aws, python,
# #########################
# ******* Cloud Data Engineer ******
# database, gcp, data, bi, sql, aws, python,
# #########################
# ******* Manager Devops Lead ******
# net, java, bash, agile, devops, gcp, data, docker, nodejs, python,
# #########################
# ******* Lead Senior Cloud Infrastructure Engineer ******
# data, aws,
# #########################
# ******* Devops Engineer Job ******
# ruby, ubuntu, net, jenkins, python, splunk, optimization, bash, devops, restful, docker, data, hadoop, linux, aws, microservices,
# #########################
# ******* Solution Architect ******
# optimization, analysis, mobile, aws,
# #########################
# ******* Senior Devops Engineer ******
# git, ruby, ubuntu, net, jenkins, jira, splunk, optimization, bash, devops, docker, data, linux, aws, documentation, python,
# #########################
# ******* Devops Engineer ******
# react, data, aws, microservices, mobile,
# #########################
# ******* System Engineer Rc ******
# linux, aws,
# #########################
# ******* System Administrator ******
# thinking,
# #########################
# ******* Cloud Architect ******
# aws,
# #########################
# ******* It Infrastructure Engineer ******
#
# #########################
# ******* Cloud Specialist ******
# consulting, data, aws,
# #########################
# ******* System Engineer ******
# linux, thinking, aws,
# #########################
# ******* Big Data Technical Architecture Delivery Manager ******
# data,
# #########################
# ******* Senior Engineer ******
# rest, linux,
# #########################
# ******* Aws Solutions Architect ******
# agile, devops, docker, aws,
# #########################
# ******* Avp Senior Associate Cloud Developer Ces Public ******
# ruby, analysis, java, agile, linux, aws, python,
# #########################
# ******* Site Reliability Engineer Infrastructure Engineering ******
# java, optimization, data, hadoop, linux, aws, python,
# #########################
# ******* System Engineer ******
# consulting,
# #########################
# ******* Infrastructure Engineer ******
# linux, data,
# #########################
# ******* Brand Technical Specialist Cloud Platform ******
# api, database, microservices, thinking,
# #########################
# ******* Cloud Communication Solution Byteplus ******
# customer service,
# #########################
# ******* Senior Executive Cloud Contact Centre ******
# java, json, sql, javascript, documentation, python,
# #########################
# ******* Senior Devops Engineer ******
# git, rest, ubuntu, jenkins, jira, splunk, optimization, devops, docker, linux, aws, documentation,
# #########################
# ******* Site Reliability Engineer Recommendation Architecture ******
# analysis, optimization, devops, linux, python, mobile,
# #########################
# ******* System Engineer ******
# database, devops, data, sql, aws, ai,
# #########################
# ******* Cloud Infrastructure Engineer ******
# net, analysis, database, agile, devops, docker, data, consulting, aws, documentation,
# #########################
# ******* System Specialist ******
# script, devops, docker, python,
# #########################
# ******* Aws Cloud It Operations Manager ******
# database, aws,
# #########################
# ******* Deputy Director Assistant Director Automation Engineering ******
# git, jenkins, jira, database, agile, docker, react, sql, javascript, python,
# #########################
# ******* Infrastructure Engineer Year Renewable Contract Changi Up To ******
# docker, data, linux, aws, apache,
# #########################
# ******* Associate Public Cloud Engineer Cloud Engineering Services ******
# analysis, java, data, linux, aws, python,
# #########################
# ******* Devops Engineer ******
# database, devops, docker, data,
# #########################
# ******* Senior Devops Engineer ******
# python, analysis, docker,
# #########################
# ******* Avp Senior Cloud Engineer Data Technology Technology Operations ******
# rest, jenkins, analysis, optimization, json, agile, javascript, linux, aws, documentation, python, customer service,
# #########################
# ******* Devops Engineer ******
# jenkins, splunk, database, github, devops, mysql, data, linux, aws, documentation,
# #########################
# ******* Vp Senior Cloud Engineer Data Technology Technology Operations ******
# rest, jenkins, analysis, optimization, json, agile, javascript, linux, aws, documentation, python, customer service,
# #########################
# ******* Aws Soc Support Engineer ******
# ruby, html, analysis, data, linux, sql, aws,
# #########################
# ******* Cloud Solution Architect ******
# net, analysis, java, devops, api, consulting, aws, documentation, microservices,
# #########################
# ******* System Admin Devops Engineer ******
# database, github, devops, docker, data, linux, microservices,
# #########################
# ******* Communications Testbed Engineer ******
# linux, python, java,
# #########################
# ******* Infra Engineer Jh ******
# documentation,
# #########################
# ******* Infrastructure Engineer Log Management ******
# linux, splunk,
# #########################
# ******* Avp Senior Associate Cloud Developer Ces Public ******
# ruby, analysis, java, agile, linux, aws, python,
# #########################
# ******* Devops Engineer ******
# django, devops, javascript, react, typescript, aws, python,
# #########################
# ******* Systems Engineer ******
# analysis, python, optimization, docker, data, linux, aws, apache,
# #########################
# ******* Service Cloud Solution Engineer Urgent ******
# html, java, database, sql, salesforce, erp,
# #########################
# ******* Cloud Security Specialist ******
# microservices, data, aws,
# #########################
# ******* Devops Engineer ******
# analysis, java, python, optimization, mysql, docker, data, blockchain, sql, mongodb, apache,
# #########################
# ******* Senior Cloud Engineer Group Consumer Banking Big Data ******
# script, data, linux, javascript, python,
# #########################
# ******* Cloud Architect ******
# linux, analysis, data, aws,
# #########################
# ******* Cloud Infrastructure Developer Associate ******
# rest, lambda, jenkins, analysis, github, json, devops, docker, api, aws, documentation, postgresql,
# #########################
# ******* Public Cloud Solution Engineer Technology And Operations ******
# node, analysis, java, optimization, agile, gcp, linux, aws, python, customer service,
# #########################
# ******* Devops Engineer ******
# database, devops, gcp, data, aws,
# #########################
# ******* Devsecops Engineer ******
# analysis, devops, docker, data, ai, python,
# #########################
# ******* Senior Systems Engineer ******
# script, data, consulting, sql, javascript, python,
# #########################
# ******* Network Engineer ******
# documentation, optimization, ubuntu, data,
# #########################
# ******* Solution Architect ******
# linux, analysis, data, aws,
# #########################
# ******* Solution Architect ******
# linux, analysis, data, aws,
# #########################
# ******* Senior Associate Cloud Engineer Data Technology Technology Operations ******
# rest, jenkins, analysis, optimization, json, agile, javascript, data, linux, aws, documentation, python, customer service,
# #########################
# ******* Infrastructure Cloud Administrator ******
# analysis, sql, data,
# #########################
# ******* Infrastructure Architect ******
# splunk, java, bash, docker, python,
# #########################
# ******* Cloud Engineer ******
# aws, devops, gcp, thinking, ai,
# #########################
# ******* Cloud Engineer ******
# aws, devops, gcp, thinking, ai,
# #########################
# ******* Backup Storage Engineer Up To Months Contract Somerset ******
# data,
# #########################
# ******* Service Enablement And Provisioning Manager ******
# git, java, jira, script, agile, devops, linux, aws,
# #########################
# ******* Devops Engineer Python Java ******
# git, jenkins, net, java, bash, devops, aws, python,
# #########################
# ******* Senior Cloud Engineer ******
# analysis, database, json, devops, linux, python,
# #########################
# ******* Devops Engineer ******
# jenkins, analysis, java, data, linux, apache,
# #########################
# ******* Devops Engineer ******
# rest, jenkins, devops, aws, python,
# #########################
# ******* Senior Devops Engineer ******
# spark, optimization, data, hadoop, linux, python,
# #########################
# ******* Presales Cloud Consultant Up To Cbd ******
# aws,
# #########################
# ******* Aws Cloud Developer ******
# api, python, react,
# #########################
# ******* Vp Cloud Architect Group Infrastructure Platform Services ******
# devops, gcp, aws,
# #########################
# ******* Cloud Engineer ******
# aws,
# #########################
# ******* Cloud Data Centre Engineer ******
# script, data, linux, ai, python,
# #########################
# ******* Cloud Infrastructure Engineer ******
# aws, devops, gcp, thinking, ai,
# #########################
# ******* Deputy Assistant Director Security Tools Platform ******
#
# #########################
# ******* Senior Assoc Infrastructure Cloud Devops Engineer ******
# analysis, devops, gcp, aws, documentation, python,
# #########################
# ******* Infrastructure Engineer ******
# analysis, aws,
# #########################
# ******* Senior Associate Associate System Monitoring Engineer Tech ******
# html, script, docker, linux, python, web development,
# #########################
# ******* Cloud Solutions Architect ******
# spark, java, database, nosql, devops, data, hadoop, consulting, sql, aws, ai, python, scala,
# #########################
# ******* Vp Group Technology Operations Public Cloud Solution Engineer ******
# devops, react, vue, aws, node, java, javascript, lambda, jenkins, json, docker, api, python, git, rest, spring, agile, angular, mvc, sql, mongodb, microservices, web development,
# #########################
# ******* Backup Storage Engineer Somerset Months Contract ******
# data,
# #########################
# ******* Network Engineer ******
# agile,
# #########################
# ******* Solution Manager Hybrid Cloud Sap ******
# documentation, consulting, analysis, aws,
# #########################
# ******* Junior System Engineer ******
# data, linux, sql, aws, documentation, python,
# #########################
# ******* Chief Technology Officer ******
# devops, thinking,
# #########################
# ******* Avp Sr Associate Sre Devops Lead Investment Trading ******
# jenkins, analysis, jira, splunk, agile, mysql, devops, react, docker, sql,
# #########################
# ******* Senior Software Engineer Job ******
# rest, net, java, python, devops, gcp, agile, data, apache, mysql, javascript, docker, typescript, aws, rabbitmq, postgresql, microservices,
# #########################
# ******* Site Reliability Engineer Cloud Vice President Worknow ******
# git, rest, ubuntu, aws, jenkins, java, splunk, optimization, json, gcp, agile, data, thinking, python,
# #########################
# ******* It Executive System Analyst ******
# analysis, sql, aws,
# #########################
# ******* Sap Cloud Solution Architect Manager ******
# analysis, database, docker, aws, documentation, mongodb, postgresql,
# #########################
# ******* Cloud Native Senior Software Engineer Development Lead ******
# rest, java, jira, database, spring, agile, devops, mysql, vue, microservices, mobile,
# #########################
# ******* Presales Solution Consultant ******
# analysis,
# #########################
# ******* Linux Engineer Devops Infrastructure Support Vp ******
# aws, analysis, java, data, linux, thinking, python,
# #########################
# ******* Avp Senior Associate Devops Engineer Virtual Private Cloud ******
# linux, microservices, docker, python,
# #########################
# ******* It Technical Architect Cloud Infrastructure Worknow ******
# ubuntu, script, gcp, data, linux, bi, aws, power bi,
# #########################
# ******* Devops Engineer ******
# django, script, devops, docker, react, linux, python,
# #########################
# ******* Deployment Engineer ******
# git, jenkins, analysis, java, script, devops, linux, sql, io, android, python, mobile,
# #########################
# ******* Cloud Site Reliability Engineer Worknow ******
# jenkins, analysis, java, bootstrap, gcp, docker, linux, swift, aws, salesforce, python,
# #########################
# ******* Senior System Engineer Central ******
# linux, express, database,
# #########################
# ******* Regional It Engineer ******
# rest,
# #########################
# ******* Junior Devops Engineer Entry Level Urgent ******
# linux, database, devops, aws,
# #########################
# ******* Aws Cloud Developer ******
# lambda, database, react, data, api, aws, python,
# #########################
# ******* Cloud Engineer ******
# aws, devops, gcp, thinking, ai,
# #########################
# ******* Cloud Site Reliability Engineer Salesforce ******
# jenkins, analysis, java, bootstrap, gcp, docker, linux, swift, aws, salesforce, python,
# #########################
# ******* Cloud Devops Engineer Data Quality Vice President ******
# spark, java, python, optimization, docker, data, sql, aws, apache,
# #########################
# ******* Systems Consultant ******
# database, devops, data, linux, aws,
# #########################
# ******* Devops Consultant ******
# python, consulting, devops, javascript,
# #########################
# ******* Cloud Infrastruture Engineers ******
# devops, aws,
# #########################
# ******* Service Cloud Solution Engineer Salesforce ******
# html, java, database, sql, salesforce, erp,
# #########################
# ******* Senior Cloud Security Engineer ******
# mobile, data,
# #########################
# ******* It Engineer Cloud Server Linux Configurations Deployment ******
# documentation, linux, data, aws,
# #########################
# ******* Cloud Architect ******
# lambda, aws, optimization, devops, docker, consulting, thinking,
# #########################
# ******* Service Cloud Solution Engineer Urgent ******
# html, java, database, sql, salesforce, erp,
# #########################
# ******* Cloud Security Analyst ******
# splunk, linux, data, aws,
# #########################
# ******* Solutions Architect ******
# database, agile, devops, consulting, aws,
# #########################
# ******* Cloud Engineer ******
# aws, java, agile, nodejs, typescript, thinking, python,
# #########################
# ******* Cloud Engineer ******
# database, gcp, aws,
# #########################
# ******* Lead Network Engineer Worknow ******
# express, script, devops, gcp, data, linux, aws, documentation, salesforce, python,
# #########################
# ******* Security Infra Cloud System Engineer ******
# documentation, linux, splunk, data,
# #########################
# ******* Avp Senior Associate Infra Cloud Engineer ******
# git, rest, jenkins, analysis, optimization, json, agile, linux, aws, documentation, customer service,
# #########################
# ******* Avp Senior Associate Infra Cloud Engineer ******
# git, rest, jenkins, analysis, optimization, json, agile, linux, aws, documentation, customer service,
# #########################
# ******* Avp Senior Associate Infra Cloud Engineer ******
# git, rest, jenkins, analysis, optimization, json, agile, linux, aws, documentation, customer service,
# #########################
# ******* Avp Senior Associate Infra Cloud Engineer Urgent ******
# git, rest, jenkins, analysis, optimization, json, agile, linux, aws, documentation, customer service,
# #########################
# ******* Cloud Devsecops Architect ******
# lambda, net, java, optimization, spring, devops, restful, data, api, aws, php,
# #########################
# ******* Devops Engineer ******
# database, java, devops, linux, python,
# #########################
# ******* Service Cloud Solution Engineer Salesforce Urgent ******
# html, java, database, sql, salesforce, erp,
# #########################
# ******* Cloud Engineer ******
# aws, devops, gcp, thinking, ai,
# #########################
# ******* Principal Senior Devops Engineer ******
# database, bash, nosql, agile, devops, autodesk, data, docker, linux, sql, aws, python,
# #########################
# ******* Associate Analyst Cloud Devops Engineer ******
# analysis, devops, gcp, aws, documentation, python,
# #########################
# ******* System Engineer ******
# consulting, analysis, data, aws,
# #########################
# ******* Research Engineer Mobile Systems Cloud Security Nsoe ******
# java,
# #########################
# ******* Azure Cloud Specialist ******
# json, script, analysis, data,
# #########################
# ******* Lead Devops Engineer ******
# git, ruby, ubuntu, net, jenkins, jira, splunk, optimization, bash, devops, docker, linux, aws, documentation, python,
# #########################
# ******* Business System Analyst Web Application Exp ******
# analysis, sql, aws,
# #########################
# ******* Cloud Application Support Engineer ******
# aws, splunk, optimization, data, thinking,
# #########################
# ******* Senior Principal Engineer ******
# jenkins, jira, devops, linux, aws, ai, python,
# #########################
# ******* Network Performance Engineer ******
# documentation, jenkins, analysis, aws,
# #########################
# ******* Principal Senior Devops Engineer ******
# database, bash, nosql, agile, devops, autodesk, data, docker, linux, sql, aws, python,
# #########################
# ******* Research Engineer Mobile Systems Cloud Security Nsoe ******
# mobile, java,
# #########################
# ******* Cybersecurity Engineer ******
# kong, rest, database, aws,
# #########################
# ******* Service Cloud Solution Engineer Worknow ******
# html, java, database, sql, salesforce, erp,
# #########################
# ******* Associate Public Cloud Sre Specialist Cloud Engineering ******
# git, rest, java, script, json, javascript, linux, aws, python,
# #########################
# ******* Service Cloud Solution Engineer Salesforce ******
# html, java, database, sql, salesforce, erp,
# #########################
# ******* Avp Senior Associate Cloud Infrastructure Engineer ******
# git, rest, ruby, html, django, java, python, database, json, devops, docker, linux, sql, javascript, springboot, php, apache, web development,
# #########################
# ******* Service Cloud Solution Engineer Worknow ******
# html, java, database, sql, salesforce, erp,
# #########################
# ******* Senior Specialist Engineer Service Operations ******
# documentation, analysis, customer service,
# #########################
# ******* Infrastructure And Devops Engineer ******
# git, jenkins, analysis, java, python, jira, database, mysql, devops, angular, javascript, linux, aws, apache,
# #########################
# ******* Public Cloud Solution Engineer Technology And Operations ******
# node, analysis, java, optimization, agile, gcp, linux, aws, python, customer service,
# #########################
# ******* Senior Devops Engineer ******
# jenkins, jira, devops, docker, thinking, microservices, mobile,
# #########################
# ******* Avp Senior Associate Pcf Cloud Operations Engineer ******
# jenkins, java, splunk, spring, agile, devops, gcp, data, linux, aws, python, customer service,
# #########################
# ******* Cloud Devops Engineer ******
# splunk, agile, devops, gcp, data, mysql, javascript, docker, typescript, aws, documentation, python, kotlin,
# #########################
# ******* Vp Public Cloud Solution Engineer Technology And Operations ******
# node, analysis, java, optimization, agile, gcp, linux, python, customer service,
# #########################
# ******* Systems Engineer ******
# documentation,
# #########################
# ******* Vp Public Cloud Solution Engineer Technology And Operations ******
# node, analysis, java, optimization, agile, gcp, linux, python, customer service,
# #########################
# ******* It Staff Urgent ******
# ruby, net, html, java, database, linux, sql, javascript, web development,
# #########################
# ******* Cloud Specialist West ******
# aws,
# #########################
# ******* Cloud Software Engineer Principal Engineer ******
# database,
# #########################
# ******* Devsecops ******
# git, jenkins, analysis, java, python, jira, database, mysql, devops, angular, javascript, linux, aws, apache,
# #########################
# ******* Devops Engineer Vice President Urgent Immediate ******
# analysis, java, devops, docker, data, linux, python,
# #########################
# ******* It Enterprise Architect ******
# jenkins, jira, github, agile, devops, docker, microservices,
# #########################
# ******* Senior Associate Infrastructure Cloud Devops Engineer ******
# analysis, devops, gcp, aws, documentation, python,
# #########################
# ******* Senior Associate Infrastructure Cloud Devops Engineer ******
# analysis, devops, gcp, aws, documentation, python,
# #########################
# ******* Avp Senior Associate Infra Cloud Middleware Engineer ******
# git, jenkins, analysis, agile, linux, aws, apache,
# #########################
# ******* Avp Senior Associate Infra Cloud Middleware Engineer ******
# git, jenkins, analysis, agile, linux, aws, apache,
# #########################
# ******* Devops Engineer ******
# jenkins, devops, autodesk, javascript, docker, linux, aws, autocad, python, mobile,
# #########################
# ******* Infrastructure Engineer ******
# ai, database, data,
# #########################
# ******* Devsecops Engineer ******
# node, java, script, agile, devops, angular, react, docker, spring, linux, aws, spring boot,
# #########################
# ******* Vp Group Technology Operations Public Cloud Solution Engineer ******
# devops, react, vue, aws, node, java, javascript, lambda, jenkins, json, docker, api, python, git, rest, spring, agile, angular, mvc, sql, mongodb, microservices, web development,
# #########################
# ******* Devops Engineer ******
# devops, linux, aws, java, gcp, io, kong, jenkins, analysis, docker, data, api, android, python, mobile, git, jira, database, spring, spring boot,
# #########################
# ******* Devops Engineer Up To ******
# git, jenkins, net, java, bash, devops, aws, python,
# #########################
# ******* Devops Expert ******
# microservices, devops, docker, aws,
# #########################
# ******* Senior Devops Engineer ******
# jenkins, devops, autodesk, javascript, docker, linux, aws, autocad, python, mobile,
# #########################
# ******* Assistant Vice President ******
# jenkins, aws, analysis, devops, consulting, thinking, python,
# #########################
# ******* Solution Architect ******
# docker, data, aws,
# #########################
# ******* Senior Devops Engineer ******
# git, jenkins, net, java, bash, devops, aws, python,
# #########################
# ******* Svp Public Cloud Software Engineer Technical Lead ******
# react, vue, aws, node, java, javascript, lambda, json, docker, api, python, git, rest, spring, agile, angular, mvc, sql, mongodb, microservices, web development,
# #########################
# ******* Cloud Engineer ******
#
# #########################
# ******* Associate Cloud Devops Engineer Technology And Operations ******
# analysis, gcp, aws, documentation, python,
# #########################
# ******* Research Engineer I ******
# ubuntu, java, database, script, nosql, spring, data, api, linux, hadoop, sql, aws, python,
# #########################
# ******* Staff Engineer ******
# jira, bash, devops, data, linux, python,
# #########################
# ******* Infrastructure Engineer ******
# ruby, optimization, linux, sql, php, python,
# #########################
# ******* Cloud Specialist West ******
# linux, ubuntu, analysis, aws,
# #########################
# ******* It Infrastructure Architect ******
# consulting, devops,
# #########################
# ******* Devops Engineer Tech Start Up ******
# django, devops, react, typescript, javascript, python,
# #########################
# ******* Cloud Devops Engineer ******
# net, java, database, agile, devops, angular, data, javascript, api, linux, docker, aws, php, python,
# #########################
# ******* Application Infrastructure Engineer ******
# net, agile, devops, api, bi, sql, javascript, documentation, python, power bi,
# #########################
# ******* Application Infrastructure Engineer ******
# ux, database, nosql, agile, devops, mysql, angular, javascript, restful, linux, nodejs, sql, aws, typescript, mongodb, python,
# #########################
# ******* Fvp Vp Devops Lead Microservices Continous Delivery Group Technology ******
# ruby, jenkins, analysis, jira, devops, thinking, python,
# #########################
# ******* Lead System Engineer ******
# docker, data, hadoop, linux, rabbitmq,
# #########################
# ******* Full Stack Engineer ******
# nosql, mysql, javascript, android, react, aws, springboot, mongodb, mobile,
# #########################
# ******* Support Engineer Sre Worknow ******
# jenkins, analysis, java, jira, splunk, agile, devops, angular, data, docker, springboot, python, scala,
# #########################
# ******* Senior Devops Engineer Passenger Processing Systems And Azure Cloud Operations ******
# git, jenkins, html, java, jira, devops, mysql, javascript, data, sql, aws, documentation,
# #########################
# ******* Lead Cybersecurity Engineer Jr ******
# jira, splunk, agile, devops, gcp, data, aws,
# #########################
# ******* Lead Devops Engineer ******
# git, ruby, ubuntu, net, jenkins, jira, splunk, optimization, bash, devops, docker, linux, aws, documentation, python,
# #########################
# ******* System Engineer ******
# linux, php, python,
# #########################
# ******* Devops Engineer ******
# devops, aws,
# #########################
# ******* Senior Research Engineer ******
# documentation, modeling, analysis, data,
# #########################
# ******* Devops Engineer Central ******
# git, jenkins, net, java, jira, agile, devops, mysql,
# #########################
# ******* Programs And Alliances Manager Asean ******
# data, aws,
# #########################
# ******* Cloud Security Architect ******
# analysis, data,
# #########################
# ******* Devops Engineer ******
# aws, devops, gcp, consulting, javascript, python,
# #########################
# ******* Senior Research Engineer ******
# documentation, modeling, analysis, data,
# #########################
# ******* Senior Research Engineer ******
# documentation, modeling, analysis, data,
# #########################
# ******* Presales It Engineer ******
# database, html, aws,
# #########################
# ******* Cloud Security Devops Engineer ******
# git, jira, database, devops, gcp, linux, aws, erp,
# #########################
# ******* System Engineer ******
# rest, ruby, database, bash, script, devops, mysql, linux, documentation, mongodb, postgresql, python,
# #########################
# ...
# #########################
# ******* Test Engineer ******
# analysis,
# #########################
# ******* Senior Associate Efx Senior Developer Technology Operations ******
# git, html, java, reactjs, script, devops, javascript, spring, react, apache, api, restful, nodejs, json, mvc, aws, microservices, mobile, spring boot,
# #########################
# ******* Software Engineer ******
# ux, spark, java, python, agile, devops, data, hadoop, linux, sql, javascript, apache,
# #########################
# ******* Lead Application Developer ******
# ux, git, html, ui, java, jira, react, sql, io, documentation, android, mobile, erp,
# #########################
# ******* Software Engineer ******
# express, node, html, jira, github, agile, react, javascript, php, web development,
# #########################
# ******* Full Stack Developer Javascript Or Typescript ******
# ui, java, spring, angular, data, react, vue, typescript, javascript, microservices, spring boot,
# #########################
# ******* C Net And Ms Sql Developer Cum Application Support ******
# net, sql,
# #########################
# ******* Senior Software Engineer ******
# java, react, sql, javascript, php, python,
# #########################
# ******* Sg Full Stack Engineer ******
# html, agile, react, data, bi, javascript, python,
# #########################
# ******* Associate Specialist Application Developer Treasury Markets ******
# rest, java, database, optimization, spring, agile, devops, data, linux, mvc, aws, documentation, apache, scala, spring boot,
# #########################
# ******* Software Design Engineer ******
# rest, analysis, data, oop, sql, documentation,
# #########################
# ******* Teradata Developer ******
# optimization, agile, data,
# #########################
# ******* Vp Application Developer Consumer Banking Group Technology ******
# ux, git, jenkins, java, jira, nosql, agile, mysql, data, aws, springboot,
# #########################
# ******* Full Stack Developer ******
# net, html, asp, database, data, api, mvc, javascript, php, mobile,
# #########################
# ******* Full Stack Developer ******
# git, rest, jenkins, html, java, database, spring, devops, angular, data, react, api, docker, nodejs, documentation, python, spring boot,
# #########################
# ******* Software Engineer ******
# html, javascript, sql, java,
# #########################
# ******* Software Engineer ******
# documentation, api, net, asp, web development,
# #########################
# ******* Senior Mobile Developer ******
# database, react, linux, sql, io, android, mobile,
# #########################
# ******* Senior Engineer ******
# python,
# #########################
# ******* It Cim Equipment Automation Senior Engineer ******
# documentation, net, sql, visual basic,
# #########################
# ******* Crm Developer ******
# net, html, asp, analysis, script, spring, data, mvc, sql, javascript, documentation, php,
# #########################
# ******* Web Developer ******
# documentation, net, web development,
# #########################
# ******* Senior Software Engineer ******
# linux,
# #########################
# ******* Application Development Manager ******
# analysis, java,
# #########################
# ******* Application Engineer ******
# rest, html, database, json, data, linux, sql, android,
# #########################
# ******* Analyst Programmer Web ******
# documentation, javascript, java,
# #########################
# ******* Java Developer Full Stack ******
# git, rest, jenkins, html, analysis, java, spring, agile, devops, angular, react, docker, api, nodejs, python, spring boot,
# #########################
# ******* R D Software Embedded Engineer ******
# git, jira,
# #########################
# ******* Software Developer ******
# jenkins, html, ui, json, agile, javascript, angular, react, restful, linux, aws, documentation, microservices,
# #########################
# ******* Application Architect ******
# net, database, mysql, docker, data, api, mvc, documentation, microservices,
# #########################
# ******* Software Engineer C C ******
# android, jira,
# #########################
# ******* Back End Developer ******
# java, database, script, docker, data, aws, documentation, python,
# #########################
# ******* Software Engineer ******
# java, sql, data,
# #########################
# ******* Software Development Team Lead ******
# html, mysql, javascript, php, mobile,
# #########################
# ******* Robotics Software Engineer ******
# git, python,
# #########################
# ******* Net Full Stack Engineer ******
# rest, net, html, asp, ui, reactjs, bootstrap, agile, angular, api, sql, sas, mobile,
# #########################
# ******* Software Developer ******
# git, net, angular, data, react, api, aws, ai, mobile,
# #########################
# ******* Technical Support Programmer ******
# database, javascript, sql, data,
# #########################
# ******* Associate Software Test Analyst ******
# analysis, script, excel, data, documentation,
# #########################
# ******* Lead Software Engineer Tech Lead ******
# java, rabbitmq, javascript, documentation, analysis, reactjs, bootstrap, restful, api, python, rest, html, asp, database, spring, mvc, nodejs, sql, php,
# #########################
# ******* It Support Engineer ******
# documentation, mobile, data, customer service,
# #########################
# ******* C Software Engineer ******
# data, visual basic,
# #########################
# ******* Application Developer ******
# git, rest, jenkins, net, java, database, angularjs, spring, devops, mysql, documentation, javascript, docker, api, bootstrap, aws, springboot, microservices, customer service,
# #########################
# ******* Software Engineer ******
# database, tableau, agile, devops, data, linux, sql, python,
# #########################
# ******* Java Developer ******
# java, spring, restful, data, mvc, swift, documentation,
# #########################
# ******* Net Developer ******
# rest, net, html, asp, ui, java, script, bootstrap, json, angular, data, react, api, mvc, sql, javascript,
# #########################
# ******* C Net Software Developer ******
# oop, net,
# #########################
# ******* Avp Senior Associate Fullstack Developer ******
# jenkins, java, jira, database, nosql, agile, devops, spring, data, aws, microservices, spring boot,
# #########################
# ******* Quality Assurance Engineer Python Shell ******
# python, data,
# #########################
# ******* Software Engineer Backend Based ******
# kong, git, database, javascript, docker, data, api, typescript, aws, documentation, mongodb,
# #########################
# ******* Senior Engineer Switch Operations ******
# mobile, linux, analysis, database,
# #########################
# ******* Software Engineer ******
# git, html, bootstrap, json, data, linux, sql, mongodb, php, python,
# #########################
# ******* Senior Web Developer ******
# javascript, java,
# #########################
# ******* React Developer Lead ******
# rest, node, html, java, reactjs, spring, devops, agile, javascript, data, react, consulting, cordova, spring boot,
# #########################
# ******* Software Developer Year Renewable Contract Up To ******
# jenkins, analysis, database, spring, data, documentation, spring boot,
# #########################
# ******* It Applications Principal Senior Engineer ******
# net, html, java, database, json, restful, data, sql, javascript, documentation, microservices, mobile,
# #########################
# ******* Software Engineer Developer ******
# ruby, java, agile, devops, oop, consulting, python, mobile, scala,
# #########################
# ******* Senior Software Engineer ******
# linux, sql, java,
# #########################
# ******* Software Engineer ******
# sql, net, asp, erp,
# #########################
# ******* Full Stack Developer ******
# ui, java, spring, angular, data, react, vue, typescript, javascript, microservices, spring boot,
# #########################
# ******* Principal Software Engineer ******
# java, database, optimization, nosql, agile, mysql, spring, data, oop, aws, microservices, spring boot,
# #########################
# ******* Junior Web Developer ******
# kong, node, github, bootstrap, gcp, mysql, laravel, vue, sas,
# #########################
# ******* Java Developer Si Environment ******
# documentation, spring, angular, java, spring boot,
# #########################
# ******* Senior Software Engineer ******
# jenkins, net, asp, java, jira, analysis, agile, sql, javascript, documentation,
# #########################
# ******* It Officer ******
# net, asp, java, script, mvc, sql, dotnet,
# #########################
# ******* Net Software Solution Consultant Net Project Consultant ******
# net,
# #########################
# ******* Senior Infra Engineer Orchard Months Contract ******
# data, linux, sql, documentation, python,
# #########################
# ******* Application Engineer ******
# net, sql, java, customer service,
# #########################
# ******* Senior Net Java Developer ******
# rest, net, asp, ui, java, jira, agile, documentation,
# #########################
# ******* It Personnel ******
# database, java, sql, aws,
# #########################
# ******* Full Stack Software Developer ******
# git, spring, analysis, java,
# #########################
# ******* Vp Avp Senior Application Develop Group Consumer Banking ******
# git, jenkins, java, jira, spring, agile, devops, data, react, typescript, javascript, springboot, microservices,
# #########################
# ******* Associate Angularjs Developer Technology Operations ******
# git, angularjs, agile,
# #########################
# ******* Senior Associate Associate Ui Developer Group Consumer Banking And Big Data Analytics Technology Technology Operati ******
# rest, jenkins, node, html, jira, database, angularjs, reactjs, nosql, agile, javascript, optimization, data, api, nodejs, thinking, mobile,
# #########################
# ******* Computer Integrated Manufacturing Engineer ******
# html, database, java, angular, sql,
# #########################
# ******* Senior Software Engineer ******
# ruby, html, reactjs, optimization, mysql, agile, laravel, react, javascript, postgresql,
# #########################
# ******* Junior Full Stack Developer ******
# java, spring, agile, data, linux, consulting, python, spring boot,
# #########################
# ******* Snrassoc Ui Developer Technology Operations ******
# git, angularjs, agile,
# #########################
# ******* Qa Engineer ******
# java, script, agile, api, thinking, postman, mobile,
# #########################
# ******* Lead Front End Engineer ******
# ui, react, data, api, ai,
# #########################
# ******* Backend Developer ******
# jenkins, github, restful, docker, data, sql, aws, mongodb, postgresql, microservices,
# #########################
# ******* Senior Java Full Stack Engineer ******
# rest, html, ui, java, reactjs, spring, agile, bootstrap, angular, restful, linux, sql, springboot, sas, mobile,
# #########################
# ******* Deskside Engineer On Site Engineer ******
# linux, express, consulting, data,
# #########################
# ******* Software Development Engineer ******
# java, spring, react, linux, nodejs, documentation,
# #########################
# ******* Junior Software Engineer ******
# mongodb, agile, mobile,
# #########################
# ******* It Engineer ******
# html, database, java, excel, javascript,
# #########################
# ******* Associate Specialist Application Developer Treasury Markets ******
# rest, java, database, optimization, spring, agile, devops, data, linux, mvc, aws, documentation, apache, scala, spring boot,
# #########################
# ******* Computer Integration Engineer ******
# html, java, database, angular, data, sql,
# #########################
# ******* Senior Java Developer ******
# rest, jenkins, html, java, database, spring, mysql, devops, linux, javascript, spring boot,
# #########################
# ******* Software Engineer ******
# documentation, api, javascript,
# #########################
# ******* Application Developer ******
# net, jira, database, java, mvc, sql,
# #########################
# ******* Java Developer ******
# ux, mobile,
# #########################
# ******* Software Engineer Jh ******
# html, java, spring, script, documentation,
# #########################
# ******* Senior Principal Engineer Manufacturing Systems Engineering ******
# analysis, java, database, script, linux, sql, documentation, apache,
# #########################
# ******* Lecturer Full Stack ******
# git, flask, html, django, java, nosql, bootstrap, javascript, angular, react, docker, sql, typescript, python, web development,
# #########################
# ******* Sql Developer ******
# spark, agile, data, sql, python,
# #########################
# ******* Software Design Engineer ******
#
# #########################
# ******* Perception Sensor Software Engineer ******
# git, agile, docker, data, linux, thinking, python,
# #########################
# ******* Frontend Engineer ******
# github, html, javascript,
# #########################
# ******* Senior Or Software Engineer ******
# html, analysis, java, data, javascript, documentation, python,
# #########################
# ******* Associate Software Engineer ******
# java, database, angularjs, mysql, agile, vue, javascript, mongodb, php, mobile,
# #########################
# ******* Lead Backend Engineer ******
# rest, database, json, mysql, data, nodejs, python,
# #########################
# ******* C Development Engineer ******
# optimization, linux, data,
# #########################
# ******* Software Engineer ******
# python,
# #########################
# ******* Design Software Engineer ******
# documentation, net, data,
# #########################
# ******* Software Engineer ******
# ux, rest, ruby, git, html, analysis, ui, java, optimization, database, restful, angular, data, react, api, javascript, documentation, python,
# #########################
# ******* Senior Firmware Engineer ******
# net, analysis, data, io, documentation,
# #########################
# ******* Java Software Developer ******
# analysis, java, database, spring, documentation, data, blockchain, sql, ai,
# #########################
# ******* Full Stack Developer ******
# flask, net, lambda, optimization, javascript, data, react, nodejs, sql, aws, sas, typescript, python,
# #########################
# ******* Software Engineer ******
# agile, python, analysis,
# #########################
# ******* Full Stack Developer ******
# flask, net, lambda, optimization, javascript, data, react, nodejs, sql, aws, sas, typescript, python,
# #########################
# ******* Junior Senior Dot Net Developer ******
# rest, jenkins, net, analysis, ssis, bootstrap, devops, docker, angular, api, mvc, sql, javascript, web development,
# #########################
# ******* R D Engineer Senior R D Engineer ******
# angularjs, nodejs, javascript,
# #########################
# ******* Software Engineer Iot Development ******
#
# #########################
# ******* Java Developer ******
# git, jenkins, java, jira, database, spring, agile, apache, sql, documentation, microservices, spring boot,
# #########################
# ******* Software Deployment Engineer ******
# documentation, database, data,
# #########################
# ******* Senior Engineer Industrial Software ******
# net, agile, thinking,
# #########################
# ******* Technical Manager ******
# analysis, java, database, data, javascript, python,
# #########################
# ******* Senior Net Developer Worknow ******
# ux, rest, node, net, html, java, database, mysql, angular, react, microservices, api, sql, javascript, documentation, apache,
# #########################
# ******* Application Developer Up To Id ******
# net, jira, java, database, data, mvc, sql,
# #########################
# ******* Regional Agile Scrum Master ******
# agile,
# #########################
# ******* Unity Software Engineer ******
# rest, ui, io, android, mobile,
# #########################
# ******* Embedded Manager ******
# python, ui,
# #########################
# ******* Senior Software Engineer ******
# kong, git, express, node, lambda, database, restful, javascript, docker, data, nodejs, aws, documentation, mongodb,
# #########################

# %%
with open("soft_skills_map.csv", "w") as f:
    for index, row in df.iterrows():
#         print("*******",row['clean_job_title'],"******")
        for i in row['soft_skills']:
#             print(i, end=", ")
            try:
                f.write(row['keyword']+","+i+"\n")
            except:
                print(i)
#         print()
#         print("#"*25)
# Out:
# 帮助将其整合到腾讯的平台上
# 调查技术有良好的理解
# gcp或azure有经验
# 包括配置和部署管理系统
# 架构和运营经验
# 对微服务架构和调试
# cd原则
# 对系统
# 确保基础设施对关键功能和工作流程的支持
# 热衷于构建可扩展
# 高性能和高可用性的系统
# 帮助定义和维护正确的网络运营实践
# ansible和jenkins的经验
# 具有ci
# 对主要云平台aws
# 开发和支持可靠的
# 网络和故障排除技术有深刻理解
# 包括内存泄露
# 熟悉android
# 启动时间
# json类据格式交互
# 在不同的应用场景下能使用相对合理的设计模式
# 熟悉面向对象编程
# 熟悉android下网路通信机制
# 熟悉数据库
# 性能
# 熟悉android的线程机制
# ui框架及相关开发工具
# 黄奕豪
# 黄奕豪
