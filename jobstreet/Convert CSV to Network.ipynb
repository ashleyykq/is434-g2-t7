# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_colwidth', None) #prevent truncated view of dataframe
pd.set_option('display.max_rows', None) #show all rows

# %%
df = pd.read_csv("31_mar_job_with_skills.csv")

# %%
df = df.drop(df.columns[0:1], axis=1)

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3153 entries, 0 to 3153
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   keyword           3153 non-null   object
#  1   clean_job_title   3153 non-null   object
#  2   clean_job_desc    3153 non-null   object
#  3   technical_skills  3153 non-null   object
#  4   soft_skills       3153 non-null   object
# dtypes: object(5)
# memory usage: 147.8+ KB

# %%
df.head()
# Out:
#           keyword                       clean_job_title  \
# 0  cloud engineer                        Cloud Engineer
# 1  cloud engineer                        Cloud Engineer
# 2  cloud engineer  Cloud Engineer Bedok Months Contract
# 3  cloud engineer                   Lead Cloud Engineer
# 4  cloud engineer                 Cloud System Engineer
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             clean_job_desc  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               description position suitable individual constant learner problem solver multi taskers candidate thrive fast paced environment step face challenge able deliver result welcome apply looking candidate interested implementation operation cloud infrastructure responsible implementing maintaining cloud infrastructure aws azure google cloud xtremax customer provide support customer issue cloud infrastructure closely security monitor privacy develop incident response procedure least year hand managing network infrastructure managed service aws azure gcp least one cloud certification level higher e g aws certified sysops administrator associate microsoft certified azure administrator associate google cloud certified professional data engineer least one operating system linux window understanding networking preferable tcp ip ip address http dns basic security concept user management o hardening communication scripting skill powershell bash python nodejs etc extra value submitting resume cv consent agree allow information provided used processed behalf xtremax pte ltd purpose registration interest current future employment u processing application employment personal data held u relating application kept strictly confidential accordance pdpa may also refer privacy policy detail http www xtremax com privacy policy inform consent providing necessary data required u process application potentially able offer
# 1  looking individual passionate designing implementing maintaining cloud infrastructure ecosystem participate project play important major role shaping customer interact u project include customer facing website portal acquire retain potential existing customer understand business design implement maintain cloud infrastructure architecture support ongoing application development integration cloud service need comfortable cloud technology architecture report directly technology manager day life collaborating engineering development team evaluate identify optimal cloud solution modifying improving existing system educating team implementation cloud technology initiative designing developing deploying modular cloud based system developing maintaining cloud solution accordance best practice ensuring efficient functioning data storage processing function accordance security policy best practice cloud security identifying analyzing resolving infrastructure vulnerability application deployment issue regularly reviewing existing system making recommendation improvement need diploma bachelor degree computer science information system computer engineering equivalent qualification azure cloud certification preferred role least year hand deploying maintaining troubleshooting cloud infrastructure familiar azure virtual desktop window virtual desktop environment preferred working azure cloud infrastructure sql server web server bonus team player able collaboratively member team troubleshooting analytical able multi task handle multiple assignment tight timeline please provide portfolio addition resume attached softcopy url offer centrally located office anson road connected tanjong pagar mrt empowering people draw career map promote agile working environment hybrid option passion building motivating dynamic competent team collaborative culture cherishes idea respectful environment competitive employee benefit flexible benefit medical wellness program creating inclusive space employee valued experience unique perspective
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     industry technology location bedok month renewable support instance wintel linux aws azure cloud environment deliver stable efficient reliable cloud infrastructure operation meet exceed stipulated sla support design implementation testing installation network underlay overlay software defined networking cloud infrastructure prem cloud perform daily performance monitoring analysis maintenance ensure network underlay prem sdn cloud infrastructure performed according sla apply interested party please send resume evonne_png persolkelly com click apply applicant would evonne png wen xuan reg r persolkelly singapore pte ltd ea license r sending u personal data curriculum vitae cv deemed consent persolkelly singapore pte ltd local overseas subsidiary affiliate collecting using disclosing personal data prospective employer company based country purpose evaluating suitability employment conducting reference check administering employment service complying government covid health advisory purpose stated privacy policy full privacy policy available www persolkelly com sg wish withdraw consent please drop u email let u know please feel free contact u query thank day
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  design implement cloud infrastructure solution secure scalable highly available aws collaborate various team define infrastructure deployment support digital transformation project provision configure maintain aws cloud infrastructure defined code ensure configuration compliance source control service eg codecommit act level support operation team automation issue encountered troubleshoot problem across wide array service functional area build operational tool deployment monitoring analysis aws infrastructure system handover operation team e g aws system manager involve participate infrastructure cost analysis optimization effort provide documentation conduct training session solution required evaluate cloud provider prepare multi cloud strategy drive transformational modernisation project degree accredited university minimum year relevant particularly cloud area focus aws cloud demonstrated hand aws code pipeline rd party integration tech savvy hand automation tool eg ansible familiar container service serverless computing preferably aws cloud certification eg aws devops solution architect ability manage time effectively set priority meet deadline posse analytical critical thinking problem solving excellent written verbal communication communication influencing presentation friendly professional demeanour ability excel team oriented environment
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     order number focused delivery wide range technology solution including innovative technology vmware microsoft virtualization microsoft core solution azure system infrastructure server storage backup many solution customer consultative basis provide troubleshooting workaround solution software issue ongoing basis customer provide installation configuration support technology solution based client work project manager deliver project accordance project management sop provide customer support direct quality assurance project assigned technical service manager provide x standby duty based duty roaster existing system maintenance customer enhance customer satisfaction overall customer relationship help leverage customer relationship within business development effort coordinate customer project schedule manage stakeholder expectation requirement till closure project deliver statement proposed consultant team ensure design accordance proposal diploma degree computer science study ability independently efficiently productively without guidance ability multi task meet deadline willingness capability learning technology required accomplishing project goal willingness x standby based duty roaster project implementation deployment troubleshooting microsoft cloud hybrid cloud solution preferred depth understanding software concept apply please kindly email updated resume cv_jasonwong goodjobcreations com sg candidate however rest assured application updated resume bank future opportunity ea personnel name jason wong seng siang ea personnel reg r ea license c
#
#                                                              technical_skills  \
# 0                 ['gcp', 'aws', 'nodejs', 'linux', 'bash', 'python', 'data']
# 1                                                    ['sql', 'data', 'agile']
# 2                                        ['data', 'analysis', 'aws', 'linux']
# 3  ['aws', 'documentation', 'analysis', 'thinking', 'devops', 'optimization']
# 4                                                                    ['rest']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         soft_skills
# 0                                                                                                                                                           ['support', 'etc', 'future', 'resume', 'responsible', 'purpose', 'service', 'incident', 'candidate', 'providing', 'ltd', 'required', 'ip', 'constant', 'xtremax', 'suitable', 'gcp', 'infrastructure', 'privacy', 'agree', 'offer', 'thrive', 'level', 'nodejs', 'google', 'learner', 'understanding', 'powershell', 'least', 'pdpa', 'monitor', 'tcp', 'fast', 'extra', 'personal', 'python', 'higher', 'able', 'associate', 'interested', 'professional', 'implementing', 'paced', 'implementation', 'allow', 'individual', 'inform', 'skill', 'processed', 'pte', 'networking', 'http', 'azure', 'sysops', 'managed', 'detail', 'basic', 'microsoft', 'current', 'scripting', 'certified', 'apply', 'administrator', 'process', 'deliver', 'confidential', 'maintaining', 'bash', 'accordance', 'concept', 'necessary', 'cloud', 'www', 'window', 'address', 'result', 'provide', 'develop', 'multi', 'behalf', 'data', 'welcome', 'used', 'consent', 'com', 'engineer', 'application', 'challenge', 'aws', 'cv', 'user', 'linux', 'dns', 'preferable', 'procedure']
# 1  ['support', 'mrt', 'perspective', 'dynamic', 'hybrid', 'resume', 'service', 'virtual', 'web', 'qualification', 'ongoing', 'function', 'degree', 'career', 'regularly', 'solution', 'infrastructure', 'offer', 'science', 'building', 'inclusive', 'timeline', 'modular', 'maintain', 'least', 'working', 'recommendation', 'identify', 'portal', 'interact', 'important', 'retain', 'able', 'unique', 'preferred', 'server', 'implementing', 'efficient', 'architecture', 'implementation', 'deployment', 'please', 'benefit', 'flexible', 'initiative', 'individual', 'understand', 'handle', 'collaborative', 'competitive', 'competent', 'report', 'designing', 'diploma', 'assignment', 'azure', 'identifying', 'major', 'familiar', 'design', 'multiple', 'promote', 'tight', 'url', 'ecosystem', 'facing', 'agile', 'comfortable', 'equivalent', 'bonus', 'participate', 'maintaining', 'sql', 'need', 'accordance', 'cloud', 'team', 'optimal', 'task', 'include', 'window', 'implement', 'tanjong', 'softcopy', 'passionate', 'evaluate', 'project', 'provide', 'website', 'multi', 'desktop', 'data', 'collaboratively', 'map', 'application', 'best', 'analytical', 'potential', 'bachelor', 'medical', 'integration']
# 2                                                                                                                                                                                                                                                                                                                                                          ['support', 'reliable', 'sg', 'analysis', 'complying', 'resume', 'purpose', 'service', 'singapore', 'applicant', 'bedok', 'monitoring', 'ltd', 'query', 'click', 'infrastructure', 'privacy', 'local', 'vitae', 'deemed', 'suitability', 'withdraw', 'underlay', 'prem', 'contact', 'know', 'personal', 'png', 'maintenance', 'interested', 'employer', 'evonne', 'reg', 'efficient', 'overseas', 'sdn', 'implementation', 'please', 'advisory', 'available', 'pte', 'stable', 'send', 'renewable', 'full', 'networking', 'azure', 'installation', 'ea', 'design', 'wen', 'exceed', 'defined', 'stated', 'apply', 'sla', 'deliver', 'free', 'drop', 'cloud', 'www', 'prospective', 'reference', 'curriculum', 'email', 'data', 'license', 'wish', 'consent', 'com', 'xuan', 'performed', 'aws', 'cv', 'thank', 'meet', 'linux', 'daily', 'covid', 'perform', 'location']
# 3                                                                                                                                                                                                                                           ['support', 'involve', 'excellent', 'analysis', 'prepare', 'control', 'transformational', 'accredited', 'service', 'provider', 'tech', 'digital', 'relevant', 'monitoring', 'minimum', 'required', 'demeanour', 'secure', 'degree', 'wide', 'container', 'serverless', 'solution', 'infrastructure', 'tool', 'handover', 'savvy', 'optimization', 'preferably', 'critical', 'level', 'excel', 'documentation', 'maintain', 'encountered', 'set', 'deadline', 'devops', 'collaborate', 'university', 'professional', 'drive', 'define', 'deployment', 'focus', 'various', 'available', 'oriented', 'build', 'manage', 'operational', 'code', 'posse', 'rd', 'familiar', 'design', 'scalable', 'troubleshoot', 'defined', 'act', 'verbal', 'participate', 'cost', 'functional', 'cloud', 'team', 'implement', 'evaluate', 'project', 'provide', 'multi', 'architect', 'friendly', 'ansible', 'configure', 'analytical', 'aws', 'meet', 'automation', 'demonstrated', 'eg', 'integration']
# 4                                                                                                                                                                                                                                                      ['support', 'sg', 'future', 'stakeholder', 'sop', 'hybrid', 'resume', 'service', 'candidate', 'wong', 'leverage', 'ongoing', 'required', 'many', 'degree', 'wide', 'updated', 'expectation', 'solution', 'infrastructure', 'quality', 'science', 'core', 'direct', 'standby', 'understanding', 'closure', 'deadline', 'focused', 'maintenance', 'preferred', 'server', 'reg', 'innovative', 'implementation', 'deployment', 'please', 'technical', 'workaround', 'assured', 'assigned', 'manage', 'satisfaction', 'virtualization', 'diploma', 'consultative', 'azure', 'installation', 'ea', 'learning', 'backup', 'design', 'microsoft', 'name', 'willingness', 'apply', 'deliver', 'cv_jasonwong', 'enhance', 'vmware', 'schedule', 'accordance', 'overall', 'concept', 'seng', 'study', 'team', 'cloud', 'depth', 'task', 'requirement', 'coordinate', 'project', 'email', 'provide', 'multi', 'duty', 'range', 'license', 'com', 'application', 'rest', 'help', 'meet']

# %%
df['technical_skills'] = df['technical_skills'].apply(eval)
df['soft_skills'] = df['soft_skills'].apply(eval)

# %%
with open("testing.csv", "w") as f:
    for index, row in df.iterrows():
        print("*******",row['clean_job_title'],"******")
        for i in row['technical_skills']:
            print(i, end=", ")
            f.write(row['keyword']+","+i+"\n")
        print()
        print("#"*25)
# Out:
# ******* Cloud Engineer ******
# gcp, aws, nodejs, linux, bash, python, data,
# #########################
# ******* Cloud Engineer ******
# sql, data, agile,
# #########################
# ******* Cloud Engineer Bedok Months Contract ******
# data, analysis, aws, linux,
# #########################
# ******* Lead Cloud Engineer ******
# aws, documentation, analysis, thinking, devops, optimization,
# #########################
# ******* Cloud System Engineer ******
# rest,
# #########################
# ******* System Engineer ******
# documentation, data, analysis, aws,
# #########################
# ******* Devops Engineer ******
# aws, jenkins,
# #########################
# ******* Systems Engineer ******
# optimization, bash, linux,
# #########################
# ******* Cloud Engineer Year Renewable Contract Bedok Up To ******
# data, analysis, aws, linux,
# #########################
# ******* Cloud Devops Engineer ******
# aws, github, gcp, devops,
# #########################
# ******* Lead Cloud Engineer ******
# aws,
# #########################
# ******* Cloud Data Engineer Analyst ******
# docker, api, sql, hadoop, microservices, spark, devops, python, tableau, modeling, data, bi,
# #########################
# ******* Cloud Engineer ******
# docker, api, lambda, aws, scala, java, json, numpy, postgresql, rest, github, devops, python, optimization, jenkins,
# #########################
# ******* Cloud Network Engineer Physical Network Infrastructure ******
# optimization, data, linux,
# #########################
# ******* Cloud Engineer ******
# gcp, aws, documentation, analysis, git, microservices, script, jenkins,
# #########################
# ******* Cloud Network Engineer Physical Network Infrastructure ******
# optimization, data, linux,
# #########################
# ******* Cloud Infrastructure System Engineer ******
# thinking, documentation, linux,
# #########################
# ******* Cloud Security Engineer ******
# database, aws, modeling, analysis, linux, rest, data,
# #########################
# ******* Cloud Engineer ******
# gcp, aws,
# #########################
# ******* Microsoft Azure Cloud Security Engineer ******
# mobile, aws, hadoop, consulting, analysis, python, sql, data,
# #########################
# ******* Cloud Security Engineer ******
# data, aws,
# #########################
# ******* Cloud Specialist Engineer ******
# consulting, data, devops,
# #########################
# ******* Senior Cybersecurity Engineer ******
#
# #########################
# ******* Senior Cloud Engineer Group Consumer Banking And Big Data ******
# linux, javascript, data, python, script,
# #########################
# ******* Desktop Wintel Linux Cloud Cyber Security Engineer ******
# apache, database, aws, linux, data, script,
# #########################
# ******* Public Cloud Solution Engineer Technology And Operations ******
# gcp, aws, java, analysis, linux, python, optimization, agile, node, customer service,
# #########################
# ******* Avp Senior Associate Pcf Cloud Operations Engineer ******
# spring, gcp, aws, java, linux, splunk, devops, python, data, agile, jenkins, customer service,
# #########################
# ******* Cloud Platform Devops Engineer ******
# gcp, aws, linux, python, optimization,
# #########################
# ******* Senior Software Engineer ******
# apache, api, django, ruby, sql, hadoop, database, java, aws, ai, html, mongodb, php, mysql, python, rest, data, json, web development,
# #########################
# ******* Vp Public Cloud Solution Engineer Technology And Operations ******
# gcp, java, analysis, linux, python, optimization, agile, node, customer service,
# #########################
# ******* Senior Cloud Engineer Group Consumer Banking And Big Data ******
# linux, javascript, data, python, script,
# #########################
# ******* Cloud Engineer ******
# net, aws, linux, mysql, data, customer service,
# #########################
# ******* Vp Public Cloud Solution Engineer Technology And Operations ******
# gcp, java, analysis, linux, python, optimization, agile, node, customer service,
# #########################
# ******* Cloud Specialist Up To Yearly Contract ******
# data, analysis, aws,
# #########################
# ******* Cloud Security Engineer ******
# database, aws, modeling, analysis, linux, rest, data,
# #########################
# ******* Avp Senior Associate Devops Engineer Virtual Private Cloud ******
# python, microservices, docker, linux,
# #########################
# ******* Svp Public Cloud Software Engineer Technical Lead ******
# json, spring, api, lambda, angular, mongodb, python, mvc, react, vue, rest, microservices, agile, docker, aws, java, javascript, git, sql, node, web development,
# #########################
# ******* Svp Public Cloud Software Engineer Technical Lead Technology ******
# json, spring, api, lambda, angular, mongodb, python, mvc, react, vue, rest, microservices, agile, docker, aws, java, javascript, git, sql, node, web development,
# #########################
# ******* Aws Cloud Engineer ******
# docker, script, analysis, aws,
# #########################
# ******* Cloud Operations Lead ******
# aws, jira, ai, linux,
# #########################
# ******* Senior Systems Engineer ******
# docker, apache, ruby, aws, java, documentation, linux, jira, git, devops, python, php, bash,
# #########################
# ******* Avp Senior Associate Network Security Engineer Cloud Engineering ******
# documentation, analysis,
# #########################
# ******* Vp Public Cloud Solution Engineer Group Technology Operations ******
# json, jenkins, spring, api, lambda, angular, mongodb, devops, python, mvc, react, vue, microservices, rest, agile, docker, aws, java, javascript, git, sql, node, web development,
# #########################
# ******* It Consultant ******
# aws,
# #########################
# ******* Devops Engineer ******
# docker, api, aws, linux, github, devops, jenkins,
# #########################
# ******* Svp Public Cloud Software Engineer Technical Lead Technology ******
# json, spring, api, lambda, angular, mongodb, python, mvc, react, vue, rest, microservices, agile, docker, aws, java, javascript, git, sql, node, web development,
# #########################
# ******* Svp Public Cloud Software Engineer Technical Lead ******
# json, spring, api, lambda, angular, mongodb, python, mvc, react, vue, rest, microservices, agile, docker, aws, java, javascript, git, sql, node, web development,
# #########################
# ******* Cloud Infrastructure Engineer ******
# thinking, documentation, linux,
# #########################
# ******* Cloud Infrastructure Specialist Ikano Retail ******
# analysis,
# #########################
# ******* Cloud Technical Consultant ******
# docker, sql, aws, java, python,
# #########################
# ******* Cloud Engineer ******
# docker, mobile, aws, linux, jira, bash, sql, script, agile,
# #########################
# ******* Cloud Data Engineer ******
# docker, apache, api, lambda, django, database, aws, spark, linux, rest, devops, python, tableau, data, agile,
# #########################
# ******* System Engineer Cloud Server Linux Configurations Deployment ******
# documentation, data, aws, linux,
# #########################
# ******* Cloud Team Lead ******
# consulting, data, aws, devops,
# #########################
# ******* Senior System Infrastructure Engineer ******
# thinking, documentation, data, database,
# #########################
# ******* Cloud Analyst ******
# aws,
# #########################
# ******* Cloud Specialist Amazon Azure ******
# consulting, data, analysis, aws,
# #########################
# ******* Cloud Security Dev ******
# aws, devops, python, data, jenkins,
# #########################
# ******* Devops Engineer ******
# net, docker, nosql, database, nodejs, linux, node, mongodb, ubuntu, microservices, data, jenkins,
# #########################
# ******* Devops Engineer ******
# docker, linux, jira, git, devops, jenkins,
# #########################
# ******* Senior It Cloud Infra Engineer ******
# microservices, aws, devops,
# #########################
# ******* Cloud Engineer ******
# gcp, aws,
# #########################
# ******* Cloud Engineer 云端工程师 ******
# docker, api, gcp, aws, linux, devops, python,
# #########################
# ******* Cloud Devsecops Architect ******
# net, restful, spring, api, lambda, aws, java, php, devops, optimization, data,
# #########################
# ******* Cloud Infrastructure Engineer ******
# thinking, documentation, linux,
# #########################
# ******* Cloud Infrastructure Engineer ******
# thinking, documentation, linux,
# #########################
# ******* It Lead Worknow ******
# aws, gcp, linux, script, ubuntu, data, bi, power bi,
# #########################
# ******* Cloud Infra Engineer ******
# documentation, data, linux,
# #########################
# ******* Devops Engineer ******
# net, docker, nosql, database, nodejs, linux, node, mongodb, ubuntu, microservices, data, jenkins,
# #########################
# ******* Devops Team Lead ******
# docker, aws, linux, thinking, bash, devops, python, script, jenkins,
# #########################
# ******* Managed Services And Devops Solution Architect ******
# restful, docker, api, database, aws, documentation, git, devops, sql, data, jenkins, customer service,
# #########################
# ******* Cloud Operation Engineer ******
# gcp, aws, documentation, analysis, microservices, script,
# #########################
# ******* Cloud System Engineer ******
# database, aws, analysis, linux, thinking, devops, python, script,
# #########################
# ******* Devops Engineer ******
# docker, aws, thinking, jira, python, script, agile, jenkins,
# #########################
# ******* Cloud Specialist Months Contract ******
# data, analysis, aws,
# #########################
# ******* Senior Devops Engineer ******
# net, aws, java, git, devops, python, bash, jenkins,
# #########################
# ******* Aws Technical Trainer ******
# net, gcp, ruby, aws, analysis, javascript, linux, php, devops, python, bash, data,
# #########################
# ******* Junior Cloud Infrastructure Architect ******
# thinking, documentation, linux,
# #########################
# ******* Quality Engineer ******
# documentation,
# #########################
# ******* Devops Lead Engineer ******
# database, aws, documentation, devops, sql, optimization, script,
# #########################
# ******* Cloud Devops Engineer ******
# aws, consulting, documentation, analysis, devops, python, script, jenkins,
# #########################
# ******* Devops Engineer ******
# docker, aws, mongodb, devops, jenkins,
# #########################
# ******* Regional Cloud Steward ******
# optimization, analysis, aws,
# #########################
# ******* System Engineer ******
# apache, sql, aws, nodejs, linux, bash, python, data,
# #########################
# ******* Software Test Engineer ******
# sql, thinking, optimization, analysis,
# #########################
# ******* Devops Engineer ******
# docker, spring, api, mobile, gcp, database, aws, java, analysis, io, linux, jira, git, devops, python, android, jenkins, spring boot,
# #########################
# ******* Junior Cloud Engineer ******
# apache, sql, aws, nodejs, linux, bash, python, data,
# #########################
# ******* Devops Engineer ******
# aws, devops, python, rest, jenkins,
# #########################
# ******* Lead Senior Cloud Devsecops Engineer ******
# docker, analysis, aws, devops,
# #########################
# ******* Kyndryl Apprenticeship ******
# java, analysis, react, data, devops, python, script,
# #########################
# ******* Avp Public Cloud Developer Technology Operations ******
# linux, javascript, data, python, script,
# #########################
# ******* Apac Data Analyst Engineer ******
# sql, analysis, python, tableau, data, bi,
# #########################
# ******* Vp Public Cloud Developer Technology Operations ******
# javascript, linux, data, python, script, agile,
# #########################
# ******* Senior Cloud Enablement Group Consumer Banking And Big Data ******
# lambda, aws, java, documentation, nodejs, splunk, devops, python, data, agile, jenkins,
# #########################
# ******* Senior Cloud Enablement Group Consumer Banking And Big Data ******
# lambda, aws, java, documentation, nodejs, splunk, devops, python, data, agile, jenkins,
# #########################
# ******* Cloud Ops Engineer ******
# database, aws, java, documentation, analysis, linux, postgresql, devops, sql, script, jenkins,
# #########################
# ******* Devops Engineer ******
# docker, api, aws, microservices, linux, rest, devops, python, optimization, agile, jenkins,
# #########################
# ******* Cloud Infrastructure System Engineer ******
# thinking, documentation, linux,
# #########################
# ******* Solution Engineer ******
# data, analysis, aws, linux,
# #########################
# ******* Senior System Engineer ******
# optimization, documentation,
# #########################
# ******* Junior Dev Ops Engineer Immediate ******
# linux, script, database, devops,
# #########################
# ******* Devops Engineer ******
# aws, documentation, linux, thinking, bash, devops, jenkins,
# #########################
# ******* Devops Engineer ******
# docker, apache, analysis, linux, devops, python, optimization, data,
# #########################
# ******* Linux Administrator ******
# aws, analysis, linux, python, script,
# #########################
# ******* Senior Cloud Enablement Group Consumer Banking And Big Data ******
# lambda, aws, java, documentation, nodejs, splunk, devops, python, data, agile, jenkins,
# #########################
# ******* Senior Research Engineer ******
# modeling, documentation, data, analysis,
# #########################
# ******* Devops Engineer ******
# docker, nosql, database, aws, documentation, linux, mysql, postgresql, mongodb, devops, python, script, node,
# #########################
# ******* Senior Associate Devops Engineer ******
# docker, ai, linux, python, microservices,
# #########################
# ******* Lead Senior Cloud Software Engineer ******
# devops,
# #########################
# ******* Cloud Architect ******
# docker, consulting, ai, sql, data,
# #########################
# ******* It Engineer ******
# docker, analysis, aws,
# #########################
# ******* Devops Engineer ******
# docker, mobile, sql, database, io, jira, data, devops, python, android, jenkins,
# #########################
# ******* Cloud Technical Architect ******
# docker, api, aws, documentation, jira, bash, mysql, python, data, agile,
# #########################
# ******* Infrastructure Engineer Infrastructure And Application Monitoring ******
# restful, api, ruby, analysis, thinking, python, data,
# #########################
# ******* It Engineer Cloud Server Linux Configurations Deployment ******
# documentation, data, aws, linux,
# #########################
# ******* Cloud Engineer ******
# sql, data,
# #########################
# ******* Cloud Site Reliability Engineer Salesforce ******
# docker, gcp, aws, java, salesforce, analysis, linux, python, bootstrap, swift, jenkins,
# #########################
# ******* Technical Support Engineer Video Cloud ******
# thinking, optimization, data,
# #########################
# ******* It Technical Architect Cloud Infrastructure Lead ******
# aws, gcp, linux, script, ubuntu, data, bi, power bi,
# #########################
# ******* Security Engineer ******
# docker, aws, java, javascript, linux, git, devops, python, jenkins,
# #########################
# ******* Service Cloud Solution Engineer Salesforce ******
# database, java, salesforce, html, erp, sql,
# #########################
# ******* Service Cloud Solution Engineer Salesforce ******
# database, java, salesforce, html, erp, sql,
# #########################
# ******* Service Cloud Solution Engineer Worknow ******
# database, java, salesforce, html, erp, sql,
# #########################
# ******* Senior Research Engineer ******
# modeling, documentation, data, analysis,
# #########################
# ******* Service Cloud Solution Engineer Urgent ******
# database, java, salesforce, html, erp, sql,
# #########################
# ******* Senior Devops Engineer ******
# docker, mobile, gcp, sql, nosql, aws, react, javascript, python, rest, data, node,
# #########################
# ******* Service Cloud Solution Engineer Salesforce Urgent ******
# database, java, salesforce, html, erp, sql,
# #########################
# ******* Big Data Technical Architecture Delivery Team Lead ******
# api, agile, database,
# #########################
# ******* Cloud Software Engineer Contract ******
# devops,
# #########################
# ******* Cloud Site Reliability Engineer Worknow ******
# docker, gcp, aws, java, salesforce, analysis, linux, python, bootstrap, swift, jenkins,
# #########################
# ******* Senior System Engineer ******
# documentation, data, analysis, aws,
# #########################
# ******* Cloud Devops Engineer Data Quality Vice President ******
# docker, apache, sql, aws, java, spark, python, optimization, data,
# #########################
# ******* Service Cloud Solution Engineer Worknow ******
# database, java, salesforce, html, erp, sql,
# #########################
# ******* Devops Engineer ******
# java, nodejs, github, jira, devops, python, data, jenkins,
# #########################
# ******* Cloud Infrastructure Architect ******
# thinking, documentation, linux,
# #########################
# ******* Service Cloud Solution Engineer Urgent ******
# database, java, salesforce, html, erp, sql,
# #########################
# ******* Site Reliability Engineer Associate Lead Public Cloud Ai Machine Learning Big Data Servicenow Blockchain ******
# gcp, aws, java, documentation, json, analysis, ai, splunk, git, devops, python, ubuntu, rest, data, agile, jenkins,
# #########################
# ******* Platform Linux Engineer ******
# ruby, linux, optimization, bash, python, rest,
# #########################
# ******* Site Reliability Engineer Cloud Vice President Worknow ******
# gcp, aws, java, json, thinking, rest, splunk, git, ubuntu, python, optimization, data, agile, jenkins,
# #########################
# ******* Devops Engineer Sre ******
# kotlin, java, typescript, ai, javascript, linux, thinking, mongodb, devops, python, data,
# #########################
# ******* Cloud System Engineer ******
# analysis, linux, devops, rest, data,
# #########################
# ******* System Infra Engineer ******
# consulting, aws, bash, linux,
# #########################
# ******* Manager Infocomm Infrastructure ******
# docker, analysis, aws,
# #########################
# ******* Support And Reliability Engineer ******
# linux, devops,
# #########################
# ******* Devops Engineer ******
# net, docker, aws, documentation, analysis, react, linux, thinking, bash, devops, python, agile,
# #########################
# ******* Lead Devops Engineer ******
# net, ruby, aws, documentation, linux, rest, jira, splunk, git, devops, python, bash, optimization, ubuntu, jenkins,
# #########################
# ******* Lead Devops Engineer ******
# docker, gcp, aws, github, bash, devops, microservices, data, jenkins,
# #########################
# ******* Manager Infocomm Infrastructure ******
# docker, analysis, aws,
# #########################
# ******* Infrastructure Engineer ******
# aws, documentation, analysis, linux, data,
# #########################
# ******* Devops Engineer ******
# restful, docker, api, lambda, java, linux, devops, rest, agile,
# #########################
# ******* Vmware Engineer ******
# docker, sql, gcp, aws, javascript, linux, thinking, github, splunk, devops, python, jenkins,
# #########################
# ******* Senior Devops Engineer ******
# docker, documentation, linux, rest, jira, splunk, git, devops, ubuntu, optimization, jenkins,
# #########################
# ******* System Engineer ******
# docker, aws, documentation, linux, optimization, data,
# #########################
# ******* Lead Devops Engineer ******
# net, docker, ruby, aws, documentation, linux, jira, splunk, git, devops, python, bash, optimization, ubuntu,
# #########################
# ******* Senior Devops Engineer ******
# docker, aws, documentation, linux, rest, jira, splunk, git, devops, ubuntu, optimization, jenkins,
# #########################
# ******* Cloud Software Engineer Principal Engineer ******
# database,
# #########################
# ******* Senior Engineer Core Operations ******
# documentation, script, linux,
# #########################
# ******* Cloud Architect ******
# aws,
# #########################
# ******* Cloud ******
# aws, documentation, linux, microservices, data,
# #########################
# ******* Senior Software Engineer ******
# docker, api, lambda, database, aws, java, agile, python, linux, git, devops, jenkins, data, autodesk, node,
# #########################
# ******* Database Hybrid Cloud Engineer ******
# aws, database, analysis, linux, sql, data, customer service,
# #########################
# ******* Infrastructure Architect ******
# docker, consulting, java, splunk, bash, python, data,
# #########################
# ******* Systems Hybrid Cloud Engineer ******
# analysis, aws, linux, customer service,
# #########################
# ******* System Engineer ******
# optimization, documentation,
# #########################
# ******* Devops Engineer Urgent ******
# data, aws, devops,
# #########################
# ******* Devops Engineer ******
# docker, ruby, aws, documentation, jira, bash, devops, python, ubuntu, script, jenkins,
# #########################
# ******* Systems Engineer Engineering ******
# analysis, database, linux, customer service,
# #########################
# ******* Senior Manager Hosting Platform ******
# docker, optimization, data,
# #########################
# ******* It Infrastructure Engineer ******
# sql, aws, database,
# #########################
# ******* Senior Software Engineer ******
# docker, api, lambda, database, aws, java, agile, python, linux, git, devops, jenkins, data, autodesk, node,
# #########################
# ******* Cloud Data Engineer ******
# sql, gcp, database, aws, python, data, bi,
# #########################
# ******* Manager Devops Lead ******
# net, docker, gcp, java, nodejs, bash, devops, python, data, agile,
# #########################
# ******* Lead Senior Cloud Infrastructure Engineer ******
# data, aws,
# #########################
# ******* Devops Engineer Job ******
# net, restful, docker, ruby, aws, hadoop, microservices, linux, splunk, bash, devops, python, ubuntu, optimization, data, jenkins,
# #########################
# ******* Solution Architect ******
# mobile, optimization, analysis, aws,
# #########################
# ******* Senior Devops Engineer ******
# net, docker, ruby, aws, documentation, linux, jira, splunk, git, devops, python, bash, optimization, data, ubuntu, jenkins,
# #########################
# ******* Devops Engineer ******
# mobile, aws, react, microservices, data,
# #########################
# ******* System Engineer Rc ******
# aws, linux,
# #########################
# ******* System Administrator ******
# thinking,
# #########################
# ******* Cloud Architect ******
# aws,
# #########################
# ******* It Infrastructure Engineer ******
#
# #########################
# ******* Cloud Specialist ******
# consulting, data, aws,
# #########################
# ******* System Engineer ******
# thinking, aws, linux,
# #########################
# ******* Big Data Technical Architecture Delivery Manager ******
# data,
# #########################
# ******* Senior Engineer ******
# rest, linux,
# #########################
# ******* Aws Solutions Architect ******
# docker, agile, aws, devops,
# #########################
# ******* Avp Senior Associate Cloud Developer Ces Public ******
# ruby, aws, java, analysis, linux, python, agile,
# #########################
# ******* Site Reliability Engineer Infrastructure Engineering ******
# aws, hadoop, java, linux, python, optimization, data,
# #########################
# ******* System Engineer ******
# consulting,
# #########################
# ******* Infrastructure Engineer ******
# data, linux,
# #########################
# ******* Brand Technical Specialist Cloud Platform ******
# thinking, microservices, api, database,
# #########################
# ******* Cloud Communication Solution Byteplus ******
# customer service,
# #########################
# ******* Senior Executive Cloud Contact Centre ******
# sql, java, documentation, javascript, python, json,
# #########################
# ******* Senior Devops Engineer ******
# docker, aws, documentation, linux, rest, jira, splunk, git, devops, ubuntu, optimization, jenkins,
# #########################
# ******* Site Reliability Engineer Recommendation Architecture ******
# mobile, analysis, linux, devops, python, optimization,
# #########################
# ******* System Engineer ******
# database, aws, ai, devops, sql, data,
# #########################
# ******* Cloud Infrastructure Engineer ******
# net, docker, database, aws, consulting, documentation, analysis, devops, data, agile,
# #########################
# ******* System Specialist ******
# python, script, docker, devops,
# #########################
# ******* Aws Cloud It Operations Manager ******
# aws, database,
# #########################
# ******* Deputy Director Assistant Director Automation Engineering ******
# docker, sql, database, react, javascript, jira, git, python, agile, jenkins,
# #########################
# ******* Infrastructure Engineer Year Renewable Contract Changi Up To ******
# docker, apache, aws, linux, data,
# #########################
# ******* Associate Public Cloud Engineer Cloud Engineering Services ******
# aws, java, analysis, linux, python, data,
# #########################
# ******* Devops Engineer ******
# docker, data, database, devops,
# #########################
# ******* Senior Devops Engineer ******
# python, docker, analysis,
# #########################
# ******* Avp Senior Cloud Engineer Data Technology Technology Operations ******
# aws, documentation, json, analysis, javascript, linux, rest, python, optimization, agile, jenkins, customer service,
# #########################
# ******* Devops Engineer ******
# database, aws, documentation, linux, mysql, github, splunk, devops, data, jenkins,
# #########################
# ******* Vp Senior Cloud Engineer Data Technology Technology Operations ******
# aws, documentation, json, analysis, javascript, linux, rest, python, optimization, agile, jenkins, customer service,
# #########################
# ******* Aws Soc Support Engineer ******
# ruby, aws, analysis, linux, html, sql, data,
# #########################
# ******* Cloud Solution Architect ******
# net, api, aws, consulting, java, documentation, analysis, devops, microservices,
# #########################
# ******* System Admin Devops Engineer ******
# docker, database, linux, github, devops, microservices, data,
# #########################
# ******* Communications Testbed Engineer ******
# python, java, linux,
# #########################
# ******* Infra Engineer Jh ******
# documentation,
# #########################
# ******* Infrastructure Engineer Log Management ******
# splunk, linux,
# #########################
# ******* Avp Senior Associate Cloud Developer Ces Public ******
# ruby, aws, java, analysis, linux, python, agile,
# #########################
# ******* Devops Engineer ******
# django, aws, typescript, react, javascript, devops, python,
# #########################
# ******* Systems Engineer ******
# docker, apache, aws, analysis, linux, python, optimization, data,
# #########################
# ******* Service Cloud Solution Engineer Urgent ******
# database, java, salesforce, html, erp, sql,
# #########################
# ******* Cloud Security Specialist ******
# microservices, data, aws,
# #########################
# ******* Devops Engineer ******
# docker, apache, sql, blockchain, java, analysis, mongodb, mysql, python, optimization, data,
# #########################
# ******* Senior Cloud Engineer Group Consumer Banking Big Data ******
# linux, javascript, data, python, script,
# #########################
# ******* Cloud Architect ******
# data, analysis, aws, linux,
# #########################
# ******* Cloud Infrastructure Developer Associate ******
# docker, api, lambda, aws, documentation, json, analysis, postgresql, github, devops, rest, jenkins,
# #########################
# ******* Public Cloud Solution Engineer Technology And Operations ******
# gcp, aws, java, analysis, linux, python, optimization, agile, node, customer service,
# #########################
# ******* Devops Engineer ******
# database, aws, gcp, devops, data,
# #########################
# ******* Devsecops Engineer ******
# docker, analysis, ai, devops, python, data,
# #########################
# ******* Senior Systems Engineer ******
# sql, consulting, javascript, data, python, script,
# #########################
# ******* Network Engineer ******
# optimization, data, ubuntu, documentation,
# #########################
# ******* Solution Architect ******
# data, analysis, aws, linux,
# #########################
# ******* Solution Architect ******
# data, analysis, aws, linux,
# #########################
# ******* Senior Associate Cloud Engineer Data Technology Technology Operations ******
# aws, documentation, json, analysis, javascript, linux, rest, python, optimization, data, agile, jenkins, customer service,
# #########################
# ******* Infrastructure Cloud Administrator ******
# sql, data, analysis,
# #########################
# ******* Infrastructure Architect ******
# docker, java, splunk, bash, python,
# #########################
# ******* Cloud Engineer ******
# aws, gcp, ai, thinking, devops,
# #########################
# ******* Cloud Engineer ******
# aws, gcp, ai, thinking, devops,
# #########################
# ******* Backup Storage Engineer Up To Months Contract Somerset ******
# data,
# #########################
# ******* Service Enablement And Provisioning Manager ******
# aws, java, linux, jira, git, devops, script, agile,
# #########################
# ******* Devops Engineer Python Java ******
# net, aws, java, git, devops, python, bash, jenkins,
# #########################
# ******* Senior Cloud Engineer ******
# database, analysis, linux, devops, python, json,
# #########################
# ******* Devops Engineer ******
# apache, java, analysis, linux, data, jenkins,
# #########################
# ******* Devops Engineer ******
# aws, devops, python, rest, jenkins,
# #########################
# ******* Senior Devops Engineer ******
# hadoop, spark, linux, python, optimization, data,
# #########################
# ******* Presales Cloud Consultant Up To Cbd ******
# aws,
# #########################
# ******* Aws Cloud Developer ******
# python, api, react,
# #########################
# ******* Vp Cloud Architect Group Infrastructure Platform Services ******
# aws, gcp, devops,
# #########################
# ******* Cloud Engineer ******
# aws,
# #########################
# ******* Cloud Data Centre Engineer ******
# ai, linux, data, python, script,
# #########################
# ******* Cloud Infrastructure Engineer ******
# aws, gcp, ai, thinking, devops,
# #########################
# ******* Deputy Assistant Director Security Tools Platform ******
#
# #########################
# ******* Senior Assoc Infrastructure Cloud Devops Engineer ******
# gcp, aws, documentation, analysis, devops, python,
# #########################
# ******* Infrastructure Engineer ******
# analysis, aws,
# #########################
# ******* Senior Associate Associate System Monitoring Engineer Tech ******
# docker, linux, html, python, script, web development,
# #########################
# ******* Cloud Solutions Architect ******
# sql, nosql, scala, hadoop, database, java, consulting, aws, ai, spark, devops, python, data,
# #########################
# ******* Vp Group Technology Operations Public Cloud Solution Engineer ******
# json, jenkins, spring, api, lambda, angular, mongodb, devops, python, mvc, react, vue, microservices, rest, agile, docker, aws, java, javascript, git, sql, node, web development,
# #########################
# ******* Backup Storage Engineer Somerset Months Contract ******
# data,
# #########################
# ******* Network Engineer ******
# agile,
# #########################
# ******* Solution Manager Hybrid Cloud Sap ******
# consulting, documentation, analysis, aws,
# #########################
# ******* Junior System Engineer ******
# sql, aws, documentation, linux, python, data,
# #########################
# ******* Chief Technology Officer ******
# thinking, devops,
# #########################
# ******* Avp Sr Associate Sre Devops Lead Investment Trading ******
# docker, analysis, react, mysql, jira, splunk, devops, sql, agile, jenkins,
# #########################
# ******* Senior Software Engineer Job ******
# net, docker, apache, gcp, aws, java, typescript, javascript, mysql, postgresql, rabbitmq, rest, devops, python, microservices, data, agile,
# #########################
# ******* Site Reliability Engineer Cloud Vice President Worknow ******
# gcp, aws, java, json, thinking, rest, splunk, git, ubuntu, python, optimization, data, agile, jenkins,
# #########################
# ******* It Executive System Analyst ******
# sql, analysis, aws,
# #########################
# ******* Sap Cloud Solution Architect Manager ******
# docker, database, aws, documentation, analysis, postgresql, mongodb,
# #########################
# ******* Cloud Native Senior Software Engineer Development Lead ******
# spring, mobile, database, java, mysql, rest, vue, jira, devops, microservices, agile,
# #########################
# ******* Presales Solution Consultant ******
# analysis,
# #########################
# ******* Linux Engineer Devops Infrastructure Support Vp ******
# aws, java, analysis, linux, thinking, python, data,
# #########################
# ******* Avp Senior Associate Devops Engineer Virtual Private Cloud ******
# python, microservices, docker, linux,
# #########################
# ******* It Technical Architect Cloud Infrastructure Worknow ******
# aws, gcp, linux, script, ubuntu, data, bi, power bi,
# #########################
# ******* Devops Engineer ******
# docker, django, react, linux, devops, python, script,
# #########################
# ******* Deployment Engineer ******
# mobile, sql, java, analysis, io, linux, script, git, devops, python, android, jenkins,
# #########################
# ******* Cloud Site Reliability Engineer Worknow ******
# docker, gcp, aws, java, salesforce, analysis, linux, python, bootstrap, swift, jenkins,
# #########################
# ******* Senior System Engineer Central ******
# database, express, linux,
# #########################
# ******* Regional It Engineer ******
# rest,
# #########################
# ******* Junior Devops Engineer Entry Level Urgent ******
# aws, linux, database, devops,
# #########################
# ******* Aws Cloud Developer ******
# api, lambda, database, aws, react, python, data,
# #########################
# ******* Cloud Engineer ******
# aws, gcp, ai, thinking, devops,
# #########################
# ******* Cloud Site Reliability Engineer Salesforce ******
# docker, gcp, aws, java, salesforce, analysis, linux, python, bootstrap, swift, jenkins,
# #########################
# ******* Cloud Devops Engineer Data Quality Vice President ******
# docker, apache, sql, aws, java, spark, python, optimization, data,
# #########################
# ******* Systems Consultant ******
# aws, database, linux, devops, data,
# #########################
# ******* Devops Consultant ******
# python, javascript, consulting, devops,
# #########################
# ******* Cloud Infrastruture Engineers ******
# aws, devops,
# #########################
# ******* Service Cloud Solution Engineer Salesforce ******
# database, java, salesforce, html, erp, sql,
# #########################
# ******* Senior Cloud Security Engineer ******
# data, mobile,
# #########################
# ******* It Engineer Cloud Server Linux Configurations Deployment ******
# documentation, data, aws, linux,
# #########################
# ******* Cloud Architect ******
# docker, lambda, aws, consulting, thinking, devops, optimization,
# #########################
# ******* Service Cloud Solution Engineer Urgent ******
# database, java, salesforce, html, erp, sql,
# #########################
# ******* Cloud Security Analyst ******
# aws, data, splunk, linux,
# #########################
# ******* Solutions Architect ******
# aws, database, consulting, devops, agile,
# #########################
# ******* Cloud Engineer ******
# aws, java, typescript, nodejs, thinking, python, agile,
# #########################
# ******* Cloud Engineer ******
# aws, gcp, database,
# #########################
# ******* Lead Network Engineer Worknow ******
# gcp, aws, salesforce, documentation, express, linux, data, devops, python, script,
# #########################
# ******* Security Infra Cloud System Engineer ******
# documentation, data, splunk, linux,
# #########################
# ******* Avp Senior Associate Infra Cloud Engineer ******
# aws, documentation, json, analysis, linux, rest, git, optimization, agile, jenkins, customer service,
# #########################
# ******* Avp Senior Associate Infra Cloud Engineer ******
# aws, documentation, json, analysis, linux, rest, git, optimization, agile, jenkins, customer service,
# #########################
# ******* Avp Senior Associate Infra Cloud Engineer ******
# aws, documentation, json, analysis, linux, rest, git, optimization, agile, jenkins, customer service,
# #########################
# ******* Avp Senior Associate Infra Cloud Engineer Urgent ******
# aws, documentation, json, analysis, linux, rest, git, optimization, agile, jenkins, customer service,
# #########################
# ******* Cloud Devsecops Architect ******
# net, restful, spring, api, lambda, aws, java, php, devops, optimization, data,
# #########################
# ******* Devops Engineer ******
# database, java, linux, devops, python,
# #########################
# ******* Service Cloud Solution Engineer Salesforce Urgent ******
# database, java, salesforce, html, erp, sql,
# #########################
# ******* Cloud Engineer ******
# aws, gcp, ai, thinking, devops,
# #########################
# ******* Principal Senior Devops Engineer ******
# docker, sql, autodesk, nosql, database, aws, linux, bash, devops, python, data, agile,
# #########################
# ******* Associate Analyst Cloud Devops Engineer ******
# gcp, aws, documentation, analysis, devops, python,
# #########################
# ******* System Engineer ******
# consulting, data, analysis, aws,
# #########################
# ******* Research Engineer Mobile Systems Cloud Security Nsoe ******
# java,
# #########################
# ******* Azure Cloud Specialist ******
# script, analysis, json, data,
# #########################
# ******* Lead Devops Engineer ******
# net, docker, ruby, aws, documentation, linux, jira, splunk, git, devops, python, bash, optimization, ubuntu, jenkins,
# #########################
# ******* Business System Analyst Web Application Exp ******
# sql, analysis, aws,
# #########################
# ******* Cloud Application Support Engineer ******
# aws, thinking, splunk, optimization, data,
# #########################
# ******* Senior Principal Engineer ******
# aws, ai, linux, jira, devops, python, jenkins,
# #########################
# ******* Network Performance Engineer ******
# aws, documentation, analysis, jenkins,
# #########################
# ******* Principal Senior Devops Engineer ******
# docker, sql, autodesk, nosql, database, aws, linux, bash, devops, python, data, agile,
# #########################
# ******* Research Engineer Mobile Systems Cloud Security Nsoe ******
# java, mobile,
# #########################
# ******* Cybersecurity Engineer ******
# aws, rest, database,
# #########################
# ******* Service Cloud Solution Engineer Worknow ******
# database, java, salesforce, html, erp, sql,
# #########################
# ******* Associate Public Cloud Sre Specialist Cloud Engineering ******
# aws, java, javascript, linux, git, python, rest, script, json,
# #########################
# ******* Service Cloud Solution Engineer Salesforce ******
# database, java, salesforce, html, erp, sql,
# #########################
# ******* Avp Senior Associate Cloud Infrastructure Engineer ******
# docker, apache, django, sql, ruby, database, java, javascript, linux, html, springboot, git, devops, python, php, rest, json, web development,
# #########################
# ******* Service Cloud Solution Engineer Worknow ******
# database, java, salesforce, html, erp, sql,
# #########################
# ******* Senior Specialist Engineer Service Operations ******
# documentation, analysis, customer service,
# #########################
# ******* Infrastructure And Devops Engineer ******
# apache, database, aws, angular, java, analysis, javascript, mysql, linux, jira, git, devops, python, jenkins,
# #########################
# ******* Public Cloud Solution Engineer Technology And Operations ******
# gcp, aws, java, analysis, linux, python, optimization, agile, node, customer service,
# #########################
# ******* Senior Devops Engineer ******
# docker, mobile, thinking, jira, devops, microservices, jenkins,
# #########################
# ******* Avp Senior Associate Pcf Cloud Operations Engineer ******
# spring, gcp, aws, java, linux, splunk, devops, python, data, agile, jenkins, customer service,
# #########################
# ******* Cloud Devops Engineer ******
# kotlin, docker, gcp, aws, documentation, typescript, javascript, mysql, splunk, devops, python, data, agile,
# #########################
# ******* Vp Public Cloud Solution Engineer Technology And Operations ******
# gcp, java, analysis, linux, python, optimization, agile, node, customer service,
# #########################
# ******* Systems Engineer ******
# documentation,
# #########################
# ******* Vp Public Cloud Solution Engineer Technology And Operations ******
# gcp, java, analysis, linux, python, optimization, agile, node, customer service,
# #########################
# ******* It Staff Urgent ******
# net, ruby, database, java, javascript, linux, html, sql, web development,
# #########################
# ******* Cloud Specialist West ******
# aws,
# #########################
# ******* Cloud Software Engineer Principal Engineer ******
# database,
# #########################
# ******* Devsecops ******
# apache, database, aws, angular, java, analysis, javascript, mysql, linux, jira, git, devops, python, jenkins,
# #########################
# ******* Devops Engineer Vice President Urgent Immediate ******
# docker, java, analysis, linux, devops, python, data,
# #########################
# ******* It Enterprise Architect ******
# docker, github, jira, devops, microservices, agile, jenkins,
# #########################
# ******* Senior Associate Infrastructure Cloud Devops Engineer ******
# gcp, aws, documentation, analysis, devops, python,
# #########################
# ******* Senior Associate Infrastructure Cloud Devops Engineer ******
# gcp, aws, documentation, analysis, devops, python,
# #########################
# ******* Avp Senior Associate Infra Cloud Middleware Engineer ******
# apache, aws, analysis, linux, git, agile, jenkins,
# #########################
# ******* Avp Senior Associate Infra Cloud Middleware Engineer ******
# apache, aws, analysis, linux, git, agile, jenkins,
# #########################
# ******* Devops Engineer ******
# docker, autocad, mobile, aws, javascript, linux, devops, python, autodesk, jenkins,
# #########################
# ******* Infrastructure Engineer ******
# data, ai, database,
# #########################
# ******* Devsecops Engineer ******
# docker, spring, aws, angular, java, react, linux, devops, script, agile, node, spring boot,
# #########################
# ******* Vp Group Technology Operations Public Cloud Solution Engineer ******
# json, jenkins, spring, api, lambda, angular, mongodb, devops, python, mvc, react, vue, microservices, rest, agile, docker, aws, java, javascript, git, sql, node, web development,
# #########################
# ******* Devops Engineer ******
# docker, spring, api, mobile, gcp, database, aws, java, analysis, io, linux, jira, data, git, devops, python, android, jenkins, spring boot,
# #########################
# ******* Devops Engineer Up To ******
# net, aws, java, git, devops, python, bash, jenkins,
# #########################
# ******* Devops Expert ******
# docker, microservices, aws, devops,
# #########################
# ******* Senior Devops Engineer ******
# docker, autocad, mobile, aws, javascript, linux, devops, python, autodesk, jenkins,
# #########################
# ******* Assistant Vice President ******
# aws, consulting, analysis, thinking, devops, python, jenkins,
# #########################
# ******* Solution Architect ******
# docker, data, aws,
# #########################
# ******* Senior Devops Engineer ******
# net, aws, java, git, devops, python, bash, jenkins,
# #########################
# ******* Svp Public Cloud Software Engineer Technical Lead ******
# json, spring, api, lambda, angular, mongodb, python, mvc, react, vue, rest, microservices, agile, docker, aws, java, javascript, git, sql, node, web development,
# #########################
# ******* Cloud Engineer ******
#
# #########################
# ******* Associate Cloud Devops Engineer Technology And Operations ******
# aws, gcp, documentation, analysis, python,
# #########################
# ******* Research Engineer I ******
# spring, api, sql, nosql, database, hadoop, aws, java, linux, data, ubuntu, python, script,
# #########################
# ******* Staff Engineer ******
# linux, jira, bash, devops, python, data,
# #########################
# ******* Infrastructure Engineer ******
# sql, ruby, linux, php, python, optimization,
# #########################
# ******* Cloud Specialist West ******
# analysis, aws, ubuntu, linux,
# #########################
# ******* It Infrastructure Architect ******
# consulting, devops,
# #########################
# ******* Devops Engineer Tech Start Up ******
# django, typescript, react, javascript, devops, python,
# #########################
# ******* Cloud Devops Engineer ******
# net, docker, api, database, aws, angular, java, javascript, linux, php, devops, python, data, agile,
# #########################
# ******* Application Infrastructure Engineer ******
# net, api, sql, documentation, javascript, devops, python, agile, bi, power bi,
# #########################
# ******* Application Infrastructure Engineer ******
# restful, sql, nosql, reactjs, database, aws, angular, typescript, nodejs, javascript, mysql, linux, mongodb, devops, python, ux, agile,
# #########################
# ******* Fvp Vp Devops Lead Microservices Continous Delivery Group Technology ******
# ruby, analysis, thinking, jira, devops, python, jenkins,
# #########################
# ******* Lead System Engineer ******
# docker, hadoop, linux, rabbitmq, data,
# #########################
# ******* Full Stack Engineer ******
# mobile, nosql, aws, react, javascript, springboot, mongodb, mysql, android,
# #########################
# ******* Support Engineer Sre Worknow ******
# docker, scala, angular, java, analysis, springboot, jira, splunk, devops, python, data, agile, jenkins,
# #########################
# ******* Senior Devops Engineer Passenger Processing Systems And Azure Cloud Operations ******
# aws, java, documentation, javascript, mysql, html, jira, git, devops, sql, data, jenkins,
# #########################
# ******* Lead Cybersecurity Engineer Jr ******
# gcp, aws, jira, splunk, devops, data, agile,
# #########################
# ******* Lead Devops Engineer ******
# net, docker, ruby, aws, documentation, linux, jira, splunk, git, devops, python, bash, optimization, ubuntu, jenkins,
# #########################
# ******* System Engineer ******
# python, php, linux,
# #########################
# ******* Devops Engineer ******
# aws, devops,
# #########################
# ******* Senior Research Engineer ******
# modeling, documentation, data, analysis,
# #########################
# ******* Devops Engineer Central ******
# net, java, mysql, jira, git, devops, agile, jenkins,
# #########################
# ******* Programs And Alliances Manager Asean ******
# data, aws,
# #########################
# ******* Cloud Security Architect ******
# data, analysis,
# #########################
# ******* Devops Engineer ******
# gcp, aws, consulting, javascript, devops, python,
# #########################
# ******* Senior Research Engineer ******
# modeling, documentation, data, analysis,
# #########################
# ******* Senior Research Engineer ******
# modeling, documentation, data, analysis,
# #########################
# ******* Presales It Engineer ******
# aws, html, database,
# #########################
# ******* Cloud Security Devops Engineer ******
# database, gcp, aws, linux, erp, jira, git, devops,
# #########################
# ******* System Engineer ******
# ruby, database, documentation, linux, mysql, postgresql, mongodb, bash, devops, python, rest, script,
# #########################
# ...
# ux, data, agile,
# #########################
# ******* Svp Vp Digital Product Manager Consumer Banking Group ******
# ux, data, agile,
# #########################
# ******* Apac Securities Change Process Oversight ******
# kong,
# #########################
# ******* Business System And Process Manager ******
# excel, optimization, consulting,
# #########################
# ******* Business System And Process Manager ******
# excel, optimization, consulting,
# #########################
# ******* Svp Program Director ******
# ai, optimization, data, agile, bi,
# #########################
# ******* Customer Success Manager ******
# consulting, html, database, javascript,
# #########################
# ******* Technology Resilience Manager Vice President ******
# mobile, documentation, analysis, data, agile,
# #########################
# ******* Payments Counsel Regional Legal ******
#
# #########################
# ******* Affiliate Senior Associate Singapore ******
# excel, data, analysis,
# #########################
# ******* Manager Compliance Systems Implementation Singapore ******
# documentation, kong, mobile, data,
# #########################
# ******* Technical Program Manager ******
# consulting, data, ai,
# #########################
# ******* Operations Lead ******
# excel, analysis, erp, sql, data,
# #########################
# ******* Avp Performance Marketing Consumer Banking Group ******
# mobile, optimization, analysis, spark,
# #########################
# ******* Tax Analyst Amk Up Immediate ******
# documentation, data,
# #########################
# ******* Tax Analyst Amk Up Immediate ******
# documentation, data,
# #########################
# ******* Senior Manager Packaging Engineering Apac ******
# modeling,
# #########################
# ******* Years Taxing Officer Immediate Amk ******
# documentation, data,
# #########################
# ******* Innovation Researcher City Location Ref ******
# aws,
# #########################
# ******* Vp Regional Trade Finance Project Test Lead Institutional Banking Group Operations Technology And Operations ******
# agile,
# #########################
# ******* Head Mobile Development ******
# net, mobile, aws, thinking, devops,
# #########################
# ******* Regional Trucking Portfolio Strategy Procurement Vp Transport ******
# excel, optimization,
# #########################
# ******* Digital Channels Business Analyst ******
# documentation, analysis, modeling, data, agile,
# #########################
# ******* Digital Channels Business Analyst ******
# documentation, analysis, modeling, data, agile,
# #########################
# ******* Svp Vp Enterprise Agile Coach Transformation Group ******
# analysis, thinking, devops, data, agile,
# #########################
# ******* Vp Customer Experience Digital Group Business Banking ******
# consulting, thinking,
# #########################
# ******* Fvp Project Manager Group Retail Channels T O ******
# consulting, data,
# #########################
# ******* Qa Qc Engineer ******
# documentation, api, aws,
# #########################
# ******* Senior Industry Development Officer Assistant Industry Development Manager ******
# documentation,
# #########################
# ******* Planner ******
# excel, erp,
# #########################
# ******* Staff Factory Automation Engineer ******
# autocad,
# #########################
# ******* Assoc Manager Equipment Maintenance Engineering ******
# thinking, documentation, analysis,
# #########################
# ******* Service Technician ******
#
# #########################
# ******* Digital Onboarding App Development Sr Manager Singapore ******
# spring, angular, java, analysis, devops, data, ui,
# #########################
# ******* Head Of Business Partnering ******
# database,
# #########################
# ******* Technician Hook Up Project Management M F ******
#
# #########################
# ******* Technician M F ******
#
# #########################
# ******* Facilities Engineer ******
#
# #########################
# ******* Technician M F ******
#
# #########################
# ******* Vice President Project Management Officer Transformation Office ******
# excel, data, analysis, consulting,
# #########################
# ******* It Senior Project Manager ******
# thinking, analysis,
# #########################
# ******* Program Planning Lead ******
#
# #########################
# ******* Global Commodity Management Consultant ******
# optimization, data, analysis, ai,
# #########################
# ******* Tax Analyst Amk Up Immediate ******
# documentation, data,
# #########################
# ******* Marketing Assistant ******
# excel,
# #########################
# ******* Community Manager Incubation ******
#
# #########################
# ******* Crm Lead ******
# mobile, excel, java, salesforce, adobe, analysis, html, sql, tableau, modeling, data,
# #########################
# ******* Marketing Manager ******
#
# #########################
# ******* Assistant Manager Property Management ******
# excel, analysis,
# #########################
# ******* Production Delivery Manager ******
# analysis,
# #########################
# ******* Hr Admin Executive ******
# data,
# #########################
# ******* Sr Unix Engineer Vmware ******
# python, apache, linux,
# #########################
# ******* Executive ******
# database,
# #########################
# ******* Content Writer ******
# seo, data, ai,
# #########################
# ******* Senior Hr Executive ******
# excel, data,
# #########################
# ******* Project Engineer ******
# documentation,
# #########################
# ******* Senior Industry Development Officer Assistant Industry Development Manager ******
# documentation,
# #########################
# ******* Project Engineer ******
# documentation,
# #########################
# ******* Building Services Engineer ******
#
# #########################
# ******* Engineer Fac Mechanical ******
#
# #########################
# ******* Plant Engineer ******
# aws, documentation, database,
# #########################
# ******* Avp Collaboration And Unified Communications ******
# documentation, aws,
# #########################
# ******* Italian Application Tech Support Practitioner Manila Philippines ******
# analysis,
# #########################
# ******* Avp Collaboration M M And Unified Communications ******
# documentation,
# #########################
# ******* Planning Executive ******
# excel, analysis,
# #########################
# ******* Senior Manager Nscc ******
# quantum, ai,
# #########################
# ******* Retail Manager Singapore ******
# excel, data,
# #########################
# ******* Vice President Project Management Officer Transformation Office ******
# excel, data, analysis, consulting,
# #########################
# ******* Avp For Collaboration And Comms It South West Up To Sgd Mth ******
# documentation,
# #########################
# ******* Senior Content Specialist Asean ******
# seo, adobe, salesforce, html, wordpress,
# #########################
# ******* It Project Intermediary Manager ******
# excel,
# #########################
# ******* Apac Branches Cib Market Tech ******
# apache, database, linux, thinking, html, sql,
# #########################
# ******* Settlements Product Engineer ******
# sql, database, excel, linux, script, jira, git, python, data, agile,
# #########################
# ******* Tech Support Vendor Manager ******
# analysis, customer service,
# #########################
# ******* Tech Support Vendor Manager ******
# analysis, customer service,
# #########################
# ******* Tech Support Vendor Manager ******
# analysis, customer service,
# #########################
# ******* Tech Support Vendor Manager Hii ******
# analysis, customer service,
# #########################
# ******* Tech Support Vendor Manager Hiiii ******
# analysis, customer service,
# #########################
# ******* Kol Marketing ******
#
# #########################
# ******* Tech Support Vendor Manager ******
# analysis, customer service,
# #########################
# ******* Tech Support Vendor Manager Hiii ******
# analysis, customer service,
# #########################
# ******* Finance Project Manager ******
# mobile,
# #########################
# ******* Tech Support Vendor Manager ******
# analysis, customer service,
# #########################
# ******* Tech Support Vendor Manager ******
# analysis, customer service,
# #########################
# ******* First Vp Project Manager Customer Digital Channels ******
# agile,
# #########################
# ******* Tech Support Vendor Manager ******
# analysis, customer service,
# #########################
# ******* Smb Sales Senior Associate Singapore ******
# kong, mobile, data,
# #########################
# ******* Tech Support Vendor Manager Iphonex ******
# analysis, customer service,
# #########################
# ******* Tech Support Vendor Manager ******
# analysis, customer service,
# #########################
# ******* Tech Support Vendor Manager Iphone ******
# analysis, customer service,
# #########################
# ******* Tech Support Vendor Manager Hi ******
# analysis, customer service,
# #########################
# ******* Hydraulic Engineer ******
#
# #########################
# ******* Senior Manager Business System And Process ******
# optimization, agile,
# #########################
# ******* E Commerce Digital Manager ******
# optimization, data, analysis,
# #########################
# ******* Senior Java Developer ******
# restful, spring, nosql, mvc, database, angular, java, react, javascript, sql, rest, json, spring boot,
# #########################
# ******* Senior Accounts Executive ******
# excel, salesforce, data, customer service,
# #########################
# ******* Facilities Assistant Manager Casino Operations ******
# customer service,
# #########################
# ******* Facilities Assistant Manager Hotelc ******
# customer service,
# #########################
# ******* Account Management Executive ******
# data,
# #########################
# ******* Industrial Engineer ******
# autocad, excel, analysis, optimization, modeling, data,
# #########################
# ******* Years Tax Analyst Up Immediate Central ******
# documentation, data,
# #########################
# ******* Technical Service Manager ******
#
# #########################
# ******* Grip Programme Manager ******
#
# #########################
# ******* Music Director ******
# database,
# #########################
# ******* Worknow Business System And Process Manager Urgent ******
# excel, optimization, consulting,
# #########################
# ******* Technology Risk Program Manager Channels Technology Associate ******
# kong, analysis,
# #########################
# ******* Digital Channel Business Analyst ******
# documentation, analysis, modeling, data, agile,
# #########################
# ******* Technology Risk Program Manager Channels Technology Associate Urgent Immediate ******
# kong, analysis,
# #########################
# ******* It Business Unit Sr Manager ******
# excel, analysis, jira, agile,
# #########################
# ******* Manager Facilities Hotel ******
# customer service,
# #########################
# ******* Assistant Manager Quantum Engineering Programme ******
# quantum,
# #########################
# ******* Manager Facilities Hotel ******
# customer service,
# #########################
# ******* Tech Recruiter ******
# documentation, data, analysis,
# #########################
# ******* Senior Product Manager ******
# ux, analysis, ui,
# #########################
# ******* Months Contract Marketing Manager ******
# data,
# #########################
# ******* Sre Tech Lead Cloud Infrastructure ******
# thinking, optimization, data, linux,
# #########################
# ******* Manager Coe Hr Tech ******
# excel, thinking, data, database,
# #########################
# ******* Sea Growth Program Management ******
# excel, consulting,
# #########################
# ******* Digital Marketing Executive ******
# thinking, seo, data, adobe,
# #########################
# ******* Uiux Designer It Central Up To Sgd Mth Worknow ******
# adobe, figma, ux, data, ui,
# #########################
# ******* Senior Uiux Designer ******
# mobile, adobe, analysis, io, thinking, figma, ux, agile, ui,
# #########################
# ******* Senior Ui Ux Designer ******
# mobile, adobe, io, javascript, thinking, html, figma, ux, android, agile, ui,
# #########################
# ******* Interaction Executive ******
# html, ux, analysis, ui,
# #########################
# ******* Mobile App Graphics Designer And Developer ******
# mobile, analysis, io, figma, blockchain, ux, android, ui,
# #########################
# ******* Uiux Designer It Central Up To Sgd Mth ******
# adobe, figma, ux, data, ui,
# #########################
# ******* Senior Uiux Designer ******
# mobile, adobe, io, thinking, figma, ux, android, ui,
# #########################
# ******* Uiux Interaction Executive ******
# html, ux, analysis, ui,
# #########################
# ******* Interaction Uiux Designer ******
# html, ux, analysis, ui,
# #########################
# ******* Uiux Designer ******
# mobile, adobe, figma, ux, agile, ui,
# #########################
# ******* Uiux Designer ******
# html, ux, analysis, ui,
# #########################
# ******* Web Developer ******
# database, sas, angular, seo, analysis, react, express, html, vue, mongodb, git, bootstrap, node, ui, web development,
# #########################
# ******* Web Development Manager ******
# thinking, documentation, seo, agile, web development,
# #########################
# ******* Senior Manager Software Engineering ******
# mobile, documentation, thinking, flutter, agile,
# #########################
# ******* Senior Manager Software Engineering Urgent ******
# mobile, documentation, thinking, flutter, agile,
# #########################
# ******* Ui Ux Engineer Intern ******
# database, angular, documentation, ai, react, javascript, html, vue, erp, figma, ux, agile, ui,
# #########################
# ******* Senior Uiux Designer ******
# mobile, adobe, javascript, thinking, html, figma, ux, ui,
# #########################
# ******* Senior Uiux Designer ******
# mobile, adobe, analysis, thinking, figma, ux, agile, ui,
# #########################
# ******* Multimedia Uiux Designer ******
# ux, adobe, ui,
# #########################
# ******* Ux Designer ******
# mobile, adobe, thinking, figma, ux, agile, ui,
# #########################
# ******* Senior Ux Designer ******
# mobile, adobe, thinking, figma, ux, agile, ui,
# #########################
# ******* Uiux Designer ******
# mobile, adobe, figma, ux, agile, ui,
# #########################
# ******* Mobile App Graphics Designer Developer ******
# mobile, analysis, io, figma, blockchain, ux, android, ui,
# #########################
# ******* Qa Engineer ******
# api, mobile, database, io, jira, sql, android,
# #########################
# ******* Adjunct Lecturer Web Design Development Uiux Design ******
# bootstrap, data, php,
# #########################
# ******* Uiux Designer ******
# mobile, adobe, io, figma, ux, android, ui,
# #########################
# ******* Uiux Intern ******
# ux, agile, figma, ui,
# #########################
# ******* Ui Ux Design Intern ******
# ux, mobile, adobe, figma, rest, ui,
# #########################
# ******* Uiux Developer ******
# mobile, reactjs, angularjs, adobe, io, javascript, rest, html, figma, ux, android, ui,
# #########################
# ******* Product Manager ******
# analysis, agile,
# #########################
# ******* Ui Ux Designer ******
# adobe, thinking, figma, ux, ui,
# #########################
# ******* Senior Product Manager ******
# analysis, agile,
# #########################
# ******* Assistant Product Manager ******
# documentation, ux, analysis, agile,
# #########################
# ******* Senior Qa Engineer ******
# api, mobile, database, io, jira, sql, android,
# #########################
# ******* Business Development Growth Intern ******
# excel, adobe, ai, figma, data,
# #########################
# ******* Ui Ux Engineer ******
# database, angular, documentation, ai, react, javascript, html, vue, erp, figma, ux, agile, ui,
# #########################
# ******* Product Development Engineer ******
# reactjs, documentation, analysis, javascript, html, figma, mongodb, ux, data, ui,
# #########################
# ******* Growth Manager ******
# data, ai,
# #########################
# ******* Ui Ux Designer ******
# adobe, thinking, figma, ux, ui,
# #########################
# ******* Senior Uiux Designer ******
# ux, adobe, analysis, ui,
# #########################

# %%
with open("31_mar_soft_skills_map.csv", "w") as f:
    for index, row in df.iterrows():
#         print("*******",row['clean_job_title'],"******")
        for i in row['soft_skills']:
#             print(i, end=", ")
            try:
                f.write(row['keyword']+","+i+"\n")
            except:
                print(i)
#         print()
#         print("#"*25)
# Out:
# 对系统
# ansible和jenkins的经验
# 帮助将其整合到腾讯的平台上
# cd流程
# 高性能和高可用性的系统
# gcp或azure有经验
# shell脚本
# 以确保对客户的服务交付承诺得以实现
# 高性能的在线服务
# 有一定的抗压能力
# 熟练使用android开发和调试工具
# 熟悉android
# 熟悉android下网路通信机制
# 积极乐观
# 具有较强的学习能力和团队意识
# 熟悉android的线程机制
# 在不同的应用场景下能使用相对合理的设计模式
# 熟悉面向对象编程
# 对各种设计模式有一定的了解
# 启动时间
# ui框架及相关开发工具
# 能够熟练使用各种android系统的线程类
# signiﬁcant
